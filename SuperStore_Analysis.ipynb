# %% [markdown]
# # SuperStore Data Analysis
#
# Analyzing orders data of the Sample SuperStore to figure out trends and patterns

# %%
# Importing Libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

sns.reset_defaults()
sns.set_style('whitegrid')

# %%
# pd.set_option('display.max_rows',None)

# %% [markdown]
# **Loading Data**
#
# 1. Loading into DataFrame
# 1. Sort the values based on the order date
# 1. Check the number of records for each column and see the unique values

# %%
df_store = pd.read_excel(io='data/Sample_Superstore_Past.xls',sheet_name='Orders')
df_store.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# 0       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3       33311   South  FUR-TA-10000577        Furniture       Tables
# 4       33311   South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
#
# [5 rows x 21 columns]

# %%
# Drop rowid --> data in file is not sorted based on order date
df_store.drop(labels='Row ID',axis=1,inplace=True)

# %%
# Sort based on Order Date and reindex the dataframe
df_store.sort_values(by='Order Date',inplace=True)
df_store.reset_index(drop=True,inplace=True)
df_store.head()
# Out:
#          Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0  CA-2014-103800 2014-01-03 2014-01-07  Standard Class    DP-13000
# 1  CA-2014-112326 2014-01-04 2014-01-08  Standard Class    PO-19195
# 2  CA-2014-112326 2014-01-04 2014-01-08  Standard Class    PO-19195
# 3  CA-2014-112326 2014-01-04 2014-01-08  Standard Class    PO-19195
# 4  CA-2014-141817 2014-01-05 2014-01-12  Standard Class    MB-18085
#
#    Customer Name      Segment        Country          City         State  \
# 0  Darren Powers     Consumer  United States       Houston         Texas
# 1  Phillina Ober  Home Office  United States    Naperville      Illinois
# 2  Phillina Ober  Home Office  United States    Naperville      Illinois
# 3  Phillina Ober  Home Office  United States    Naperville      Illinois
# 4     Mick Brown     Consumer  United States  Philadelphia  Pennsylvania
#
#    Postal Code   Region       Product ID         Category Sub-Category  \
# 0        77095  Central  OFF-PA-10000174  Office Supplies        Paper
# 1        60540  Central  OFF-LA-10003223  Office Supplies       Labels
# 2        60540  Central  OFF-ST-10002743  Office Supplies      Storage
# 3        60540  Central  OFF-BI-10004094  Office Supplies      Binders
# 4        19143     East  OFF-AR-10003478  Office Supplies          Art
#
#                                         Product Name    Sales  Quantity  \
# 0  Message Book, Wirebound, Four 5 1/2" X 4" Form...   16.448         2
# 1                                          Avery 508   11.784         3
# 2                      SAFCO Boltless Steel Shelving  272.736         3
# 3         GBC Standard Plastic Binding Systems Combs    3.540         2
# 4  Avery Hi-Liter EverBold Pen Style Fluorescent ...   19.536         3
#
#    Discount   Profit
# 0       0.2   5.5512
# 1       0.2   4.2717
# 2       0.2 -64.7748
# 3       0.8  -5.4870
# 4       0.2   4.8840

# %%
# Check datatype and number of entries
df_store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       9994 non-null   object
#  1   Order Date     9994 non-null   datetime64[ns]
#  2   Ship Date      9994 non-null   datetime64[ns]
#  3   Ship Mode      9994 non-null   object
#  4   Customer ID    9994 non-null   object
#  5   Customer Name  9994 non-null   object
#  6   Segment        9994 non-null   object
#  7   Country        9994 non-null   object
#  8   City           9994 non-null   object
#  9   State          9994 non-null   object
#  10  Postal Code    9994 non-null   int64
#  11  Region         9994 non-null   object
#  12  Product ID     9994 non-null   object
#  13  Category       9994 non-null   object
#  14  Sub-Category   9994 non-null   object
#  15  Product Name   9994 non-null   object
#  16  Sales          9994 non-null   float64
#  17  Quantity       9994 non-null   int64
#  18  Discount       9994 non-null   float64
#  19  Profit         9994 non-null   float64
# dtypes: datetime64[ns](2), float64(3), int64(2), object(13)
# memory usage: 1.5+ MB

# %%
# Printing unique values
for col in df_store:
    print("\nUnique values for " + col + ':')
    if col == 'Order Date' or col == 'Ship Date':
        print(df_store[col].dt.year.unique())  # Instead of date check for the year
    else:
        print(df_store[col].unique())
# Out:
# Unique values for Order ID:
# ['CA-2014-103800' 'CA-2014-112326' 'CA-2014-141817' ... 'CA-2017-126221'
#  'CA-2017-156720' 'CA-2017-143259']
#
# Unique values for Order Date:
# [2014 2015 2016 2017]
#
# Unique values for Ship Date:
# [2014 2015 2016 2017 2018]
#
# Unique values for Ship Mode:
# ['Standard Class' 'First Class' 'Second Class' 'Same Day']
#
# Unique values for Customer ID:
# ['DP-13000' 'PO-19195' 'MB-18085' 'ME-17320' 'JO-15145' 'LS-17230'
#  'VS-21820' 'MS-17830' 'AJ-10780' 'SV-20365' 'CS-12250' 'BD-11605'
#  'MM-17920' 'ND-18370' 'BS-11590' 'EH-13990' 'DL-13315' 'DW-13195'
#  'TS-21340' 'XP-21865' 'MV-17485' 'MM-18280' 'HL-15040' 'TB-21400'
#  'SG-20605' 'IM-15055' 'SD-20485' 'CA-11965' 'EJ-13720' 'JC-15340'
#  'MV-18190' 'LC-17050' 'BD-11500' 'EB-13930' 'CD-12790' 'DB-13270'
#  'MH-17440' 'ND-18460' 'CK-12760' 'NM-18445' 'GA-14725' 'NF-18385'
#  'SC-20095' 'ML-17395' 'ST-20530' 'BF-11020' 'MN-17935' 'AB-10015'
#  'TB-21595' 'LC-16930' 'SR-20740' 'TM-21010' 'SA-20830' 'MG-17875'
#  'JH-15430' 'JS-16030' 'VF-21715' 'DB-13060' 'SC-20380' 'HR-14770'
#  'GW-14605' 'KN-16705' 'NH-18610' 'AJ-10945' 'JS-15595' 'SC-20020'
#  'EJ-14155' 'AP-10720' 'CL-12565' 'AB-10150' 'CM-12715' 'NP-18685'
#  'KT-16480' 'SW-20275' 'RB-19435' 'FM-14215' 'CK-12205' 'KA-16525'
#  'CK-12325' 'DK-13225' 'NF-18475' 'JF-15295' 'RB-19465' 'AS-10240'
#  'QJ-19255' 'CP-12340' 'BN-11515' 'AZ-10750' 'SM-20320' 'SC-20050'
#  'EK-13795' 'MC-17605' 'KH-16690' 'GM-14440' 'CB-12025' 'TS-21205'
#  'BF-11275' 'CC-12685' 'VM-21835' 'BG-11740' 'PO-18865' 'MS-17710'
#  'CD-11920' 'CA-12265' 'CS-12505' 'JD-15895' 'DK-12835' 'CV-12295'
#  'DR-12940' 'MP-18175' 'MG-18145' 'MP-17470' 'NC-18340' 'Dl-13600'
#  'SG-20890' 'KM-16720' 'TG-21640' 'KB-16240' 'DD-13570' 'JO-15280'
#  'AA-10315' 'KH-16330' 'AH-10690' 'RD-19585' 'KE-16420' 'KB-16585'
#  'MZ-17515' 'PK-18910' 'JG-15805' 'RP-19855' 'GM-14695' 'RD-19900'
#  'TH-21550' 'FH-14275' 'SC-20260' 'GP-14740' 'AY-10555' 'PJ-19015'
#  'VM-21685' 'RS-19765' 'JM-15655' 'JS-15880' 'PC-19000' 'RA-19885'
#  'JK-15370' 'MM-18055' 'GM-14455' 'SE-20110' 'KN-16450' 'EH-13765'
#  'SV-20785' 'BF-11170' 'PS-18970' 'SP-20650' 'JL-15835' 'NF-18595'
#  'AG-10390' 'BP-11230' 'DB-13555' 'AA-10375' 'AH-10030' 'TS-21160'
#  'LB-16795' 'DA-13450' 'BT-11305' 'LC-16885' 'MH-17290' 'AG-10300'
#  'GB-14530' 'DS-13180' 'MY-18295' 'AI-10855' 'LA-16780' 'KH-16360'
#  'LL-16840' 'HG-14845' 'JM-16195' 'AR-10510' 'CS-11860' 'JS-15940'
#  'NC-18415' 'AA-10480' 'BS-11365' 'PM-18940' 'GD-14590' 'EB-13870'
#  'PF-19120' 'SN-20710' 'HP-14815' 'CT-11995' 'SB-20290' 'PG-18820'
#  'GM-14680' 'AF-10885' 'VW-21775' 'RM-19375' 'BG-11695' 'HD-14785'
#  'PG-18895' 'EH-14005' 'AG-10270' 'NP-18325' 'AJ-10795' 'CC-12475'
#  'PW-19030' 'PA-19060' 'GA-14515' 'TT-21070' 'BS-11755' 'TD-20995'
#  'JH-15820' 'RF-19345' 'MC-17590' 'BT-11530' 'MW-18235' 'FG-14260'
#  'EH-14185' 'GT-14710' 'RP-19390' 'JL-15235' 'BW-11065' 'HF-14995'
#  'Dp-13240' 'MH-17785' 'LE-16810' 'PJ-18835' 'MM-17260' 'LW-16825'
#  'EB-13840' 'MC-17425' 'SS-20410' 'JG-15160' 'JK-15625' 'DW-13480'
#  'CR-12625' 'LT-17110' 'RE-19450' 'SC-20725' 'RB-19795' 'BT-11440'
#  'SB-20170' 'GT-14635' 'VT-21700' 'BM-11785' 'NR-18550' 'BP-11095'
#  'RD-19480' 'CS-11950' 'BH-11710' 'CW-11905' 'CM-12445' 'FO-14305'
#  'HK-14890' 'SR-20425' 'PS-18760' 'KL-16555' 'SC-20575' 'JF-15415'
#  'GH-14425' 'DB-13660' 'MC-18100' 'Co-12640' 'NW-18400' 'TB-21280'
#  'DV-13465' 'AA-10645' 'JE-15745' 'BS-11665' 'DL-13330' 'LP-17080'
#  'GK-14620' 'NS-18640' 'LM-17065' 'RW-19630' 'CA-12775' 'DL-12865'
#  'AR-10825' 'MS-17980' 'BD-11620' 'RA-19915' 'HA-14905' 'EH-13945'
#  'MS-17770' 'DM-13525' 'MC-17845' 'DC-12850' 'DP-13390' 'EP-13915'
#  'BC-11125' 'MH-18025' 'EB-13705' 'GH-14410' 'BM-11650' 'DS-13030'
#  'MH-17455' 'JK-15205' 'ME-17725' 'AC-10420' 'PV-18985' 'SS-20515'
#  'PB-19150' 'AW-10930' 'BF-10975' 'AH-10120' 'JL-15130' 'CA-12310'
#  'EM-14140' 'SW-20245' 'KM-16375' 'CC-12145' 'RD-19720' 'HM-14860'
#  'ME-18010' 'EM-14065' 'AB-10255' 'JL-15850' 'NC-18535' 'AG-10900'
#  'KL-16645' 'SG-20470' 'LF-17185' 'CL-11890' 'AS-10045' 'BB-10990'
#  'TS-21430' 'IL-15100' 'AS-10630' 'NZ-18565' 'BK-11260' 'VD-21670'
#  'SS-20590' 'RS-19420' 'GZ-14470' 'CS-12130' 'RF-19735' 'TB-21625'
#  'MA-17560' 'LR-16915' 'VG-21790' 'MB-17305' 'AG-10525' 'MG-17650'
#  'GM-14500' 'JH-15985' 'ED-13885' 'BW-11200' 'DH-13675' 'CS-12175'
#  'CS-12355' 'KH-16510' 'TS-21610' 'DJ-13510' 'LH-16900' 'CR-12730'
#  'DE-13255' 'JP-15520' 'AP-10915' 'RH-19495' 'RB-19645' 'JP-15460'
#  'DW-13585' 'MW-18220' 'JM-15265' 'JE-15715' 'RC-19960' 'PP-18955'
#  'KB-16315' 'FM-14290' 'ZD-21925' 'CC-12610' 'RA-19945' 'HH-15010'
#  'AT-10735' 'SJ-20500' 'LT-16765' 'KD-16345' 'MR-17545' 'PR-18880'
#  'NP-18700' 'VP-21760' 'SZ-20035' 'DK-13375' 'LR-17035' 'BM-11140'
#  'MC-17275' 'LH-17020' 'KT-16465' 'KC-16255' 'SP-20620' 'LC-17140'
#  'MS-17365' 'CC-12220' 'RR-19525' 'DL-12925' 'SF-20065' 'LW-17125'
#  'BN-11470' 'TA-21385' 'LW-17215' 'PT-19090' 'ON-18715' 'JM-15535'
#  'EA-14035' 'JB-15400' 'DM-13015' 'JC-15775' 'AJ-10960' 'MF-18250'
#  'JA-15970' 'AG-10765' 'MC-18130' 'JK-15640' 'FA-14230' 'SB-20185'
#  'DN-13690' 'HG-14965' 'PF-19165' 'ES-14020' 'MA-17995' 'JG-15115'
#  'SL-20155' 'LH-16750' 'VG-21805' 'AS-10090' 'TT-21220' 'JP-16135'
#  'TH-21115' 'JD-16060' 'BF-11005' 'MT-18070' 'KF-16285' 'NB-18580'
#  'CS-12400' 'TH-21100' 'KD-16495' 'GZ-14545' 'LD-17005' 'SM-20950'
#  'EB-14170' 'DB-13615' 'KW-16570' 'DM-12955' 'ES-14080' 'DO-13435'
#  'BP-11290' 'RD-19930' 'AR-10405' 'JD-16015' 'DF-13135' 'BD-11635'
#  'AM-10360' 'FC-14335' 'TN-21040' 'JF-15565' 'HA-14920' 'BP-11050'
#  'ZC-21910' 'SP-20545' 'TC-21295' 'JE-15610' 'HG-15025' 'AC-10660'
#  'LS-17245' 'TB-21520' 'IG-15085' 'LS-17200' 'AS-10225' 'EH-14125'
#  'JF-15490' 'RP-19270' 'LS-16975' 'FH-14365' 'SF-20965' 'MG-17680'
#  'DB-12910' 'AH-10585' 'RD-19810' 'TS-21370' 'BT-11395' 'NC-18625'
#  'GG-14650' 'AM-10705' 'AC-10450' 'NL-18310' 'KH-16630' 'PL-18925'
#  'DG-13300' 'PO-18850' 'SW-20755' 'SH-20395' 'JK-16120' 'DM-13345'
#  'TC-21535' 'WB-21850' 'TH-21235' 'MS-17530' 'BG-11035' 'MD-17350'
#  'TC-20980' 'BF-11215' 'TZ-21580' 'KD-16270' 'PK-19075' 'DB-12970'
#  'RF-19840' 'JL-15505' 'CM-11815' 'RM-19675' 'ML-17410' 'PB-19105'
#  'JF-15190' 'AB-10165' 'RH-19510' 'JD-16150' 'AH-10075' 'RB-19330'
#  'YC-21895' 'JK-15730' 'MK-17905' 'PW-19240' 'AB-10600' 'JC-16105'
#  'GR-14560' 'JM-15865' 'AD-10180' 'DB-13360' 'DH-13075' 'SC-20680'
#  'JK-15325' 'SP-20920' 'TC-21475' 'PB-19210' 'SS-20140' 'SM-20005'
#  'HR-14830' 'DK-12985' 'NG-18430' 'NG-18355' 'AT-10435' 'AR-10540'
#  'BT-11680' 'MO-17500' 'MC-17635' 'BF-11080' 'AH-10210' 'BS-11380'
#  'TR-21325' 'DP-13165' 'EM-13825' 'MC-17575' 'MD-17860' 'KN-16390'
#  'CP-12085' 'RL-19615' 'JB-15925' 'DK-13150' 'NB-18655' 'RC-19825'
#  'FP-14320' 'TB-21250' 'DJ-13420' 'TB-21175' 'SH-19975' 'CY-12745'
#  'LH-17155' 'RA-19285' 'KC-16675' 'SS-20875' 'CS-11845' 'SP-20860'
#  'SC-20305' 'SC-20695' 'CC-12100' 'SH-20635' 'EC-14050' 'MK-18160'
#  'IM-15070' 'TS-21505' 'AB-10105' 'PS-19045' 'KM-16660' 'TW-21025'
#  'SF-20200' 'CC-12670' 'CK-12595' 'MG-17695' 'TB-21190' 'RE-19405'
#  'MG-17890' 'DC-13285' 'MF-17665' 'AR-10345' 'KB-16600' 'PC-18745'
#  'JL-15175' 'CB-12535' 'AH-10465' 'AG-10495' 'CS-12490' 'YS-21880'
#  'KS-16300' 'CR-12820' 'RW-19540' 'LO-17170' 'TS-21655' 'SJ-20215'
#  'GT-14755' 'LC-16960' 'NP-18670' 'TP-21565' 'DK-13090' 'AH-10195'
#  'JJ-15445' 'DK-12895' 'TG-21310' 'EB-13750' 'CM-12385' 'JE-15475'
#  'JO-15550' 'CM-12655' 'BW-11110' 'JW-16075' 'DB-13210' 'FW-14395'
#  'BP-11185' 'BV-11245' 'CM-12115' 'JD-15790' 'MO-17950' 'RD-19660'
#  'EB-14110' 'HJ-14875' 'AW-10840' 'TP-21130' 'MP-17965' 'OT-18730'
#  'JK-16090' 'LS-16945' 'JW-15220' 'DB-13120' 'LC-16870' 'JB-16045'
#  'SV-20815' 'AG-10675' 'RO-19780' 'JH-16180' 'NK-18490' 'EN-13780'
#  'BD-11560' 'BD-11320' 'ML-18265' 'CG-12040' 'BP-11155' 'BB-11545'
#  'EM-13810' 'MJ-17740' 'GB-14575' 'JH-15910' 'FC-14245' 'SN-20560'
#  'SC-20770' 'SW-20455' 'CH-12070' 'RH-19600' 'BD-11725' 'VP-21730'
#  'KM-16225' 'FM-14380' 'VB-21745' 'TS-21085' 'RK-19300' 'BE-11455'
#  'EM-14095' 'PN-18775' 'DB-13405' 'PO-19180' 'TT-21265' 'JW-15955'
#  'SC-20440' 'RB-19705' 'DP-13105' 'FH-14350' 'KW-16435' 'CA-12055'
#  'CC-12430' 'NM-18520' 'BO-11425' 'KD-16615' 'BM-11575' 'AC-10615'
#  'MO-17800' 'JR-16210' 'CM-12190' 'AB-10060' 'SJ-20125' 'CM-11935'
#  'DR-12880' 'BS-11800' 'HW-14935' 'EM-13960' 'HM-14980' 'JJ-15760'
#  'GH-14485' 'SO-20335' 'CG-12520' 'JF-15355' 'MY-17380' 'SG-20080'
#  'KC-16540' 'EG-13900' 'CB-12415' 'MT-17815' 'DO-13645' 'MZ-17335'
#  'GH-14665' 'KB-16405' 'PB-18805' 'TP-21415' 'RH-19555' 'MH-17620'
#  'SU-20665' 'AF-10870' 'TT-21460' 'SC-20800' 'DJ-13630' 'PM-19135'
#  'EM-14200' 'ER-13855' 'JR-15670' 'DL-13495' 'BT-11485' 'BO-11350'
#  'EB-13975' 'JB-16000' 'BE-11335' 'TB-21355' 'HE-14800' 'BE-11410'
#  'DW-13540' 'JG-15310' 'CJ-12010' 'BD-11770' 'HZ-14950' 'SV-20935'
#  'JM-15250' 'RB-19360' 'SW-20350' 'JM-15580' 'CR-12580' 'EL-13735'
#  'CL-12700' 'RB-19570' 'CM-12235' 'SM-20905' 'LW-16990' 'CV-12805'
#  'AS-10285' 'CC-12370' 'RW-19690' 'SC-20230' 'LP-17095' 'RS-19870'
#  'DV-13045' 'JS-15685' 'TB-21055' 'LD-16855' 'PF-19225' 'AR-10570'
#  'LB-16735' 'AG-10330' 'ML-17755' 'AO-10810' 'MH-18115' 'CM-12160'
#  'SC-20845' 'AS-10135' 'RR-19315' 'NS-18505' 'CD-11980' 'SK-19990'
#  'JE-16165' 'CJ-11875' 'RM-19750' 'ML-18040' 'TM-21490' 'MG-18205'
#  'CC-12550' 'CS-12460' 'JC-15385' 'TC-21145' 'PH-18790' 'JR-15700'
#  'CD-12280']
#
# Unique values for Customer Name:
# ['Darren Powers' 'Phillina Ober' 'Mick Brown' 'Maria Etezadi'
#  "Jack O'Briant" 'Lycoris Saunders' 'Vivek Sundaresam' 'Melanie Seite'
#  'Anthony Jacobs' 'Seth Vernon' 'Chris Selesnick' 'Brian Dahlen'
#  'Michael Moore' 'Natalie DeCherney' 'Brendan Sweed' 'Erica Hackney'
#  'Delfina Latchford' 'David Wiener' 'Toby Swindell' 'Xylona Preis'
#  'Mark Van Huff' 'Muhammed MacIntyre' 'Hunter Lopez' 'Tom Boeckenhauer'
#  'Speros Goranitis' 'Ionia McGrath' 'Shirley Daniels' 'Carol Adams'
#  'Ed Jacobs' 'Jasper Cacioppo' 'Mike Vittorini' 'Liz Carlisle'
#  'Bradley Drucker' 'Eric Barreto' 'Cynthia Delaney' 'Deborah Brumfield'
#  'Mark Haberlin' 'Neil Ducich' 'Cyma Kinney' 'Nathan Mautz'
#  'Guy Armstrong' 'Natalie Fritzler' 'Sanjit Chand' 'Marina Lichtenstein'
#  'Shui Tom' 'Barry Französisch' 'Michael Nguyen' 'Aaron Bergman'
#  'Troy Blackwell' 'Linda Cazamias' 'Steven Roelle' 'Tamara Manning'
#  'Sue Ann Reed' 'Michael Grace' 'Jennifer Halladay' 'Joy Smith'
#  'Vicky Freymann' 'Dave Brooks' 'Shahid Collister' 'Hallie Redmond'
#  'Giulietta Weimer' 'Kristina Nunn' 'Nicole Hansen' 'Ashley Jarboe'
#  'Jill Stevenson' 'Sam Craven' 'Eva Jacobs' 'Anne Pryor' 'Clay Ludtke'
#  'Aimee Bixby' 'Craig Molinari' 'Nora Pelletier' 'Kean Thornton'
#  'Scott Williamson' 'Richard Bierner' 'Filia McAdams'
#  'Chloris Kastensmidt' 'Kelly Andreada' 'Christine Kargatis' 'Dean Katz'
#  'Neil Französisch' 'Jason Fortune-' 'Rick Bensley' 'Alan Shonely'
#  'Quincy Jones' 'Christine Phan' 'Bradley Nguyen' 'Annie Zypern'
#  'Sean Miller' 'Sample Company A' 'Eileen Kiefer' 'Matt Connell'
#  'Kristen Hastings' 'Gary McGarr' 'Cassandra Brandow' 'Thomas Seio'
#  'Beth Fritzler' 'Craig Carroll' 'Vivian Mathis' 'Bruce Geld'
#  "Patrick O'Donnell" 'Maurice Satty' 'Carlos Daly' 'Christina Anderson'
#  'Cindy Stewart' 'Jonathan Doherty' 'Damala Kotsonis'
#  'Christina VanderZanden' 'Daniel Raglin' 'Mike Pelletier'
#  'Mike Gockenbach' 'Mark Packer' 'Nat Carroll' 'Dorris liebe'
#  'Susan Gilcrest' 'Kunst Miller' 'Trudy Glocke' 'Karen Bern'
#  'Dorothy Dickinson' "Jas O'Carroll" 'Alex Avila' 'Katharine Harms'
#  'Anna Häberlin' 'Rob Dowd' 'Katrina Edelman' 'Ken Black' 'Mary Zewe'
#  'Paul Knutson' 'John Grady' 'Roy Phan' 'Greg Maxwell' 'Ruben Dartt'
#  'Tracy Hopkins' 'Frank Hawley' 'Scott Cohen' 'Guy Phonely' 'Andy Yotov'
#  'Pauline Johnson' 'Valerie Mitchum' 'Roland Schwarz' 'Jim Mitchum'
#  'John Stevenson' 'Pauline Chand' 'Ruben Ausman' 'Jay Kimmel'
#  'Michelle Moray' 'Gary Mitchum' 'Sanjit Engle' 'Kean Nguyen'
#  'Edward Hooks' 'Stewart Visinsky' 'Ben Ferrer' 'Paul Stevenson'
#  'Stephanie Phelps' 'John Lee' 'Nicole Fjeld' 'Allen Goldenen'
#  'Benjamin Patterson' 'Dorothy Badders' 'Allen Armold' 'Aaron Hawkins'
#  'Theresa Swint' 'Laurel Beltran' 'Dianna Arnett' 'Beth Thompson'
#  'Lena Creighton' 'Marc Harrigan' 'Aleksandra Gannaway' 'George Bell'
#  'David Smith' 'Muhammed Yedwab' 'Arianne Irving' 'Laura Armstrong'
#  'Katherine Hughes' 'Lauren Leatherbury' 'Harry Greene'
#  'Justin MacKendrick' 'Andrew Roberts' 'Cari Schnelling' 'Joni Sundaresam'
#  'Nathan Cano' 'Andrew Allen' 'Bill Shonely' 'Paul MacIntyre'
#  'Giulietta Dortch' 'Emily Burns' 'Peter Fuller' 'Steve Nguyen'
#  'Harold Pawlan' 'Carol Triggs' 'Sean Braxton' 'Patrick Gardner'
#  'Greg Matthias' 'Art Foster' 'Victoria Wilson' 'Raymond Messe'
#  'Brooke Gillingham' 'Harold Dahlen' 'Paul Gonzalez' 'Erica Hernandez'
#  'Alejandro Grove' 'Naresj Patel' 'Anthony Johnson' 'Cindy Chapman'
#  'Pauline Webber' 'Pete Armstrong' 'George Ashbrook' 'Ted Trevino'
#  'Bruce Stewart' 'Tamara Dahlen' 'John Huston' 'Randy Ferguson'
#  'Matt Collister' 'Bradley Talbott' 'Mitch Willingham' 'Frank Gastineau'
#  'Evan Henry' 'Greg Tran' 'Resi Pölking' 'Janet Lee' 'Barry Weirich'
#  'Herbert Flentye' 'Dean percer' 'Maya Herman' 'Laurel Elliston'
#  'Patrick Jones' 'Magdelene Morse' 'Laurel Workman' 'Ellis Ballard'
#  'Mark Cousins' 'Shahid Shariari' 'James Galang' 'Jim Karlsson'
#  'Dianna Wilson' 'Corey Roper' 'Liz Thompson' 'Richard Eichhorn'
#  'Steven Cartwright' 'Ross Baird' 'Bobby Trafton' 'Sarah Bern'
#  'Grant Thornton' 'Valerie Takahito' 'Bryan Mills' 'Nick Radford'
#  'Bart Pistole' 'Rick Duston' 'Carlos Soltero' 'Brosina Hoffman'
#  'Carl Weiss' 'Chuck Magee' 'Frank Olsen' 'Heather Kirkland'
#  'Sharelle Roach' 'Pamela Stobb' 'Kelly Lampkin' 'Sonia Cooley'
#  'Jennifer Ferguson' 'Gary Hwang' 'Duane Benoit' 'Mick Crebagga'
#  'Corey-Lock' 'Natalie Webber' 'Toby Braunhardt' 'Dianna Vittorini'
#  'Anna Andreadi' 'Joel Eaton' 'Brian Stugart' 'Denise Leinenbach'
#  'Liz Pelletier' 'Grace Kelly' 'Noel Staavos' 'Liz MacKendrick'
#  'Rob Williams' 'Cynthia Arntzen' 'Dan Lawera' 'Anthony Rawles'
#  'Michael Stewart' 'Brian DeCherney' 'Russell Applegate' 'Helen Abelman'
#  'Eric Hoffmann' 'Maxwell Schwartz' 'Don Miller' 'Michael Chen'
#  'Dan Campbell' 'Dennis Pardue' 'Emily Phan' 'Becky Castell'
#  'Michelle Huthwaite' 'Ed Braxton' 'Gary Hansen' 'Brian Moss'
#  'Darrin Sayre' 'Mark Hamilton' 'Jamie Kunitz' 'Max Engle' 'Alyssa Crouse'
#  'Paul Van Hugh' 'Shirley Schmidt' 'Philip Brown' 'Arthur Wiediger'
#  'Barbara Fisher' 'Adrian Hane' 'Jack Lebron' 'Christine Abelman'
#  'Eugene Moren' 'Scot Wooten' 'Katherine Murray' 'Charles Crestani'
#  'Roger Demir' 'Harry Marie' 'Michelle Ellison' 'Erin Mull'
#  'Alejandro Ballentine' 'John Lucas' 'Nick Crebassa' 'Arthur Gainer'
#  'Ken Lonsdale' 'Sheri Gordon' 'Luke Foster' 'Carl Ludwig'
#  'Aaron Smayling' 'Barry Blumstein' 'Tom Stivers' 'Ivan Liston'
#  'Ann Steele' 'Nick Zandusky' 'Berenike Kampe' 'Valerie Dominguez'
#  'Sonia Sunley' 'Ricardo Sperren' 'Gary Zandusky' 'Chad Sievert'
#  'Roland Fjeld' 'Trudy Brown' 'Matt Abelman' 'Lena Radford'
#  'Vivek Gonzalez' 'Maria Bertelson' 'Andy Gerbode' 'Matthew Grinstein'
#  'Gene McClure' 'Joseph Holt' 'Emily Ducich' 'Ben Wallace' 'Duane Huffman'
#  'Charles Sheldon' 'Christine Sundaresam' 'Keith Herrera' 'Troy Staebel'
#  'Don Jones' 'Lena Hernandez' 'Craig Reiter' 'Deanra Eno' 'Jeremy Pistek'
#  'Arthur Prichep' 'Rick Hansen' 'Robert Barroso' 'Jennifer Patt'
#  'Dorothy Wardle' 'Mitch Webber' 'Janet Molinari' 'Joe Elijah'
#  'Ryan Crowe' 'Paul Prost' 'Karl Braun' 'Frank Merwin'
#  'Zuschuss Donatelli' 'Corey Catlett' 'Ryan Akin' 'Hilary Holden'
#  'Annie Thurman' 'Shirley Jackson' 'Larry Tron' 'Katherine Ducich'
#  'Mathew Reese' 'Patrick Ryan' 'Nora Preis' 'Victoria Pisteka'
#  'Sam Zeldin' 'Dennis Kane' 'Lisa Ryan' 'Becky Martin' 'Marc Crier'
#  'Lisa Hazard' 'Kean Takahito' 'Karen Carlisle' 'Stefania Perrino'
#  'Logan Currie' 'Maribeth Schnelling' 'Chris Cortes' 'Rick Reed'
#  'Daniel Lacy' 'Sandra Flanagan' 'Liz Willingham' 'Brad Norvell'
#  'Tom Ashbrook' 'Luke Weiss' 'Pete Takahito' 'Odella Nelson'
#  'Jessica Myrick' 'Erin Ashbrook' 'Jennifer Braxton' 'Darrin Martin'
#  'John Castell' 'Astrea Jones' 'Monica Federle' 'Joseph Airdo'
#  'Anthony Garverick' 'Mike Caudle' 'Jim Kriz' 'Frank Atkinson'
#  'Sarah Brown' 'Duane Noonan' 'Henry Goldwyn' 'Philip Fox' 'Erica Smith'
#  'Michelle Arnett' 'Jack Garza' 'Sara Luxemburg' 'Larry Hughes'
#  'Vivek Grady' 'Adam Shillingsburg' 'Thomas Thornton' 'Julie Prescott'
#  'Thea Hudgings' 'Julia Dunbar' 'Barry Franz' 'Michelle Tran'
#  'Karen Ferguson' 'Nicole Brennan' 'Christopher Schild' 'Thea Hendricks'
#  'Keith Dawkins' 'George Zrebassa' 'Lisa DeCherney' 'Suzanne McNair'
#  'Evan Bailliet' 'Doug Bickford' 'Kelly Williams' 'Dario Medina'
#  'Erin Smith' 'Denny Ordway' 'Beth Paige' "Russell D'Ascenzo"
#  'Allen Rosenblatt' 'Joy Daniels' 'David Flashing' 'Brian Derr'
#  'Alice McCarthy' 'Fred Chung' 'Tanja Norvell' 'Jill Fjeld'
#  'Helen Andreada' 'Barry Pond' 'Zuschuss Carroll' 'Sibella Parks'
#  'Toby Carlisle' 'Jim Epp' 'Hunter Glantz' 'Anna Chung' 'Lynn Smith'
#  'Tracy Blumstein' 'Ivan Gibson' 'Luke Schmidt' 'Alan Schoenberger'
#  'Eugene Hildebrand' 'Jeremy Farry' 'Rachel Payne' 'Lindsay Shagiari'
#  'Fred Hopkins' 'Sylvia Foulston' 'Maureen Gastineau' 'Daniel Byrd'
#  'Angele Hood' 'Ross DeVincentis' 'Todd Sumrall' 'Bill Tyler'
#  'Noah Childs' 'Greg Guthrie' 'Anne McFarland' 'Amy Cox' 'Nancy Lomonaco'
#  'Ken Heidel' 'Paul Lucas' 'Deirdre Greer' "Patrick O'Brill" 'Steven Ward'
#  'Shahid Hopkins' 'Julie Kriz' 'Denise Monton' 'Tracy Collins'
#  'William Brown' 'Tiffany House' 'MaryBeth Skach' 'Barry Gonzalez'
#  'Maribeth Dona' 'Tamara Chand' 'Benjamin Farhat' 'Tracy Zic'
#  'Karen Daniels' 'Pete Kriz' 'Darren Budd' 'Roy Französisch'
#  'Jeremy Lonsdale' 'Candace McMahon' 'Robert Marley' 'Maris LaWare'
#  'Peter Bühler' 'Jamie Frazer' 'Alan Barnes' 'Rick Huthwaite'
#  'Justin Deggeller' 'Adam Hart' 'Randy Bradley' 'Yoseph Carroll'
#  'Joe Kamberova' 'Michael Kennedy' 'Pierre Wener' 'Ann Blume'
#  'Julie Creighton' 'Georgia Rosenberg' 'John Murray' 'Alan Dominguez'
#  'Dennis Bolton' 'Dave Hallsten' 'Steve Carroll' 'Jason Klamczynski'
#  'Susan Pistek' 'Tony Chapman' 'Phillip Breyer' 'Saphhira Shifley'
#  'Sally Matthias' 'Harold Ryan' 'Darren Koutras' 'Nathan Gelder'
#  'Nat Gilpin' 'Alyssa Tate' 'Andy Reiter' 'Brian Thompson' "Mary O'Rourke"
#  'Matthew Clasen' 'Bart Folk' 'Alan Hwang' 'Bill Stewart' 'Toby Ritter'
#  'David Philippe' 'Elizabeth Moffitt' 'Matt Collins' 'Michael Dominguez'
#  'Katherine Nockton' 'Cathy Prescott' 'Rob Lucas' 'Joni Blumstein'
#  'David Kendrick' 'Nona Balk' 'Roy Collins' 'Frank Preis' 'Tim Brockman'
#  'Denny Joy' 'Thomas Boland' 'Sally Hughsby' 'Craig Yedwab'
#  'Logan Haushalter' 'Ralph Arnett' 'Kimberly Carter' 'Sung Shariari'
#  'Cari Sayre' 'Sung Pak' 'Sean Christensen' 'Steve Chapman'
#  'Chad Cunningham' 'Stefanie Holloman' 'Erin Creighton' 'Mike Kennedy'
#  'Irene Maddox' 'Tony Sayre' 'Adrian Barton' 'Penelope Sewall'
#  'Khloe Miller' 'Tamara Willingham' 'Sarah Foster' 'Craig Carreira'
#  'Clytie Kelty' 'Maureen Gnade' 'Thomas Brumley' 'Ricardo Emerson'
#  'Michael Granlund' 'Debra Catini' 'Maureen Fritzler' 'Alex Russell'
#  'Ken Brennan' 'Pamela Coakley' 'James Lanier' 'Claudia Bergmann'
#  'Amy Hunt' 'Andrew Gjertsen' 'Cindy Schnelling' 'Yana Sorensen'
#  'Karen Seio' 'Cyra Reiten' 'Rick Wilson' 'Lori Olson' 'Trudy Schmidt'
#  'Sarah Jordon' 'Guy Thornton' 'Lindsay Castell' 'Nora Paige'
#  'Tracy Poddar' 'Dave Kipp' 'Alan Haines' 'Jennifer Jackson' 'Dana Kaydos'
#  'Toby Gnade' 'Edward Becker' 'Christopher Martinez' 'Jeremy Ellison'
#  'Jesus Ocampo' 'Corinna Mitchell' 'Bart Watters' 'Julia West'
#  'Dean Braden' 'Fred Wasserman' 'Ben Peterman' 'Benjamin Venier'
#  'Chad McGuire' 'John Dryer' 'Michael Oakman' 'Robert Dilbeck'
#  'Eugene Barchas' 'Heather Jas' 'Anthony Witt' 'Theone Pippenger'
#  'Michael Paige' 'Olvera Toch' 'Juliana Krohn' 'Linda Southworth'
#  'Jane Waco' 'David Bremer' 'Lena Cacioppo' 'Julia Barnett' 'Stuart Van'
#  'Anna Gayman' "Rose O'Brian" 'Justin Hirsh' 'Neil Knudson'
#  'Edward Nazzal' 'Brendan Dodson' 'Bill Donatelli' 'Muhammed Lee'
#  'Catherine Glotzbach' 'Becky Pak' 'Brenda Bowman' 'Eleni McCrary'
#  'Max Jones' 'Giulietta Baptist' 'Jonathan Howell' 'Frank Carlisle'
#  'Skye Norling' 'Stewart Carmichael' 'Shaun Weien' 'Cathy Hwang'
#  'Rob Haberlin' 'Bruce Degenhardt' 'Victor Preis' 'Kalyca Meade'
#  'Fred McMath' 'Victoria Brennan' 'Thais Sissman' 'Ralph Kennedy'
#  'Brad Eason' 'Eudokia Martin' 'Parhena Norris' 'Denny Blanton'
#  'Philisse Overcash' 'Tim Taslimi' 'Joni Wasserman' 'Shaun Chance'
#  'Roger Barcio' 'Dave Poirier' 'Fred Harton' 'Katrina Willman'
#  'Cathy Armstrong' 'Chuck Clark' 'Neoma Murray' 'Bobby Odegard' 'Ken Dana'
#  'Brendan Murry' 'Ann Chong' "Meg O'Connel" 'Justin Ritter'
#  'Charlotte Melton' 'Adam Bellavance' 'Sanjit Jacobs' 'Carlos Meador'
#  'Dan Reichenbach' 'Bryan Spruell' 'Helen Wasserman' 'Eric Murdock'
#  'Henry MacAllister' 'Joel Jenkins' 'Gene Hale' "Sean O'Donnell"
#  'Claire Gute' 'Jay Fein' 'Maribeth Yedwab' 'Sandra Glassco'
#  'Kelly Collister' 'Emily Grady' 'Christy Brittain' 'Meg Tillman'
#  "Doug O'Connell" 'Maria Zettner' 'Greg Hansen' 'Katrina Bavinger'
#  'Patrick Bzostek' 'Tom Prescott' 'Ritsa Hightower' 'Matt Hagelstein'
#  'Stephanie Ulpright' 'Art Ferguson' 'Tonja Turnell' 'Stuart Calhoun'
#  'Doug Jacobs' 'Peter McVee' 'Evan Minnotte' 'Elpida Rittenbach'
#  'Jim Radford' 'Dionis Lloyd' 'Brad Thomas' 'Bill Overfelt' 'Erica Bern'
#  'Joy Bell-' 'Bill Eplett' 'Todd Boyes' 'Harold Engle' 'Bobby Elias'
#  'Don Weiss' 'Jason Gross' 'Caroline Jumper' 'Bryan Davis' 'Henia Zydlo'
#  'Susan Vittorini' 'Janet Martin' 'Raymond Buch' 'Sean Wendt'
#  'Jill Matthias' 'Clay Rozendal' 'Ed Ludwig' 'Craig Leslie' 'Rob Beeghly'
#  'Chris McAfee' 'Susan MacKendrick' 'Lindsay Williams' 'Cynthia Voltz'
#  'Alejandro Savely' 'Christopher Conant' 'Robert Waldorf' 'Scot Coram'
#  'Liz Preis' 'Roy Skaria' 'Darrin Van Huff' 'Jim Sink' 'Ted Butterfield'
#  'Lela Donovan' 'Phillip Flathmann' 'Anemone Ratner' 'Larry Blacks'
#  'Alex Grayson' 'Max Ludwig' "Anthony O'Donnell" 'Mick Hernandez'
#  'Charles McCrossin' 'Sung Chung' 'Adrian Shami' 'Ralph Ritter'
#  'Neola Schneider' 'Carol Darley' 'Sally Knutson' 'Justin Ellison'
#  'Carl Jackson' 'Roland Murray' 'Michelle Lonsdale' 'Tony Molinari'
#  'Mitch Gastineau' 'Clay Cheatham' 'Chuck Sachs' 'Jenna Caffey'
#  'Theresa Coyne' 'Patricia Hirasaki' 'Jocasta Rupert' 'Christina DeMoss']
#
# Unique values for Segment:
# ['Consumer' 'Home Office' 'Corporate']
#
# Unique values for Country:
# ['United States']
#
# Unique values for City:
# ['Houston' 'Naperville' 'Philadelphia' 'Henderson' 'Athens' 'Los Angeles'
#  'Huntsville' 'Laredo' 'Springfield' 'Dover' 'Bossier City'
#  'San Francisco' 'Newark' 'Mount Pleasant' 'Roswell' 'Scottsdale'
#  'Westland' 'Smyrna' 'Jonesboro' 'Miami' 'Lafayette' 'Las Vegas'
#  'Alexandria' 'Rapid City' 'San Diego' 'New York City' 'Detroit'
#  'Mission Viejo' 'Green Bay' 'Saint Petersburg' 'Seattle' 'Escondido'
#  'Chesapeake' 'Romeoville' 'Linden' 'North Las Vegas' 'Columbia' 'Concord'
#  'Dallas' 'Chicago' 'Arlington' 'Lubbock' 'Richmond' 'Woodstock'
#  'Moreno Valley' 'El Paso' 'Medford' 'Columbus' 'Elmhurst' 'Wilmington'
#  'Margate' 'Yonkers' 'Des Moines' 'Denver' 'Royal Oak' 'Roseville'
#  'Huntington Beach' 'Jacksonville' 'Logan' 'Tampa' 'Raleigh' 'Jackson'
#  'Lakeville' 'Burbank' 'Lakeland' 'Knoxville' 'Hamilton' 'Asheville'
#  'Tucson' 'Greensboro' 'Portage' 'Delray Beach' 'Fresno' 'Pomona'
#  'Albuquerque' 'Plano' 'Brownsville' 'Apple Valley' 'Long Beach' 'Vallejo'
#  'Revere' 'Virginia Beach' 'Decatur' 'Dearborn Heights' 'Lancaster'
#  'Mobile' 'Marietta' 'Glendale' 'Toledo' 'Chandler' 'Great Falls' 'Austin'
#  'Lewiston' 'Redondo Beach' 'Lodi' 'Bloomington' 'Baltimore' 'San Jose'
#  'Troy' 'San Gabriel' 'Jamestown' 'Memphis' 'Rochester' 'Lake Charles'
#  'Louisville' 'Appleton' 'Middletown' 'Freeport' 'San Antonio' 'Lawrence'
#  'Kent' 'Watertown' 'Fort Worth' 'Franklin' 'Milwaukee' 'Hialeah'
#  'West Jordan' 'Oakland' 'Eau Claire' 'Akron' 'Cleveland' 'Midland'
#  'San Marcos' 'Bellevue' 'Murray' 'Buffalo Grove' 'Lakewood' 'Little Rock'
#  'Orem' 'Aurora' 'Peoria' 'Bristol' 'Harrisonburg' 'Hempstead' 'Mishawaka'
#  'Lawton' 'Pueblo' 'Meriden' 'Waynesboro' 'Phoenix' 'Minneapolis'
#  'Chester' 'Salem' 'Southaven' 'Cincinnati' 'Deltona' 'Plainfield'
#  'Palm Coast' 'El Cajon' 'Buffalo' 'Hackensack' 'Niagara Falls'
#  'League City' 'Sioux Falls' 'New Rochelle' 'Riverside' 'Omaha' 'Atlanta'
#  'Draper' 'Apopka' 'Charlotte' 'Bangor' 'Pleasant Grove' 'Texas City'
#  'Trenton' 'Vacaville' 'Hollywood' 'Fairfield' 'Hampton' 'Saint Charles'
#  'North Miami' 'Grand Rapids' 'Oceanside' 'Billings' 'Owensboro'
#  'Santa Fe' 'Fayetteville' 'Bowling Green' 'Tulsa' 'Oswego' 'Santa Clara'
#  'Pasco' 'Tyler' 'Macon' 'Lowell' 'Greenville' 'Clifton' 'Gresham'
#  'Oxnard' 'Cary' 'Olathe' 'Tempe' 'Odessa' 'Corpus Christi' 'Chula Vista'
#  'Garland' 'Boca Raton' 'Mesquite' 'Boynton Beach' 'Clarksville' 'Reno'
#  'Durham' 'Evanston' 'Indianapolis' 'Manteca' 'Pasadena' 'Edmonds'
#  'Mount Vernon' 'Everett' 'Parma' 'Beaumont' 'Texarkana' 'Montgomery'
#  'Newport News' 'Rancho Cucamonga' 'Fort Lauderdale' 'Rock Hill'
#  'Garden City' 'Cranston' 'Avondale' 'Lorain' 'Mason' 'Portland' 'Orange'
#  'Medina' 'Irving' 'Nashville' 'Wausau' 'Redding' 'Reading' 'Madison'
#  'Carrollton' 'Johnson City' 'Manhattan' 'Moorhead' 'Cedar Hill'
#  'Des Plaines' 'Provo' 'Monroe' 'Coon Rapids' 'Salt Lake City'
#  'Bolingbrook' 'Saint Louis' 'Sacramento' 'Brentwood' 'Woonsocket' 'Utica'
#  'Tigard' 'Skokie' 'Orlando' 'Clinton' 'Sandy Springs' 'Oklahoma City'
#  'Gilbert' 'Olympia' 'Mesa' 'Caldwell' 'Marion' 'Florence' 'Thornton'
#  'Grand Prairie' 'Port Arthur' 'Colorado Springs' 'Beverly' 'Anaheim'
#  'Cottage Grove' 'Taylor' 'Providence' 'Baytown' 'Woodbury' 'Bartlett'
#  'Park Ridge' 'Bozeman' 'West Palm Beach' 'Rome' 'Suffolk' 'Kenosha'
#  'Perth Amboy' 'Hot Springs' 'Las Cruces' 'Sterling Heights' 'Leominster'
#  'Altoona' 'Coppell' 'Bethlehem' 'New Castle' 'Plantation' 'Chico' 'Lehi'
#  'Auburn' 'San Bernardino' 'Thousand Oaks' 'Coral Springs' 'Covington'
#  'Normal' 'Lansing' 'Spokane' 'Norwich' 'Norfolk' 'Farmington' 'Mcallen'
#  'Santa Maria' 'New Albany' 'Daytona Beach' 'Washington' 'Tinley Park'
#  'Allen' 'Cuyahoga Falls' 'Camarillo' 'Wilson' 'Frankfort' 'Haltom City'
#  'Wichita' 'Manchester' 'Paterson' 'Pocatello' 'Layton' 'East Point'
#  'Carol Stream' 'Holyoke' 'Vineland' 'Amarillo' 'Port Saint Lucie'
#  'Bakersfield' 'South Bend' 'Highland Park' 'Hattiesburg' 'Kirkwood'
#  'Boise' 'Redmond' 'Eagan' 'Yucaipa' 'New Bedford' 'Allentown' 'Murrieta'
#  'Bedford' 'Holland' 'Charlottesville' 'La Quinta' 'Tamarac' 'Redlands'
#  'North Charleston' 'Lincoln Park' 'Quincy' 'Broken Arrow' 'Dubuque'
#  'Rockford' 'Murfreesboro' 'Bayonne' 'Cambridge' 'Rockville' 'Hillsboro'
#  'Warner Robins' 'Ann Arbor' 'Santa Barbara' 'Noblesville' 'Orland Park'
#  'Sparks' 'Salinas' 'Conway' 'Burlington' 'Lebanon' 'Helena' 'Rio Rancho'
#  'Frisco' 'Morristown' 'Pembroke Pines' 'Lake Elsinore' 'Champaign'
#  'Santa Ana' 'Dearborn' 'Tallahassee' 'Temecula' 'Costa Mesa' 'Glenview'
#  'Lindenhurst' 'Bullhead City' 'Superior' 'Dublin' 'Visalia' 'Missoula'
#  'Gaithersburg' 'Longview' 'Westfield' 'Gulfport' 'Atlantic City'
#  'Sierra Vista' 'Chattanooga' 'Belleville' 'La Crosse' 'Round Rock'
#  'Milford' 'Andover' 'Harlingen' 'Redwood City' 'Bryan' 'Malden'
#  'Littleton' 'Saint Peters' 'Norman' 'Grapevine' 'Gastonia'
#  'Jefferson City' 'San Clemente' 'Hesperia' 'Encinitas' 'Yuma' 'Waterbury'
#  'Warwick' 'Passaic' 'Parker' 'Longmont' 'York' 'Broomfield' 'Pensacola'
#  'Hendersonville' 'Kenner' 'West Allis' 'Davis' 'Edinburg' 'Fort Collins'
#  'Sheboygan' 'Pharr' 'Englewood' 'Waco' 'Waukesha' 'Georgetown'
#  'Cedar Rapids' 'Thomasville' 'Saint Paul' 'Wheeling' 'Stockton' 'Arvada'
#  'Twin Falls' 'Laguna Niguel' 'Marlborough' 'Woodland' 'Iowa City'
#  'La Porte' 'Lake Forest' 'Coral Gables' 'The Colony' 'Marysville'
#  'Bridgeton' 'San Luis Obispo' 'Conroe' 'Urbandale' 'Eugene' 'Cheyenne'
#  'Arlington Heights' 'Vancouver' 'Carlsbad' 'Edmond' 'Montebello'
#  'Shelton' 'Overland Park' 'East Orange' 'Hickory' 'San Angelo'
#  'Morgan Hill' 'Antioch' 'Richardson' 'Fremont' 'Greenwood' 'Homestead'
#  'Torrance' 'Goldsboro' 'Nashua' 'Deer Park' 'Tuscaloosa' 'Ormond Beach'
#  'Keller' 'Hoover' 'Muskogee' 'Rogers' 'Pompano Beach' 'Oak Park'
#  'New Brunswick' 'Greeley' 'Kissimmee' 'Sanford' 'Danville' 'Westminster'
#  'Mansfield' 'Fargo' 'Laurel' 'Bellingham' 'Missouri City' 'Pearland'
#  'Rochester Hills' 'Maple Grove' 'Chapel Hill' 'Commerce City'
#  'Citrus Heights' 'San Mateo' 'Pico Rivera' 'Waterloo' 'Elkhart'
#  'Loveland' 'Inglewood' 'La Mesa' 'Independence' 'Modesto' 'Clovis'
#  'Grand Island' 'Melbourne' 'Pine Bluff' 'Saint Cloud' 'Miramar' 'Mentor'
#  'Meridian' 'Springdale' 'Sunnyvale' 'Coachella' 'Aberdeen' 'Jupiter'
#  'Grove City' 'Elyria' 'Hagerstown' 'Saginaw' 'College Station' 'Ontario'
#  'Renton' 'Canton' 'Summerville' 'Gladstone' 'Whittier' 'Palatine'
#  'Abilene' 'Port Orange' 'Danbury']
#
# Unique values for State:
# ['Texas' 'Illinois' 'Pennsylvania' 'Kentucky' 'Georgia' 'California'
#  'Virginia' 'Delaware' 'Louisiana' 'Ohio' 'South Carolina' 'Oregon'
#  'Arizona' 'Michigan' 'Tennessee' 'Arkansas' 'Florida' 'Indiana' 'Nevada'
#  'South Dakota' 'New York' 'Wisconsin' 'Washington' 'New Jersey'
#  'Missouri' 'North Carolina' 'Colorado' 'Utah' 'Mississippi' 'Minnesota'
#  'Iowa' 'New Mexico' 'Massachusetts' 'Alabama' 'Montana' 'Idaho'
#  'Maryland' 'Connecticut' 'New Hampshire' 'Oklahoma' 'Nebraska' 'Maine'
#  'Kansas' 'Rhode Island' 'District of Columbia' 'Vermont' 'Wyoming'
#  'North Dakota' 'West Virginia']
#
# Unique values for Postal Code:
# [77095 60540 19143 42420 30605 90049 77340 78041 22153 19901 71111 94109
#  43055 29464 19140 30076 19134 97477 85254 48185 37167 72401 33180 47905
#  89115 22304 57701 92037 10024 48234 92691 54302 33710 98105 92024 92025
#  23320 60441  7036 89031 65203 94521 98103 75220 60653 76017 79424 47374
#  60098 92553 79907 97504 43229 60126 98115 10035 77036 10009 19120 28403
#  33063 29203 10701 98198 80219 48073 95661 40475 92646 32216 84321 33614
#  27604 39212 55044 75217 91505 94110 33801 37918 45011 28806 85705 27405
#  46368 33445 90036 93727 91767 94122 50315 87105 45503 75023 78521 55124
#  11561 60610 94591  2151 23464 90008 70506 48205 62521 48127 90004 17602
#  36608 30062 85301 43615 85224 35601 59405 78745 83501 90278 95240 47401
#  21215 95123 22204 77070 90045 12180 91776 14701 38109 14609 70601 40214
#  54915  6457 49201 61032 78207  1841 98031 13601 76106  2038 53209 33012
#  84084 94601 54703 44312 44105 48640  3820 78666 98006 60623 84107 92105
#  23223 60089  8701 72209 84057 60505 61604 37620 90032 22801 11550 46544
#  19711 73505 81001  6450 22980 85023 55407 19013 80027 28027 97301 38671
#  45231 10011 32725  7060 80013 32137 92020 14215  7601 14304 77573 57103
#  10801  6010 92503 68104 30318 84020 32712 28205 65807  4401 84062 77590
#  48183 95687 30188 33021 75081  6824 31907 23666 44107 63301 33161 49505
#  11572 59102 42301 33178 87505 72701 43402 74133 60543 95051 99301 75701
#  31204 48227 43130  1852 27834  7011 97030 93030 27511 66062 45014 85281
#  79762 78415 91911 90805 21044 61701 75043 33433 77041 75150 28314 33437
#  37042 89502 27707 60201 46203 28540 95336 91104 98026 10550  2149  3301
#  44134 77705 71854 36116 90712 23602 91730 33311 29730 67846 47201  2920
#  85323 44052 45040 97206  7050 44256 75061 37211 54401 96003 19601 53711
#  75007 77506 37604 66502 56560 75104 60016 53132 84604 19805 71203 55433
#  84106 60440 63116 95823 94513  2895 13501 97224 11520 60076 32839 20735
#  30328 73120 85234 98502 85204 83605 43302 35630 38401 80229 75051 77642
#  80906  1915 92804 44240 60174 55016 48180  2908 77520 55125 38134 60068
#  59715 33407 13440 23434 53142  8861 71901 88001 48310  1453 16602 75019
#  18018 47362 33317 95928 84043 36830 93534 92404 35810 91360 29501 33065
#  98042 33142 61761 48911 99207  6360 68701 87401 78501 93454 47150 32114
#  20016 45373 60477 75002 44221 93010 27893 60423 76117 67212  6040  7501
#  83201  4240 85345 84041 30344 30080 60188  1040  8360 79109 34952 93309
#  46614 60035 39401 63122 83704 97756 55122 92399  2740 18103 41042 92563
#  76021 49423 22901 55901 92253 33319 92374 13021 29406 48146  2169 37064
#  92054 74012 52001 61107 37130  7002 62301  2138 20852 97123 31088 48104
#  93101 46060 48858 60462 89431 93905 72032 28110  5408 46226 55113 37087
#  59601 87124 75034  7960 38301 33024 92530 61821 92704 48126 32303 92592
#  92627 60025 11757 86442 54880 43017 93277 59801 20877 98632  7090 39503
#   8401 85635 37421  7109 54601 78664  6460  1810 78550 94061 77803  2148
#  80122 63376 73071 76051 28052 65109 92672 92345 89015 24153 85364  6708
#   2886  7055 80134 80501 17403 48066 80020 42104 32503 37075 70065 53214
#  95616 78539 80525 53081 78577 80112 76706 53186 40324 52402 27360 55106
#  60090 95207 80004 83301 92677  1752 98052 95695 52240 46350 92630 33134
#  75056 98270 77571  8302 93405 77301 50322 97405 82001 60004 98661 98002
#  27217 88220 73034 90640  6484 66212  7017 28601 76903 52302 95037 42071
#  94509 75080 68025 46142 33030 90503 92307 27534  3060 77536 35401 32174
#  76248 35244 74403 72756 33068 94533 48237  8901 80634 34741 32771 61832
#  92683 76063 58103 20707 98226 77489 77581 48307 55369 27514 80022 26003
#  95610 94403 90660 50701 46514 80538 90301 91941 64055 95351 88101 68801
#  32935 71603 56301 33023 44060 83642 94526 72762 94086 92236 57401 33458
#  94568 43123 44035 21740 48601 77840 91761 98059 48187 29483 64118 90604
#  52601 60067 79605 60302 32127  6810 98208]
#
# Unique values for Region:
# ['Central' 'East' 'South' 'West']
#
# Unique values for Product ID:
# ['OFF-PA-10000174' 'OFF-LA-10003223' 'OFF-ST-10002743' ...
#  'TEC-MA-10001856' 'FUR-BO-10002206' 'OFF-FA-10000089']
#
# Unique values for Category:
# ['Office Supplies' 'Furniture' 'Technology']
#
# Unique values for Sub-Category:
# ['Paper' 'Labels' 'Storage' 'Binders' 'Art' 'Chairs' 'Phones' 'Fasteners'
#  'Furnishings' 'Accessories' 'Envelopes' 'Bookcases' 'Appliances' 'Tables'
#  'Supplies' 'Machines' 'Copiers']
#
# Unique values for Product Name:
# ['Message Book, Wirebound, Four 5 1/2" X 4" Forms/Pg., 200 Dupl. Sets/Book'
#  'Avery 508' 'SAFCO Boltless Steel Shelving' ...
#  'Panasonic Business\xa0Telephones\xa0KX-T7736'
#  'Bush Saratoga Collection 5-Shelf Bookcase, Hanover Cherry, *Special Order'
#  'Acco Glide Clips']
#
# Unique values for Sales:
# [ 16.448  11.784 272.736 ...   3.024  52.776  90.93 ]
#
# Unique values for Quantity:
# [ 2  3  9  4  1  7  6  5 10 13  8 14 12 11]
#
# Unique values for Discount:
# [0.2  0.8  0.   0.6  0.7  0.15 0.5  0.4  0.1  0.3  0.32 0.45]
#
# Unique values for Profit:
# [  5.5512   4.2717 -64.7748 ...  19.791    2.7279  12.1176]

# %% [markdown]
# **Frequency Calculation**
#
# The dataset has multiple lines for one order pertaining to each line item. So, to find frequency of below attributes, we need to drop duplicates based on combination of OrderID and the corresponding attribute
#
# 1. Order Dates
# 1. Shipping Modes
# 1. Customers
# 1. Cities

# %%
# Date on which orders were placed most --> 5th September 2016 was the Labour day and also most purchases are done in the month of holidays
# %matplotlib inline
df_store.drop_duplicates(subset=['Order ID','Order Date']).groupby('Order Date')['Order Date']\
        .count().sort_values(ascending=False).head(10).plot(kind='bar',color='limegreen',figsize=(4,4))
# Out:
# <AxesSubplot:xlabel='Order Date'>

# %%
# Most Frequent Shipping Mode used
df_store.drop_duplicates(subset=['Order ID','Ship Mode']).groupby('Ship Mode')['Ship Mode'].count()\
        .sort_values(ascending=False).plot(kind='bar',color='pink',figsize=(4,4))
# Out:
# <AxesSubplot:xlabel='Ship Mode'>

# %%
# Most Frequent Customer --> one customer placing different orders(meaning multiple different orders)
df_store.drop_duplicates(subset=['Order ID','Customer ID']).groupby('Customer ID')['Customer ID']\
        .count().sort_values(ascending=False).head(10).plot(kind='bar',color='magenta',figsize=(6,5))
# Out:
# <AxesSubplot:xlabel='Customer ID'>

# %%
# least Frequent customers
df_store.drop_duplicates(subset=['Order ID','Customer ID']).groupby('Customer ID')['Customer ID']\
        .count().sort_values(ascending=False).tail(20).plot(kind='bar',color='aqua',figsize=(6,5))
# Out:
# <AxesSubplot:xlabel='Customer ID'>

# %%
# From which city the orders have been placed most
df_store.drop_duplicates(subset=['Order ID','City']).groupby('City')['City']\
        .count().sort_values(ascending=False).head(15).plot(kind='bar',color='yellowgreen',figsize=(6,5))
# Out:
# <AxesSubplot:xlabel='City'>

# %%
# From which city the orders have been placed least
df_store.drop_duplicates(subset=['Order ID','City']).groupby('City')['City']\
        .count().sort_values(ascending=False).tail(300)
# Out:
# City
# Loveland             3
# Port Saint Lucie     3
# Gulfport             3
# Waynesboro           3
# Sterling Heights     3
# Beaumont             3
# Mission Viejo        3
# Boise                3
# Pocatello            3
# Garland              3
# Georgetown           3
# Palm Coast           3
# Taylor               3
# Cuyahoga Falls       3
# Avondale             3
# Medina               3
# Medford              3
# Evanston             3
# Plantation           3
# Overland Park        3
# Escondido            3
# Sparks               3
# Corpus Christi       3
# Marietta             3
# Vallejo              3
# West Palm Beach      3
# Modesto              3
# Rome                 3
# Hattiesburg          3
# Johnson City         3
# Kenosha              3
# Eagan                3
# Highland Park        3
# Round Rock           3
# Wilson               3
# Olympia              3
# Cary                 3
# Hesperia             3
# Laguna Niguel        3
# Rockville            3
# Santa Clara          3
# Cambridge            3
# Woonsocket           3
# Chico                3
# Lansing              3
# Chula Vista          3
# Apopka               3
# Westland             3
# Sioux Falls          3
# Clarksville          3
# Redondo Beach        3
# Lebanon              3
# Thornton             3
# Reno                 3
# Revere               3
# Broken Arrow         3
# Hamilton             3
# Las Cruces           3
# Tigard               3
# Oak Park             2
# East Orange          2
# Parker               2
# Thomasville          2
# Dearborn             2
# Dubuque              2
# Draper               2
# Dearborn Heights     2
# Olathe               2
# Owensboro            2
# Delray Beach         2
# Des Plaines          2
# Texarkana            2
# The Colony           2
# Texas City           2
# Independence         2
# Pompano Beach        2
# Daytona Beach        2
# Pasco                2
# Camarillo            2
# San Angelo           2
# Canton               2
# Cedar Hill           2
# Saint Paul           2
# Buffalo Grove        2
# Saginaw              2
# Royal Oak            2
# Charlottesville      2
# Bryan                2
# Santa Fe             2
# Broomfield           2
# Sierra Vista         2
# Southaven            2
# College Station      2
# Bossier City         2
# Coppell              2
# Pleasant Grove       2
# Sunnyvale            2
# Superior             2
# Covington            2
# Pharr                2
# Boca Raton           2
# Hot Springs          2
# Danville             2
# Pearland             2
# Tamarac              2
# North Miami          2
# Bedford              2
# North Charleston     2
# Appleton             2
# Longmont             2
# Longview             2
# Norman               2
# Greenwood            2
# Woodbury             2
# Malden               2
# Mansfield            2
# Visalia              2
# Manteca              2
# Maple Grove          2
# Woodland             2
# Allentown            2
# Hillsboro            2
# Marysville           2
# Hackensack           2
# Hickory              2
# La Crosse            2
# Lodi                 2
# West Jordan          2
# Lincoln Park         2
# Hendersonville       2
# Lewiston             2
# Leominster           2
# Lehi                 2
# League City          2
# Lake Charles         2
# Lawton               2
# Lake Forest          2
# Haltom City          2
# Ann Arbor            2
# Harlingen            2
# Warner Robins        2
# Helena               2
# Bangor               2
# Mount Pleasant       2
# Bethlehem            2
# Noblesville          2
# Niagara Falls        2
# Edinburg             2
# El Cajon             2
# Hoover               2
# Bellingham           2
# Torrance             2
# Elmhurst             2
# Nashua               2
# Encinitas            2
# Muskogee             2
# Homestead            2
# Tuscaloosa           2
# York                 2
# Holland              2
# Frankfort            2
# Meridian             2
# Allen                2
# Mishawaka            2
# Jamestown            2
# Urbandale            2
# Frisco               2
# Tyler                2
# Moorhead             2
# Fargo                2
# Andover              1
# Yucaipa              1
# Bullhead City        1
# Altoona              1
# San Luis Obispo      1
# Whittier             1
# Sanford              1
# Santa Maria          1
# San Marcos           1
# San Mateo            1
# Wausau               1
# Sheboygan            1
# Atlantic City        1
# Tinley Park          1
# Burbank              1
# Baytown              1
# Beverly              1
# Temecula             1
# Twin Falls           1
# Bayonne              1
# Billings             1
# Vacaville            1
# Bartlett             1
# Arvada               1
# Shelton              1
# Summerville          1
# Arlington Heights    1
# Waterloo             1
# Waukesha             1
# Springdale           1
# West Allis           1
# South Bend           1
# Bozeman              1
# Bridgeton            1
# Antioch              1
# San Gabriel          1
# Pensacola            1
# Caldwell             1
# Gastonia             1
# Grapevine            1
# Marlborough          1
# Mason                1
# Grand Island         1
# Melbourne            1
# Goldsboro            1
# Mentor               1
# Glenview             1
# Gladstone            1
# Gaithersburg         1
# New Castle           1
# Missoula             1
# Missouri City        1
# Montebello           1
# Morgan Hill          1
# Eugene               1
# Englewood            1
# Murrieta             1
# Elyria               1
# New Albany           1
# Margate              1
# Manhattan            1
# Greeley              1
# Grove City           1
# Iowa City            1
# Holyoke              1
# Jefferson City       1
# Jupiter              1
# Keller               1
# Kenner               1
# Kirkwood             1
# Kissimmee            1
# La Mesa              1
# La Quinta            1
# Lake Elsinore        1
# Laurel               1
# Layton               1
# Linden               1
# Lindenhurst          1
# Hagerstown           1
# Littleton            1
# Logan                1
# Abilene              1
# New Brunswick        1
# Elkhart              1
# San Clemente         1
# Rochester Hills      1
# Rapid City           1
# Clovis               1
# Redding              1
# Clifton              1
# Redwood City         1
# Renton               1
# Richardson           1
# Citrus Heights       1
# Rio Rancho           1
# Rock Hill            1
# Edmond               1
# Cheyenne             1
# Rogers               1
# Romeoville           1
# Chapel Hill          1
# Champaign            1
# Saint Cloud          1
# Cedar Rapids         1
# Saint Peters         1
# Carol Stream         1
# Coachella            1
# Commerce City        1
# Conroe               1
# Conway               1
# Norfolk              1
# Normal               1
# East Point           1
# Ontario              1
# Orland Park          1
# Deer Park            1
# Ormond Beach         1
# Oswego               1
# Palatine             1
# Passaic              1
# Davis                1
# Danbury              1
# Cottage Grove        1
# Pico Rivera          1
# Pine Bluff           1
# Coral Gables         1
# Port Orange          1
# Portage              1
# Coon Rapids          1
# Aberdeen             1
# Name: City, dtype: int64

# %% [markdown]
# **Product Categories and State relation**
#
# Finding out which sub-categories are bought most in which state --> using total qty. for each state

# %%
df_state_subcatg = df_store.groupby(by=['State','Sub-Category']).agg({'Quantity':'sum'})
df_state_subcatg.sort_values(by='Quantity',ascending=False).head(20)
# Out:
#                            Quantity
# State        Sub-Category
# California   Paper             1091
#              Binders           1057
#              Furnishings        751
# New York     Binders            696
# California   Phones             691
#              Art                644
#              Storage            637
# Texas        Binders            626
#              Paper              572
# California   Accessories        568
# New York     Paper              565
# California   Chairs             466
# New York     Phones             393
# Washington   Binders            365
# New York     Furnishings        356
#              Storage            356
# California   Labels             349
#              Appliances         346
# New York     Art                336
# Pennsylvania Binders            331

# %%
df_state_subcatg.loc['Wyoming']
# Out:
#               Quantity
# Sub-Category
# Chairs               4

# %%
df_state_subcatg.reset_index(inplace=True)
df_state_subcatg.head()
# Out:
#      State Sub-Category  Quantity
# 0  Alabama  Accessories        24
# 1  Alabama   Appliances         1
# 2  Alabama          Art        38
# 3  Alabama      Binders        41
# 4  Alabama       Chairs        30

# %%
df_state_subcatg1 = df_state_subcatg.pivot('State','Sub-Category','Quantity')
df_state_subcatg1.head()
# Out:
# Sub-Category  Accessories  Appliances    Art  Binders  Bookcases  Chairs  \
# State
# Alabama              24.0         1.0   38.0     41.0        NaN    30.0
# Arizona              85.0        21.0   47.0    155.0       18.0    52.0
# Arkansas             43.0         NaN   27.0     42.0        9.0     9.0
# California          568.0       346.0  644.0   1057.0      198.0   466.0
# Colorado             76.0        38.0   32.0    112.0       41.0    53.0
#
# Sub-Category  Copiers  Envelopes  Fasteners  Furnishings  Labels  Machines  \
# State
# Alabama           3.0       11.0        2.0         12.0     8.0       8.0
# Arizona           NaN       28.0       23.0         82.0     9.0       9.0
# Arkansas          NaN        8.0       13.0         23.0     1.0       NaN
# California       60.0      149.0      148.0        751.0   349.0      86.0
# Colorado          1.0       16.0       12.0         92.0     5.0      13.0
#
# Sub-Category   Paper  Phones  Storage  Supplies  Tables
# State
# Alabama         29.0    18.0     14.0       5.0    12.0
# Arizona        124.0    79.0     78.0      16.0    36.0
# Arkansas        36.0    19.0      8.0       NaN     2.0
# California    1091.0   691.0    637.0     145.0   281.0
# Colorado        64.0    59.0     51.0      14.0    14.0

# %%
# Heatmap representation to identify which subcategories were bought most and minimum in which cities.
# Also, representing the subcategories which were not bought altogether in gray color
plt.figure(figsize=(12,12))
sns.set(rc={'axes.facecolor':'gray'})
sns.heatmap(df_state_subcatg1,cmap="Oranges",linecolor='black',linewidths=0.5,mask=df_state_subcatg1.isnull())
# Out:
# <AxesSubplot:xlabel='Sub-Category', ylabel='State'>

# %% [markdown]
# Paper is the most bought product in the store. Let's check which paper type product is most and least popular

# %%
# Identifying which type of Paper sold most. Need to group by productid also coz for ex- easy-staple paper was with different 
# product id's
df_store[df_store['Sub-Category']=='Paper'].groupby(['Product Name','Product ID'])['Quantity'].sum().sort_values(ascending=False)
# Out:
# Product Name                                                                                     Product ID
# Xerox 226                                                                                        OFF-PA-10003441    53
# Xerox 1898                                                                                       OFF-PA-10002986    46
# Xerox 1945                                                                                       OFF-PA-10000100    45
# Xerox 216                                                                                        OFF-PA-10004100    42
# Xerox 1988                                                                                       OFF-PA-10001125    41
# Xerox 1919                                                                                       OFF-PA-10000675    40
# Xerox 1909                                                                                       OFF-PA-10003641    40
# Xerox 1893                                                                                       OFF-PA-10001033    39
# Xerox 191                                                                                        OFF-PA-10000157    39
# Strathmore Photo Mount Cards                                                                     OFF-PA-10003673    38
# Xerox 1881                                                                                       OFF-PA-10001970    38
# White Computer Printout Paper by Universal                                                       OFF-PA-10001289    37
# Xerox 1883                                                                                       OFF-PA-10002254    37
# REDIFORM Incoming/Outgoing Call Register, 11" X 8 1/2", 100 Messages                             OFF-PA-10000380    37
# Xerox 214                                                                                        OFF-PA-10001972    37
# Xerox 1931                                                                                       OFF-PA-10000019    36
# Southworth 100% Résumé Paper, 24lb.                                                              OFF-PA-10002137    35
# Wirebound Message Book, 4 per Page                                                               OFF-PA-10003724    35
# Wirebound Message Books, Four 2 3/4 x 5 White Forms per Page                                     OFF-PA-10000575    34
# Easy-staple paper                                                                                OFF-PA-10000474    34
# Xerox 1978                                                                                       OFF-PA-10002160    34
# Xerox 1964                                                                                       OFF-PA-10001954    33
# Adams Phone Message Book, 200 Message Capacity, 8 1/16” x 11”                                    OFF-PA-10002713    33
# Xerox 225                                                                                        OFF-PA-10002005    33
# Xerox 1895                                                                                       OFF-PA-10002245    33
# Xerox 1906                                                                                       OFF-PA-10003302    32
# Adams Telephone Message Book W/Dividers/Space For Phone Numbers, 5 1/4"X8 1/2", 200/Messages     OFF-PA-10002377    32
# Xerox 1884                                                                                       OFF-PA-10001019    32
# Great White Multi-Use Recycled Paper (20Lb. and 84 Bright)                                       OFF-PA-10001667    32
# Xerox 1908                                                                                       OFF-PA-10001970    32
# Xerox 1960                                                                                       OFF-PA-10003039    32
# Recycled Desk Saver Line "While You Were Out" Book, 5 1/2" X 4"                                  OFF-PA-10001509    30
# Xerox 1891                                                                                       OFF-PA-10001878    30
# Xerox 1997                                                                                       OFF-PA-10003848    30
# Xerox 1887                                                                                       OFF-PA-10000176    30
# Xerox 4200 Series MultiUse Premium Copy Paper (20Lb. and 84 Bright)                              OFF-PA-10002479    30
# Xerox 1951                                                                                       OFF-PA-10002581    30
# Easy-staple paper                                                                                OFF-PA-10001685    29
# Xerox 209                                                                                        OFF-PA-10003797    29
# Astroparche Fine Business Paper                                                                  OFF-PA-10000143    29
# Xerox 202                                                                                        OFF-PA-10001870    28
# Xerox 1962                                                                                       OFF-PA-10003893    28
# Snap-A-Way Black Print Carbonless Ruled Speed Letter, Triplicate                                 OFF-PA-10000482    28
# Xerox 1971                                                                                       OFF-PA-10000327    28
# Southworth 25% Cotton Premium Laser Paper and Envelopes                                          OFF-PA-10004353    28
# Xerox 1996                                                                                       OFF-PA-10003172    28
# Wirebound Message Books, Four 2 3/4" x 5" Forms per Page, 600 Sets per Book                      OFF-PA-10001776    28
# Xerox 1949                                                                                       OFF-PA-10001526    28
# Adams Telephone Message Book w/Frequently-Called Numbers Space, 400 Messages per Book            OFF-PA-10004082    28
# Personal Creations Ink Jet Cards and Labels                                                      OFF-PA-10004530    28
# Xerox 1915                                                                                       OFF-PA-10000994    28
# Xerox 1894                                                                                       OFF-PA-10004101    27
# Xerox 195                                                                                        OFF-PA-10001804    27
# Xerox Color Copier Paper, 11" x 17", Ream                                                        OFF-PA-10002222    27
# Southworth 25% Cotton Antique Laid Paper & Envelopes                                             OFF-PA-10001950    26
# Things To Do Today Pad                                                                           OFF-PA-10002250    26
# Xerox 1900                                                                                       OFF-PA-10004610    26
# Xerox 1968                                                                                       OFF-PA-10003651    26
# Wirebound Message Books, Four 2 3/4 x 5 Forms per Page, 200 Sets per Book                        OFF-PA-10000791    26
# Xerox 1928                                                                                       OFF-PA-10002606    26
# Xerox 1991                                                                                       OFF-PA-10003790    26
# Easy-staple paper                                                                                OFF-PA-10000349    25
# Xerox 220                                                                                        OFF-PA-10001800    25
# Xerox 1917                                                                                       OFF-PA-10003228    25
# TOPS Carbonless Receipt Book, Four 2-3/4 x 7-1/4 Money Receipts per Page                         OFF-PA-10000659    25
# Xerox 2                                                                                          OFF-PA-10001166    25
# Xerox 212                                                                                        OFF-PA-10004621    25
# It's Hot Message Books with Stickers, 2 3/4" x 5"                                                OFF-PA-10004041    25
# Weyerhaeuser First Choice Laser/Copy Paper (20Lb. and 88 Bright)                                 OFF-PA-10002689    25
# Tops Wirebound Message Log Books                                                                 OFF-PA-10001609    25
# Ampad Gold Fibre Wirebound Steno Books, 6" x 9", Gregg Ruled                                     OFF-PA-10002615    25
# Xerox 217                                                                                        OFF-PA-10004888    25
# Xerox 1947                                                                                       OFF-PA-10001593    25
# Adams Telephone Message Book W/Dividers/Space For Phone Numbers, 5 1/4"X8 1/2", 300/Messages     OFF-PA-10001838    24
# Xerox 205                                                                                        OFF-PA-10000061    24
# Universal Premium White Copier/Laser Paper (20Lb. and 87 Bright)                                 OFF-PA-10004040    24
# Computer Printout Paper with Letter-Trim Perforations                                            OFF-PA-10001295    24
# Xerox 1903                                                                                       OFF-PA-10001184    24
# Xerox 1993                                                                                       OFF-PA-10001934    24
# White Dual Perf Computer Printout Paper, 2700 Sheets, 1 Part, Heavyweight, 20 lbs., 14 7/8 x 11  OFF-PA-10000357    24
# Xerox 1888                                                                                       OFF-PA-10000357    24
# Xerox 1933                                                                                       OFF-PA-10001363    24
# Xerox 203                                                                                        OFF-PA-10001639    24
# Xerox 21                                                                                         OFF-PA-10001937    24
# Adams "While You Were Out" Message Pads                                                          OFF-PA-10003016    24
# Xerox 1930                                                                                       OFF-PA-10002036    24
# Xerox 1905                                                                                       OFF-PA-10004735    23
# Xerox 23                                                                                         OFF-PA-10004983    23
# Xerox 227                                                                                        OFF-PA-10002787    22
# Wirebound Four 2-3/4 x 5 Forms per Page, 400 Sets per Book                                       OFF-PA-10002246    22
# Xerox 1970                                                                                       OFF-PA-10002586    22
# Xerox 192                                                                                        OFF-PA-10002262    22
# Xerox 222                                                                                        OFF-PA-10004451    22
# Xerox 1995                                                                                       OFF-PA-10000304    22
# Xerox 1939                                                                                       OFF-PA-10004243    22
# Avoid Verbal Orders Carbonless Minifold Book                                                     OFF-PA-10002659    21
# Xerox 1959                                                                                       OFF-PA-10004285    21
# Xerox 230                                                                                        OFF-PA-10001534    21
# Xerox 1935                                                                                       OFF-PA-10003656    21
# Rediform S.O.S. 1-Up Phone Message Bk, 4-1/4x3-1/16 Bk, 1 Form/Pg, 40 Messages/Bk, 3/Pk          OFF-PA-10004911    21
# Eaton Premium Continuous-Feed Paper, 25% Cotton, Letter Size, White, 1000 Shts/Box               OFF-PA-10004071    21
# Xerox 1977                                                                                       OFF-PA-10000743    20
# Xerox 188                                                                                        OFF-PA-10004156    20
# Xerox 1916                                                                                       OFF-PA-10002377    20
# Advantus Motivational Note Cards                                                                 OFF-PA-10004665    20
# Ampad Phone Message Book, Recycled, 400 Message Capacity, 5 ¾” x 11”                             OFF-PA-10002870    20
# Xerox 1952                                                                                       OFF-PA-10000477    20
# Southworth 25% Cotton Linen-Finish Paper & Envelopes                                             OFF-PA-10002666    20
# Xerox 1934                                                                                       OFF-PA-10000806    20
# Xerox 1885                                                                                       OFF-PA-10001815    20
# Eureka Recycled Copy Paper 8 1/2" x 11", Ream                                                    OFF-PA-10003072    19
# Xerox 1914                                                                                       OFF-PA-10001497    19
# Xerox 1941                                                                                       OFF-PA-10003395    19
# Xerox 189                                                                                        OFF-PA-10000418    19
# Xerox 211                                                                                        OFF-PA-10003309    19
# Black Print Carbonless Snap-Off Rapid Letter, 8 1/2" x 7"                                        OFF-PA-10000726    19
# Multicolor Computer Printout Paper                                                               OFF-PA-10004359    19
# HP Office Recycled Paper (20Lb. and 87 Bright)                                                   OFF-PA-10002464    19
# Xerox 232                                                                                        OFF-PA-10001569    19
# Xerox 201                                                                                        OFF-PA-10000520    19
# Message Book, Phone, Wirebound Standard Line Memo, 2 3/4" X 5"                                   OFF-PA-10003883    19
# Speediset Carbonless Redi-Letter 7" x 8 1/2"                                                     OFF-PA-10004996    19
# RSVP Cards & Envelopes, Blank White, 8-1/2" X 11", 24 Cards/25 Envelopes/Set                     OFF-PA-10002195    19
# Xerox 1880                                                                                       OFF-PA-10001736    18
# Xerox 1925                                                                                       OFF-PA-10000167    18
# Message Book, Wirebound, Four 5 1/2" X 4" Forms/Pg., 200 Dupl. Sets/Book                         OFF-PA-10000174    18
# Xerox 197                                                                                        OFF-PA-10003823    18
# Xerox 213                                                                                        OFF-PA-10000289    18
# Xerox 210                                                                                        OFF-PA-10000788    18
# Xerox 1954                                                                                       OFF-PA-10003270    18
# Xerox 1927                                                                                       OFF-PA-10003657    18
# Xerox 196                                                                                        OFF-PA-10004971    18
# Rediform Wirebound "Phone Memo" Message Book, 11 x 5-3/4                                         OFF-PA-10001892    17
# Xerox 1963                                                                                       OFF-PA-10001215    17
# TOPS "Important Message" Pads, Canary, 4-1/4 x 5-1/2, 50 Sheets per Pad                          OFF-PA-10000807    17
# Telephone Message Books with Fax/Mobile Section, 5 1/2" x 3 3/16"                                OFF-PA-10004675    17
# Xerox 1999                                                                                       OFF-PA-10003177    17
# Xerox 1957                                                                                       OFF-PA-10003349    17
# Easy-staple paper                                                                                OFF-PA-10000249    17
# Xerox 1913                                                                                       OFF-PA-10001144    17
# Green Bar Computer Printout Paper                                                                OFF-PA-10000062    17
# Xerox 204                                                                                        OFF-PA-10003363    17
# Xerox 224                                                                                        OFF-PA-10000029    17
# Wirebound Message Books, 2 7/8" x 5", 3 Forms per Page                                           OFF-PA-10001745    17
# Xerox 1923                                                                                       OFF-PA-10002947    16
# Strathmore Photo Frame Cards                                                                     OFF-PA-10001471    16
# Xerox 1944                                                                                       OFF-PA-10002319    16
# Xerox 198                                                                                        OFF-PA-10000213    16
# Xerox 1929                                                                                       OFF-PA-10000595    16
# IBM Multi-Purpose Copy Paper, 8 1/2 x 11", Case                                                  OFF-PA-10000241    16
# Xerox 1897                                                                                       OFF-PA-10002230    16
# Xerox 199                                                                                        OFF-PA-10000130    16
# Xerox 1943                                                                                       OFF-PA-10003892    16
# Xerox 1956                                                                                       OFF-PA-10002709    16
# Xerox 1987                                                                                       OFF-PA-10003845    16
# Southworth Parchment Paper & Envelopes                                                           OFF-PA-10000533    15
# Xerox 200                                                                                        OFF-PA-10000552    15
# Xerox 1948                                                                                       OFF-PA-10001712    15
# Wirebound Message Books, Two 4 1/4" x 5" Forms per Page                                          OFF-PA-10004569    15
# Riverleaf Stik-Withit Designer Note Cubes                                                        OFF-PA-10000246    15
# Adams Telephone Message Books, 5 1/4” x 11”                                                      OFF-PA-10001560    15
# Xerox 1992                                                                                       OFF-PA-10003022    15
# Xerox 1967                                                                                       OFF-PA-10002365    15
# Southworth 100% Cotton The Best Paper                                                            OFF-PA-10003591    15
# Important Message Pads, 50 4-1/4 x 5-1/2 Forms per Pad                                           OFF-PA-10001307    15
# Xerox 228                                                                                        OFF-PA-10004782    15
# Embossed Ink Jet Note Cards                                                                      OFF-PA-10002421    15
# EcoTones Memo Sheets                                                                             OFF-PA-10003063    15
# Xerox 219                                                                                        OFF-PA-10004255    15
# Array Parchment Paper, Assorted Colors                                                           OFF-PA-10000587    15
# Xerox 229                                                                                        OFF-PA-10000295    15
# Xerox 19                                                                                         OFF-PA-10000483    15
# Spiral Phone Message Books with Labels by Adams                                                  OFF-PA-10004519    15
# Xerox 1920                                                                                       OFF-PA-10002751    15
# Telephone Message Books with Fax/Mobile Section, 4 1/4" x 6"                                     OFF-PA-10000007    15
# Easy-staple paper                                                                                OFF-PA-10002764    15
# Xerox 1966                                                                                       OFF-PA-10002195    14
# Xerox 1981                                                                                       OFF-PA-10000528    14
# Xerox 2000                                                                                       OFF-PA-10000223    14
# Ampad Evidence Wirebond Steno Books, 6" x 9"                                                     OFF-PA-10000141    14
# HP Office Paper (20Lb. and 87 Bright)                                                            OFF-PA-10001461    14
# Xerox 1899                                                                                       OFF-PA-10001846    14
# Xerox 231                                                                                        OFF-PA-10004355    14
# Xerox 221                                                                                        OFF-PA-10004609    14
# Xerox 1886                                                                                       OFF-PA-10001357    14
# Tops White Computer Printout Paper                                                               OFF-PA-10003129    14
# Xerox 1910                                                                                       OFF-PA-10001790    14
# White GlueTop Scratch Pads                                                                       OFF-PA-10001457    14
# Adams Phone Message Book, Professional, 400 Message Capacity, 5 3/6” x 11”                       OFF-PA-10000659    14
# Wirebound Service Call Books, 5 1/2" x 4"                                                        OFF-PA-10002893    13
# Xerox 22                                                                                         OFF-PA-10000477    13
# While You Were Out Pads, 50 per Pad, 4 x 5 1/4, Green Cycle                                      OFF-PA-10004000    13
# Things To Do Today Spiral Book                                                                   OFF-PA-10004733    13
# Xerox 1986                                                                                       OFF-PA-10003001    13
# TOPS 4 x 6 Fluorescent Color Memo Sheets, 500 Sheets per Pack                                    OFF-PA-10000069    13
# Xerox 1994                                                                                       OFF-PA-10003936    13
# Easy-staple paper                                                                                OFF-PA-10003127    13
# Xerox 1942                                                                                       OFF-PA-10002923    13
# Xerox 1911                                                                                       OFF-PA-10004327    13
# Xerox 1946                                                                                       OFF-PA-10001293    13
# Xerox 193                                                                                        OFF-PA-10001801    13
# Xerox 1937                                                                                       OFF-PA-10003134    12
# Xerox 1975                                                                                       OFF-PA-10000232    12
# Xerox 1882                                                                                       OFF-PA-10004039    12
# Wirebound Message Books, 5-1/2 x 4 Forms, 2 or 4 Forms per Page                                  OFF-PA-10002749    12
# Xerox 1982                                                                                       OFF-PA-10000740    12
# Xerox 1940                                                                                       OFF-PA-10004475    12
# Xerox 1953                                                                                       OFF-PA-10004239    12
# Xerox 1924                                                                                       OFF-PA-10000682    12
# TOPS Voice Message Log Book, Flash Format                                                        OFF-PA-10000697    12
# Easy-staple paper                                                                                OFF-PA-10004947    12
# Memo Book, 100 Message Capacity, 5 3/8” x 11”                                                    OFF-PA-10000466    12
# TOPS Money Receipt Book, Consecutively Numbered in Red,                                          OFF-PA-10001260    11
# Standard Line “While You Were Out” Hardbound Telephone Message Book                              OFF-PA-10003022    11
# Black Print Carbonless 8 1/2" x 8 1/4" Rapid Memo Book                                           OFF-PA-10003036    11
# Rediform Voice Mail Log Books                                                                    OFF-PA-10004405    11
# Xerox 206                                                                                        OFF-PA-10000809    11
# Xerox 1979                                                                                       OFF-PA-10003625    11
# Xerox 1912                                                                                       OFF-PA-10003465    11
# Array Memo Cubes                                                                                 OFF-PA-10000551    11
# Avery Personal Creations Heavyweight Cards                                                       OFF-PA-10003256    11
# Southworth Structures Collection                                                                 OFF-PA-10004734    10
# Xerox 1974                                                                                       OFF-PA-10001947    10
# Xerox 1972                                                                                       OFF-PA-10001204    10
# Petty Cash Envelope                                                                              OFF-PA-10000501    10
# 14-7/8 x 11 Blue Bar Computer Printout Paper                                                     OFF-PA-10004381    10
# Xerox 1889                                                                                       OFF-PA-10002120    10
# Xerox 1955                                                                                       OFF-PA-10000312    10
# Xerox 1907                                                                                       OFF-PA-10004438    10
# Xerox 1965                                                                                       OFF-PA-10003971    10
# Post-it “Important Message” Note Pad, Neon Colors, 50 Sheets/Pad                                 OFF-PA-10000673     9
# Xerox 194                                                                                        OFF-PA-10001977     9
# Ampad Poly Cover Wirebound Steno Book, 6" x 9" Assorted Colors, Gregg Ruled                      OFF-PA-10001622     9
# Xerox 223                                                                                        OFF-PA-10002105     9
# Xerox 1936                                                                                       OFF-PA-10000300     9
# Xerox 208                                                                                        OFF-PA-10000556     9
# Xerox 1950                                                                                       OFF-PA-10000605     9
# Xerox 1998                                                                                       OFF-PA-10003729     9
# Xerox 218                                                                                        OFF-PA-10003953     8
# Adams Write n' Stick Phone Message Book, 11" X 5 1/4", 200 Messages                              OFF-PA-10004470     8
# "While you Were Out" Message Book, One Form per Page                                             OFF-PA-10003424     8
# Xerox 1990                                                                                       OFF-PA-10004248     8
# Geographics Note Cards, Blank, White, 8 1/2" x 11"                                               OFF-PA-10002259     8
# Xerox 1980                                                                                       OFF-PA-10002741     8
# Xerox 1973                                                                                       OFF-PA-10002968     8
# Xerox 207                                                                                        OFF-PA-10001826     7
# Tops Green Bar Computer Printout Paper                                                           OFF-PA-10004092     7
# Xerox 215                                                                                        OFF-PA-10001246     7
# 1/4 Fold Party Design Invitations & White Envelopes, 24 8-1/2" X 11" Cards, 25 Env./Pack         OFF-PA-10001583     7
# Xerox 1921                                                                                       OFF-PA-10004965     7
# Xerox 1926                                                                                       OFF-PA-10002960     7
# Xerox 1938                                                                                       OFF-PA-10002558     7
# Southworth 25% Cotton Granite Paper & Envelopes                                                  OFF-PA-10000955     7
# Hammermill CopyPlus Copy Paper (20Lb. and 84 Bright)                                             OFF-PA-10001752     7
# Xerox 1976                                                                                       OFF-PA-10001837     7
# Ink Jet Note and Greeting Cards, 8-1/2" x 5-1/2" Card Size                                       OFF-PA-10001994     6
# Message Book, Standard Line "While You Were Out", 5 1/2" X 4", 200 Sets/Book                     OFF-PA-10000350     6
# Xerox 190                                                                                        OFF-PA-10004948     6
# Unpadded Memo Slips                                                                              OFF-PA-10000859     5
# Xerox 1890                                                                                       OFF-PA-10002499     5
# Xerox Blank Computer Paper                                                                       OFF-PA-10000210     5
# Xerox 1892                                                                                       OFF-PA-10001725     5
# Xerox 1896                                                                                       OFF-PA-10001763     5
# Xerox 1985                                                                                       OFF-PA-10003543     5
# Xerox 1958                                                                                       OFF-PA-10002552     5
# Xerox 1983                                                                                       OFF-PA-10001243     5
# Easy-staple paper                                                                                OFF-PA-10000565     5
# Loose Memo Sheets                                                                                OFF-PA-10001274     5
# Wirebound Message Forms, Four 2 3/4 x 5 Forms per Page, Pink Paper                               OFF-PA-10003205     5
# Rediform S.O.S. Phone Message Books                                                              OFF-PA-10001450     4
# Snap-A-Way Black Print Carbonless Speed Message, No Reply Area, Duplicate                        OFF-PA-10001001     4
# Xerox 1902                                                                                       OFF-PA-10001952     4
# Wirebound Voice Message Log Book                                                                 OFF-PA-10002109     4
# Xerox 1901                                                                                       OFF-PA-10000308     4
# Xerox 1918                                                                                       OFF-PA-10000919     4
# Computer Printout Paper with Letter-Trim Fine Perforations                                       OFF-PA-10001281     4
# Hammermill Color Copier Paper (28Lb. and 96 Bright)                                              OFF-PA-10004022     3
# Universal Ultra Bright White Copier/Laser Paper, 8 1/2" x 11", Ream                              OFF-PA-10002333     3
# Xerox 1922                                                                                       OFF-PA-10001661     3
# Xerox 1932                                                                                       OFF-PA-10001166     3
# Xerox 1989                                                                                       OFF-PA-10003919     2
# Xerox 1969                                                                                       OFF-PA-10003739     2
# Xerox 1984                                                                                       OFF-PA-10002001     2
# Xerox 20                                                                                         OFF-PA-10000048     1
# Name: Quantity, dtype: int64

# %% [markdown]
# **Profit & Discounts on Paper**
#
# --> Calculating unit price of each product without the discount</br>
#
# --> Profit earned from different paper types</br>
#
# --> Discount offered on each paper type</br>

# %%
# The unit_price will hold the actual selling price of the product
cond_list = [df_store['Discount'] == 0 , df_store['Discount'] > 0]
choice_list = [df_store['Sales']/df_store['Quantity'],df_store['Sales']/(df_store['Quantity']*(1-df_store['Discount']))]
df_store['unit_price'] = np.select(cond_list,choice_list)
df_store.tail(n=10)
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 9984  CA-2017-118885 2017-12-29 2018-01-02  Standard Class    JG-15160
# 9985  CA-2017-158673 2017-12-29 2018-01-04  Standard Class    KB-16600
# 9986  US-2017-102638 2017-12-29 2017-12-31     First Class    MC-17845
# 9987  CA-2017-115427 2017-12-30 2018-01-03  Standard Class    EB-13975
# 9988  CA-2017-126221 2017-12-30 2018-01-05  Standard Class    CC-12430
# 9989  CA-2017-156720 2017-12-30 2018-01-03  Standard Class    JM-15580
# 9990  CA-2017-143259 2017-12-30 2018-01-03  Standard Class    PO-18865
# 9991  CA-2017-143259 2017-12-30 2018-01-03  Standard Class    PO-18865
# 9992  CA-2017-115427 2017-12-30 2018-01-03  Standard Class    EB-13975
# 9993  CA-2017-143259 2017-12-30 2018-01-03  Standard Class    PO-18865
#
#           Customer Name      Segment        Country           City  \
# 9984       James Galang     Consumer  United States    Los Angeles
# 9985        Ken Brennan    Corporate  United States   Grand Rapids
# 9986       Michael Chen     Consumer  United States  New York City
# 9987         Erica Bern    Corporate  United States      Fairfield
# 9988        Chuck Clark  Home Office  United States       Columbus
# 9989      Jill Matthias     Consumer  United States       Loveland
# 9990  Patrick O'Donnell     Consumer  United States  New York City
# 9991  Patrick O'Donnell     Consumer  United States  New York City
# 9992         Erica Bern    Corporate  United States      Fairfield
# 9993  Patrick O'Donnell     Consumer  United States  New York City
#
#            State  ...   Region       Product ID         Category Sub-Category  \
# 9984  California  ...     West  TEC-PH-10002563       Technology       Phones
# 9985    Michigan  ...  Central  OFF-PA-10000994  Office Supplies        Paper
# 9986    New York  ...     East  OFF-FA-10002988  Office Supplies    Fasteners
# 9987  California  ...     West  OFF-BI-10004632  Office Supplies      Binders
# 9988     Indiana  ...  Central  OFF-AP-10002457  Office Supplies   Appliances
# 9989    Colorado  ...     West  OFF-FA-10003472  Office Supplies    Fasteners
# 9990    New York  ...     East  OFF-BI-10003684  Office Supplies      Binders
# 9991    New York  ...     East  TEC-PH-10004774       Technology       Phones
# 9992  California  ...     West  OFF-BI-10002103  Office Supplies      Binders
# 9993    New York  ...     East  FUR-BO-10003441        Furniture    Bookcases
#
#                                            Product Name    Sales  Quantity  \
# 9984                                   Adtran 1202752G1  302.376         3
# 9985                                         Xerox 1915  209.700         2
# 9986                                       Ideal Clamps    6.030         3
# 9987                                 GBC Binding covers   20.720         2
# 9988  Eureka The Boss Plus 12-Amp Hard Box Upright V...  209.300         2
# 9989                                Bagged Rubber Bands    3.024         3
# 9990               Wilson Jones Legal Size Ring Binders   52.776         3
# 9991                          Gear Head AU3700S Headset   90.930         7
# 9992    Cardinal Slant-D Ring Binder, Heavy Gauge Vinyl   13.904         2
# 9993  Bush Westfield Collection Bookcases, Fully Ass...  323.136         4
#
#       Discount    Profit  unit_price
# 9984       0.2   22.6782      125.99
# 9985       0.0  100.6560      104.85
# 9986       0.0    2.9547        2.01
# 9987       0.2    6.4750       12.95
# 9988       0.0   56.5110      104.65
# 9989       0.2   -0.6048        1.26
# 9990       0.2   19.7910       21.99
# 9991       0.0    2.7279       12.99
# 9992       0.2    4.5188        8.69
# 9993       0.2   12.1176      100.98
#
# [10 rows x 21 columns]

# %%
# Total profit earned from each paper product type - Papers that sold out least
df_store[df_store['Sub-Category']=='Paper'].groupby(['Product Name','Product ID'])[['Quantity','Profit']].sum()\
            .sort_values(by = 'Quantity',ascending=False).tail(20)
# Out:
#                                                                     Quantity  \
# Product Name                                       Product ID
# Xerox 1958                                         OFF-PA-10002552         5
# Xerox 1983                                         OFF-PA-10001243         5
# Easy-staple paper                                  OFF-PA-10000565         5
# Loose Memo Sheets                                  OFF-PA-10001274         5
# Wirebound Message Forms, Four 2 3/4 x 5 Forms p... OFF-PA-10003205         5
# Rediform S.O.S. Phone Message Books                OFF-PA-10001450         4
# Snap-A-Way Black Print Carbonless Speed Message... OFF-PA-10001001         4
# Xerox 1902                                         OFF-PA-10001952         4
# Wirebound Voice Message Log Book                   OFF-PA-10002109         4
# Xerox 1901                                         OFF-PA-10000308         4
# Xerox 1918                                         OFF-PA-10000919         4
# Computer Printout Paper with Letter-Trim Fine P... OFF-PA-10001281         4
# Hammermill Color Copier Paper (28Lb. and 96 Bri... OFF-PA-10004022         3
# Universal Ultra Bright White Copier/Laser Paper... OFF-PA-10002333         3
# Xerox 1922                                         OFF-PA-10001661         3
# Xerox 1932                                         OFF-PA-10001166         3
# Xerox 1989                                         OFF-PA-10003919         2
# Xerox 1969                                         OFF-PA-10003739         2
# Xerox 1984                                         OFF-PA-10002001         2
# Xerox 20                                           OFF-PA-10000048         1
#
#                                                                       Profit
# Product Name                                       Product ID
# Xerox 1958                                         OFF-PA-10002552   15.5520
# Xerox 1983                                         OFF-PA-10001243   14.6510
# Easy-staple paper                                  OFF-PA-10000565  137.1510
# Loose Memo Sheets                                  OFF-PA-10001274    8.5775
# Wirebound Message Forms, Four 2 3/4 x 5 Forms p... OFF-PA-10003205   14.2975
# Rediform S.O.S. Phone Message Books                OFF-PA-10001450    9.7608
# Snap-A-Way Black Print Carbonless Speed Message... OFF-PA-10001001   31.4712
# Xerox 1902                                         OFF-PA-10001952   32.8896
# Wirebound Voice Message Log Book                   OFF-PA-10002109    4.9504
# Xerox 1901                                         OFF-PA-10000308    5.2800
# Xerox 1918                                         OFF-PA-10000919   75.9696
# Computer Printout Paper with Letter-Trim Fine P... OFF-PA-10001281   91.9680
# Hammermill Color Copier Paper (28Lb. and 96 Bri... OFF-PA-10004022   13.4865
# Universal Ultra Bright White Copier/Laser Paper... OFF-PA-10002333    5.6376
# Xerox 1922                                         OFF-PA-10001661    4.3326
# Xerox 1932                                         OFF-PA-10001166   28.7064
# Xerox 1989                                         OFF-PA-10003919    2.6892
# Xerox 1969                                         OFF-PA-10003739    5.6644
# Xerox 1984                                         OFF-PA-10002001    6.3504
# Xerox 20                                           OFF-PA-10000048    3.1104

# %%
# get the second level index label values to get the product_ids(paper) which are being sold least
paper_sold_least = df_store[df_store['Sub-Category']=='Paper'].groupby(['Product Name','Product ID'])[['Quantity','Profit']].sum()\
            .sort_values(by = 'Quantity',ascending=False).tail(20).index.get_level_values(1)
# printing discount values of those product_id's
df_store[df_store['Product ID'].isin(paper_sold_least)][['Product ID','Discount']].sort_values(by='Product ID')
# Out:
#            Product ID  Discount
# 3842  OFF-PA-10000048       0.0
# 9369  OFF-PA-10000308       0.2
# 9157  OFF-PA-10000565       0.0
# 4730  OFF-PA-10000565       0.0
# 200   OFF-PA-10000919       0.0
# 4630  OFF-PA-10001001       0.2
# 1680  OFF-PA-10001166       0.2
# 7596  OFF-PA-10001166       0.2
# 7397  OFF-PA-10001166       0.0
# 6848  OFF-PA-10001166       0.2
# 1367  OFF-PA-10001166       0.2
# 4124  OFF-PA-10001166       0.2
# 3898  OFF-PA-10001166       0.2
# 613   OFF-PA-10001166       0.2
# 2364  OFF-PA-10001166       0.0
# 3410  OFF-PA-10001166       0.2
# 1941  OFF-PA-10001243       0.0
# 4415  OFF-PA-10001243       0.0
# 3502  OFF-PA-10001274       0.0
# 3722  OFF-PA-10001274       0.0
# 7227  OFF-PA-10001281       0.0
# 3155  OFF-PA-10001450       0.0
# 2642  OFF-PA-10001661       0.2
# 599   OFF-PA-10001952       0.2
# 2439  OFF-PA-10001952       0.0
# 8577  OFF-PA-10002001       0.0
# 8697  OFF-PA-10002109       0.2
# 1346  OFF-PA-10002109       0.2
# 7505  OFF-PA-10002333       0.2
# 6532  OFF-PA-10002552       0.0
# 8934  OFF-PA-10002552       0.0
# 8017  OFF-PA-10003205       0.0
# 9324  OFF-PA-10003205       0.2
# 9004  OFF-PA-10003739       0.0
# 8884  OFF-PA-10003919       0.2
# 5735  OFF-PA-10004022       0.0
# 4333  OFF-PA-10004022       0.0

# %%
# Total profit earned from each paper product type - Papers that sold out most
df_store[df_store['Sub-Category']=='Paper'].groupby(['Product Name','Product ID'])[['Quantity','Profit']].sum()\
            .sort_values(by = 'Quantity',ascending=False).head(20)
# Out:
#                                                                     Quantity  \
# Product Name                                       Product ID
# Xerox 226                                          OFF-PA-10003441        53
# Xerox 1898                                         OFF-PA-10002986        46
# Xerox 1945                                         OFF-PA-10000100        45
# Xerox 216                                          OFF-PA-10004100        42
# Xerox 1988                                         OFF-PA-10001125        41
# Xerox 1919                                         OFF-PA-10000675        40
# Xerox 1909                                         OFF-PA-10003641        40
# Xerox 1893                                         OFF-PA-10001033        39
# Xerox 191                                          OFF-PA-10000157        39
# Strathmore Photo Mount Cards                       OFF-PA-10003673        38
# Xerox 1881                                         OFF-PA-10001970        38
# White Computer Printout Paper by Universal         OFF-PA-10001289        37
# Xerox 1883                                         OFF-PA-10002254        37
# REDIFORM Incoming/Outgoing Call Register, 11" X... OFF-PA-10000380        37
# Xerox 214                                          OFF-PA-10001972        37
# Xerox 1931                                         OFF-PA-10000019        36
# Southworth 100% Résumé Paper, 24lb.                OFF-PA-10002137        35
# Wirebound Message Book, 4 per Page                 OFF-PA-10003724        35
# Wirebound Message Books, Four 2 3/4 x 5 White F... OFF-PA-10000575        34
# Easy-staple paper                                  OFF-PA-10000474        34
#
#                                                                       Profit
# Product Name                                       Product ID
# Xerox 226                                          OFF-PA-10003441  155.7792
# Xerox 1898                                         OFF-PA-10002986  120.7744
# Xerox 1945                                         OFF-PA-10000100  756.2655
# Xerox 216                                          OFF-PA-10004100   96.9408
# Xerox 1988                                         OFF-PA-10001125  404.2890
# Xerox 1919                                         OFF-PA-10000675  729.6220
# Xerox 1909                                         OFF-PA-10003641  400.9760
# Xerox 1893                                         OFF-PA-10001033  619.3589
# Xerox 191                                          OFF-PA-10000157  354.2454
# Strathmore Photo Mount Cards                       OFF-PA-10003673  106.3104
# Xerox 1881                                         OFF-PA-10001970  207.0408
# White Computer Printout Paper by Universal         OFF-PA-10001289  547.6788
# Xerox 1883                                         OFF-PA-10002254  354.0196
# REDIFORM Incoming/Outgoing Call Register, 11" X... OFF-PA-10000380  127.6020
# Xerox 214                                          OFF-PA-10001972   90.4608
# Xerox 1931                                         OFF-PA-10000019   88.6464
# Southworth 100% Résumé Paper, 24lb.                OFF-PA-10002137  113.1990
# Wirebound Message Book, 4 per Page                 OFF-PA-10003724   87.6945
# Wirebound Message Books, Four 2 3/4 x 5 White F... OFF-PA-10000575   95.2656
# Easy-staple paper                                  OFF-PA-10000474  467.0992

# %%
# get the second level index label values to get the product_ids(paper) which are being sold most
paper_sold_most = df_store[df_store['Sub-Category']=='Paper'].groupby(['Product Name','Product ID'])[['Quantity','Profit']].sum()\
            .sort_values(by = 'Quantity',ascending=False).head(20).index.get_level_values(1)
# printing discount values of those product_id's
df_store[df_store['Product ID'].isin(paper_sold_most)][['Product ID','Discount']].sort_values(by='Product ID').head()
# Out:
#            Product ID  Discount
# 1797  OFF-PA-10000019       0.0
# 9870  OFF-PA-10000019       0.2
# 5356  OFF-PA-10000019       0.0
# 5296  OFF-PA-10000019       0.0
# 4470  OFF-PA-10000019       0.0

# %% [markdown]
# **Get the Region's most profitable product**

# %%
df_store.groupby(by=['Region','Product ID'])['Profit'].sum().round(4).sort_values(ascending=False)
# Out:
# Region   Product ID
# East     TEC-CO-10004722    10079.9712
# Central  TEC-CO-10004722     8399.9760
# West     TEC-CO-10004722     6719.9808
# South    OFF-BI-10003527     3812.9700
# Central  OFF-BI-10000545     3804.9000
# East     TEC-MA-10003979     3772.9461
#          TEC-MA-10001047     3717.9714
#          TEC-MA-10000045     3343.5360
# West     OFF-BI-10003527     3050.3760
# East     TEC-CO-10001449     3023.9496
#          OFF-BI-10001359     2610.2409
#          OFF-BI-10003527     2414.8810
# Central  TEC-CO-10003763     2302.9671
# West     TEC-CO-10003763     2267.9676
# East     TEC-MA-10001127     2239.9872
# West     TEC-CO-10001449     2183.9636
# East     TEC-MA-10002927     1995.9900
# West     TEC-AC-10002049     1938.7404
# East     TEC-AC-10002049     1855.4652
# South    TEC-MA-10001127     1854.9894
# West     TEC-AC-10003870     1715.9480
# Central  OFF-BI-10001120     1700.9910
# East     TEC-MA-10003673     1668.2050
# West     OFF-BI-10001120     1644.2913
#          TEC-AC-10003832     1589.7207
#          TEC-CO-10001766     1480.4671
# South    TEC-MA-10000010     1459.2000
#          TEC-CO-10001449     1439.9760
#          TEC-MA-10000864     1416.8000
# East     OFF-BI-10004995     1415.4296
# West     TEC-CO-10003236     1379.9770
# East     TEC-AC-10003033     1323.0995
# Central  OFF-AP-10002945     1289.7885
# South    OFF-BI-10003925     1276.4871
# West     OFF-BI-10003925     1257.0876
# East     TEC-CO-10002095     1224.9755
#          TEC-CO-10004115     1194.9761
#          OFF-ST-10002615     1169.1524
#          TEC-MA-10000488     1159.9855
# Central  OFF-BI-10004600     1159.1685
# East     TEC-PH-10002885     1156.6974
# West     OFF-BI-10004390     1136.6460
# East     OFF-AP-10002945     1106.3920
#          OFF-ST-10003208     1101.4622
# South    TEC-PH-10001459     1091.9740
# Central  TEC-CO-10002095     1074.9785
# West     OFF-BI-10004995     1061.5722
#          TEC-CO-10001046     1049.9850
#          TEC-AC-10001838     1031.9484
# East     OFF-ST-10000142     1031.3824
#          TEC-MA-10002428      976.4370
# West     OFF-AP-10000275      918.7920
# South    TEC-PH-10000730      909.9818
# East     OFF-ST-10001490      892.3500
# West     OFF-ST-10001496      890.1386
#          TEC-MA-10000984      881.3700
# East     OFF-ST-10002011      880.2990
# Central  TEC-CO-10001046      874.9875
# South    TEC-AC-10003033      871.0680
# West     TEC-CO-10004115      869.9826
# South    OFF-AP-10002945      850.8395
# West     OFF-BI-10004632      845.1975
# Central  TEC-AC-10004666      829.3754
# West     TEC-CO-10002095      824.9835
# Central  TEC-CO-10002313      803.9866
# West     FUR-CH-10003973      803.0016
# East     TEC-PH-10003072      796.4469
# West     OFF-ST-10000078      795.5100
# East     TEC-PH-10004586      791.8900
# Central  FUR-CH-10002320      770.3520
# South    TEC-PH-10002496      764.3510
# West     OFF-AP-10002651      755.6733
# South    TEC-CO-10001943      751.9624
# Central  OFF-AP-10003057      751.7601
# South    FUR-CH-10004063      746.4078
# Central  TEC-PH-10001795      743.9880
# East     OFF-AP-10000275      735.0336
# Central  FUR-CH-10000454      731.9400
#          OFF-PA-10000994      721.3680
#          TEC-CO-10001571      714.9870
# West     TEC-CO-10002313      701.9883
# East     TEC-AC-10001838      693.9653
#          FUR-CH-10002331      687.0414
# West     OFF-BI-10004584      682.5168
# South    FUR-BO-10004695      676.8652
# Central  FUR-CH-10001854      673.8816
#          TEC-AC-10003033      673.0980
# West     TEC-CO-10000971      659.9780
#          OFF-AP-10001058      654.7554
# East     TEC-MA-10004212      648.5624
# West     FUR-CH-10004287      646.3080
# East     OFF-AP-10003849      644.0760
# West     OFF-BI-10004600      643.9825
# East     FUR-CH-10000595      643.6800
# South    OFF-BI-10003650      641.6956
# East     OFF-ST-10001526      637.7490
# West     OFF-ST-10003306      634.2984
# South    TEC-AC-10004145      632.4747
#          TEC-CO-10001046      629.9910
# West     FUR-TA-10001307      629.0100
#          FUR-CH-10001215      626.2250
# East     OFF-ST-10001780      621.9744
# West     TEC-MA-10004002      621.2115
# East     OFF-BI-10003091      618.1848
# West     OFF-LA-10003930      613.4544
# East     FUR-CH-10004086      609.7157
#          TEC-PH-10001835      606.6816
# Central  FUR-CH-10000847      605.2384
# West     OFF-BI-10003091      604.7460
# East     TEC-PH-10000984      603.6492
#          TEC-PH-10002114      592.7896
# Central  FUR-CH-10002335      589.3420
# East     OFF-BI-10004318      588.1660
# West     FUR-FU-10002937      585.4570
#          OFF-AP-10002684      583.5840
# South    OFF-LA-10003930      567.2487
#          FUR-CH-10000454      561.1540
# Central  FUR-CH-10004063      554.8012
# East     FUR-CH-10002073      553.3902
# Central  OFF-ST-10001490      553.2570
# West     OFF-PA-10004359      549.4140
# East     TEC-PH-10002834      548.9695
# Central  TEC-PH-10002624      545.1884
# West     FUR-TA-10004619      541.6540
# East     TEC-PH-10001494      530.9115
# South    TEC-AC-10003870      527.9840
# West     OFF-ST-10003208      526.2340
#          OFF-SU-10000151      524.0096
# Central  FUR-CH-10003746      519.9876
#          FUR-CH-10004495      517.6856
# East     TEC-AC-10004145      517.4793
# South    TEC-PH-10000984      517.4136
# Central  TEC-PH-10004165      516.9812
# East     OFF-PA-10001970      515.3418
#          OFF-BI-10004600      515.1860
#          OFF-AP-10000891      511.3680
# West     TEC-AC-10004975      507.9690
# Central  TEC-PH-10000895      503.9720
# East     OFF-ST-10000078      503.8230
#          OFF-AP-10002651      503.7822
# West     OFF-PA-10000675      502.1275
# South    FUR-TA-10003569      501.2250
#          OFF-ST-10001526      500.5728
# East     OFF-BI-10003925      496.6272
# South    TEC-AC-10003174      495.8340
# West     TEC-CO-10001571      494.9910
# South    FUR-TA-10001932      493.7856
# West     OFF-ST-10000046      491.1120
# East     FUR-CH-10004675      488.4992
# Central  TEC-CO-10001766      485.9892
# East     FUR-CH-10002320      481.4700
#          FUR-CH-10000785      477.7872
#          TEC-CO-10002313      467.9922
# West     FUR-TA-10002958      464.5444
#          TEC-PH-10002885      454.8810
# Central  TEC-PH-10003012      454.2705
# South    FUR-CH-10000015      450.5280
# East     OFF-AP-10000828      448.8304
# Central  FUR-TA-10001095      444.4395
# West     OFF-ST-10002615      443.4716
#          FUR-TA-10000577      442.2267
#          TEC-AC-10003095      441.9660
# Central  TEC-AC-10000990      440.7648
# West     TEC-AC-10000990      440.7648
# East     TEC-CO-10001571      439.9920
#          FUR-CH-10002335      439.7398
#          FUR-CH-10000454      439.1640
#          FUR-CH-10001708      437.0380
#          TEC-PH-10004539      436.5669
# West     TEC-PH-10001795      433.9930
#          TEC-MA-10000488      431.9946
#          TEC-AC-10003610      431.9280
# South    TEC-AC-10001838      429.9785
# West     OFF-AP-10003057      429.5772
#          OFF-ST-10001490      428.3280
#          TEC-PH-10001817      426.0200
# South    OFF-AP-10002518      425.3722
#          FUR-CH-10000309      422.5100
# East     TEC-AC-10002001      422.3736
#          OFF-BI-10001071      422.2680
# South    FUR-CH-10001854      421.1760
# Central  OFF-BI-10003091      421.0824
#          OFF-BI-10003650      420.7840
# South    TEC-PH-10000560      419.9880
#          TEC-AC-10002049      415.3950
# East     TEC-AC-10001432      412.6320
# West     OFF-AP-10002534      412.4680
# Central  FUR-CH-10004086      411.3393
# West     FUR-TA-10001705      408.1920
# South    TEC-CO-10004202      404.9865
# West     OFF-PA-10001878      404.4857
#          TEC-PH-10001459      403.1904
# South    OFF-ST-10003805      400.0450
# Central  FUR-CH-10004675      396.9056
# West     TEC-AC-10003911      396.7752
# East     TEC-AC-10004171      395.9604
#          OFF-BI-10003656      394.3768
# Central  FUR-CH-10000988      394.2680
# East     TEC-PH-10001944      394.0650
#          FUR-CH-10004218      393.8220
# South    OFF-PA-10000994      390.0420
#          FUR-TA-10004915      388.8128
# West     FUR-TA-10003748      388.4088
# South    FUR-TA-10002645      386.8350
# Central  FUR-CH-10002073      383.9310
# West     OFF-PA-10003395      381.6540
# Central  TEC-AC-10003832      381.4424
#          TEC-PH-10003645      378.1674
#          FUR-FU-10003664      378.0216
# West     TEC-CO-10001943      377.9811
#          TEC-AC-10004571      377.9622
# East     FUR-FU-10002937      377.0740
# Central  TEC-PH-10001760      376.1100
# East     FUR-CH-10001215      375.7350
# Central  TEC-PH-10002584      375.5940
# West     TEC-PH-10002200      373.9320
# Central  OFF-BI-10004519      373.4550
# East     FUR-BO-10002613      365.2740
#          TEC-MA-10003356      364.4595
# West     FUR-TA-10002903      363.5940
# South    TEC-PH-10002352      362.6870
# West     TEC-MA-10000418      359.9988
# East     TEC-PH-10003012      357.2568
#          FUR-CH-10003379      356.2250
#          FUR-CH-10004983      355.7658
#          TEC-AC-10004666      355.4466
# South    FUR-CH-10002073      354.8052
# East     TEC-PH-10004977      354.7419
# West     FUR-CH-10001394      350.9900
# Central  FUR-TA-10000617      350.4270
# West     OFF-ST-10000142      349.3392
# East     FUR-FU-10000576      348.3344
#          OFF-PA-10000418      348.1020
#          OFF-PA-10003302      345.1856
# Central  TEC-CO-10004202      344.9885
# South    TEC-PH-10001530      343.5266
# Central  TEC-PH-10001363      341.9940
# East     OFF-AP-10002118      337.2192
# Central  OFF-LA-10003930      337.2033
# South    TEC-AC-10003198      336.6480
# Central  TEC-CO-10001449      335.9944
# West     OFF-AP-10004487      335.0384
# South    FUR-CH-10003379      327.7270
# East     TEC-PH-10001459      327.5922
#          TEC-AC-10002800      327.4345
# Central  FUR-CH-10000015      324.9000
#          TEC-PH-10001494      323.9460
# East     TEC-PH-10001760      322.3800
# South    OFF-AP-10003057      322.1829
# East     TEC-PH-10000895      320.3822
#          TEC-AC-10004571      319.9680
#          FUR-BO-10000362      319.7326
# South    OFF-BI-10004318      318.3016
# East     TEC-PH-10001336      317.3154
# South    FUR-TA-10001086      316.1392
# West     TEC-CO-10004202      314.9895
# East     TEC-PH-10003691      314.9750
# West     TEC-PH-10002726      314.9400
# South    FUR-TA-10003238      314.0586
#          FUR-CH-10002602      314.0384
#          TEC-CO-10003236      311.9948
# East     TEC-AC-10002402      311.9610
# West     FUR-TA-10003392      311.8878
#          OFF-ST-10001780      310.9872
# East     FUR-FU-10004306      310.8800
# West     OFF-PA-10000357      309.5968
#          TEC-AC-10000420      309.3558
# Central  FUR-BO-10002545      307.9564
# South    FUR-CH-10004853      306.4894
# East     TEC-PH-10002310      305.5824
#          OFF-AP-10002311      305.5164
# Central  OFF-AP-10003590      305.1300
# West     OFF-AP-10003590      305.1300
# East     TEC-AC-10002842      304.6400
#          OFF-ST-10000689      304.2360
# South    OFF-PA-10000100      304.1458
# West     OFF-ST-10004340      302.1948
# South    OFF-PA-10004359      301.9680
# East     TEC-PH-10002447      298.6855
# Central  OFF-PA-10000418      297.7740
# South    FUR-FU-10002937      297.6900
#          TEC-PH-10003601      296.9820
# East     TEC-MA-10002859      296.0671
# West     TEC-AC-10002926      295.4409
#          OFF-LA-10003510      294.9198
# South    TEC-PH-10003273      294.8166
#          TEC-PH-10001128      293.9804
#          OFF-AP-10002734      290.3016
# West     OFF-AP-10001242      289.7280
#          FUR-CH-10002320      288.8820
#          FUR-FU-10001979      288.4288
# Central  OFF-ST-10000078      286.3836
#          FUR-FU-10004665      284.9184
# South    FUR-FU-10004665      284.9184
#          FUR-CH-10001270      284.6250
# Central  TEC-AC-10004145      282.4887
# East     FUR-CH-10001394      280.7920
# West     FUR-BO-10002916      280.4072
# East     FUR-BO-10002598      280.3710
#          OFF-AP-10000938      278.7048
# Central  TEC-PH-10002103      278.2104
# East     OFF-ST-10000585      277.5360
#          FUR-CH-10003746      276.0428
# Central  OFF-PA-10000357      275.8627
# West     OFF-PA-10003228      275.8524
# South    OFF-BI-10004632      274.4910
# West     OFF-PA-10000806      274.3020
#          FUR-FU-10004864      273.9566
#          OFF-PA-10000062      273.1512
# East     TEC-PH-10004094      272.9825
# West     FUR-FU-10000576      272.7920
#          TEC-AC-10001465      272.4000
# South    FUR-TA-10002530      271.7640
# West     FUR-FU-10001215      271.7190
# East     FUR-BO-10002545      271.4192
# West     FUR-CH-10004495      270.8820
# Central  FUR-CH-10002084      270.5780
#          TEC-CO-10001943      269.9865
# East     OFF-AP-10003779      269.7240
#          TEC-MA-10004552      269.3080
# West     OFF-BI-10002026      269.1108
#          TEC-PH-10001760      268.6500
#          TEC-AC-10000844      268.5684
#          OFF-PA-10001736      266.5088
# South    OFF-ST-10003716      265.5236
# Central  TEC-PH-10001835      265.4232
#          TEC-AC-10001908      264.9735
# West     TEC-AC-10004171      263.9736
# Central  TEC-PH-10004345      263.8900
# East     TEC-PH-10001578      263.2175
# Central  TEC-PH-10004120      263.0208
# East     FUR-CH-10000749      260.6112
# South    OFF-BI-10001359      260.1271
# West     FUR-TA-10000617      259.4070
#          FUR-TA-10000688      259.2415
#          TEC-AC-10000892      259.2000
#          TEC-AC-10000736      259.1676
#          OFF-EN-10001434      258.2790
# East     OFF-AP-10002518      258.0710
# West     FUR-CH-10004063      257.3820
# East     FUR-CH-10004287      256.8660
# Central  TEC-PH-10004536      256.4810
# West     TEC-AC-10000474      256.4730
# East     FUR-FU-10000965      255.5448
# Central  TEC-AC-10004659      255.4650
# West     OFF-AP-10000828      253.3720
# East     OFF-BI-10004390      252.5880
# South    TEC-AC-10004469      252.4840
# East     FUR-CH-10000155      251.2020
# West     OFF-ST-10001526      250.2864
#          TEC-AC-10002253      249.3600
# South    FUR-FU-10003664      249.1506
# East     OFF-BI-10004519      248.9700
#          TEC-PH-10003601      247.4850
# South    TEC-PH-10000369      246.9404
# Central  OFF-ST-10003306      245.7192
#          OFF-ST-10001496      245.0584
# East     TEC-CO-10001046      244.9965
# West     TEC-AC-10001908      244.9755
#          OFF-EN-10003296      244.2960
# Central  OFF-ST-10003816      243.1422
#          FUR-CH-10003379      242.2330
#          FUR-CH-10004626      242.1360
#          FUR-TA-10001950      241.1046
# East     OFF-ST-10000036      240.0597
# South    TEC-MA-10003183      239.9850
#          TEC-AC-10004171      239.9760
# East     OFF-PA-10000357      239.6736
#          TEC-AC-10002473      239.5272
# West     FUR-FU-10004188      239.3820
#          FUR-CH-10000155      239.2400
# East     OFF-AP-10000179      238.1234
# West     TEC-PH-10001530      236.9821
# Central  TEC-PH-10002922      236.5860
# West     FUR-CH-10004086      236.3013
#          OFF-AP-10001391      235.5264
#          OFF-BI-10001718      234.8066
# East     TEC-AC-10000892      234.0000
# South    OFF-EN-10000056      233.9848
#          FUR-FU-10003553      233.8180
# Central  TEC-PH-10004042      232.1254
# East     OFF-AP-10003217      231.9940
# Central  FUR-TA-10000198      231.4116
# West     OFF-PA-10001815      230.5920
# South    TEC-PH-10002563      229.3018
# West     OFF-EN-10001453      229.2848
#          TEC-AC-10002842      228.4800
# Central  OFF-AP-10001005      228.0850
# South    TEC-PH-10000526      226.5364
# Central  OFF-ST-10002011      226.3626
# East     TEC-MA-10004626      225.6000
#          FUR-CH-10004997      225.5760
# South    FUR-CH-10002331      224.2674
# West     TEC-MA-10003183      223.9860
# South    OFF-ST-10003208      223.1958
# West     TEC-MA-10004241      223.0540
#          OFF-ST-10002292      222.5880
# South    TEC-PH-10002033      222.1596
# East     TEC-AC-10001606      221.9778
# West     OFF-BI-10003656      220.9870
#          OFF-PA-10000100      220.9361
# Central  TEC-PH-10003072      220.4853
#          TEC-AC-10003198      220.1160
# South    OFF-BI-10000632      219.6546
# Central  TEC-PH-10001336      219.2830
#          OFF-AP-10001058      218.2518
# West     TEC-AC-10003033      217.7670
# East     TEC-AC-10002567      217.5728
# West     OFF-AP-10000240      217.1288
# East     TEC-PH-10004447      216.8244
# Central  TEC-AC-10002049      215.7426
#          OFF-AP-10001394      215.4600
# South    OFF-ST-10000585      214.7600
# East     FUR-FU-10004848      212.3859
# West     OFF-ST-10000675      211.8125
#          TEC-PH-10002275      211.6688
#          TEC-PH-10002624      211.4955
# South    TEC-PH-10002624      211.4955
# East     TEC-AC-10003628      211.1296
# West     FUR-CH-10001854      210.5880
# Central  FUR-CH-10002024      210.2940
# West     OFF-ST-10000532      210.1008
# East     TEC-AC-10001908      209.9790
# West     OFF-AR-10002135      209.6700
#          TEC-MA-10001972      209.4000
#          TEC-PH-10000486      208.7820
# East     OFF-AP-10000026      208.5174
#          FUR-FU-10003192      207.8856
#          OFF-AP-10001005      207.6360
# South    TEC-PH-10001557      207.3384
# East     OFF-ST-10003306      207.1470
#          OFF-BI-10003718      206.6232
# West     OFF-BI-10003718      206.6232
# Central  TEC-AC-10001432      206.3160
# East     OFF-BI-10002026      205.6740
# West     OFF-ST-10003716      204.7682
# East     FUR-CH-10003761      204.3288
# South    TEC-PH-10004539      204.1092
# Central  OFF-EN-10003001      204.0714
# West     FUR-CH-10002335      204.0030
# Central  OFF-EN-10002230      203.9499
# West     FUR-FU-10000277      202.2528
# South    FUR-BO-10003546      201.9600
# Central  FUR-CH-10004287      201.6260
# West     FUR-BO-10002545      200.9546
# South    TEC-PH-10001061      199.9800
# East     OFF-EN-10003055      199.9000
# South    TEC-PH-10002680      197.9910
# Central  OFF-AP-10000938      197.9208
# West     TEC-AC-10003399      197.8704
# East     TEC-PH-10000673      197.5696
# West     OFF-EN-10003001      197.3530
# Central  TEC-PH-10001819      196.1564
#          TEC-PH-10000560      195.9944
# West     FUR-CH-10000454      195.1840
# Central  TEC-AC-10000736      195.1756
#          TEC-AC-10000844      193.7772
# East     TEC-AC-10001990      191.9680
# Central  FUR-TA-10003748      191.7146
# West     FUR-FU-10000965      191.6586
# South    FUR-FU-10003930      190.4298
# East     FUR-CH-10000309      190.1295
# South    TEC-MA-10004458      190.0800
# East     OFF-ST-10001932      189.3066
# West     OFF-ST-10001932      189.3066
# East     TEC-AC-10004469      188.5640
# South    FUR-CH-10000785      188.2192
# West     TEC-AC-10002800      187.4625
#          TEC-PH-10004908      186.9780
# East     OFF-PA-10004071      186.4128
# South    TEC-PH-10004977      184.2306
#          TEC-PH-10002103      184.2204
# East     OFF-PA-10004243      182.1120
# West     FUR-CH-10000665      181.1760
# Central  FUR-CH-10000665      181.1760
# West     OFF-PA-10001033      180.7659
#          OFF-BI-10000632      180.5856
#          FUR-TA-10003473      180.5424
#          FUR-TA-10003569      180.4410
# South    TEC-PH-10004586      179.9750
#          OFF-PA-10001033      179.9461
# West     TEC-AC-10003628      179.9400
#          OFF-BI-10004318      179.9096
# South    FUR-CH-10003746      179.7488
# West     TEC-MA-10000112      179.7300
# Central  OFF-BI-10002867      179.3400
# East     TEC-PH-10000011      179.1104
#          TEC-AC-10004353      178.9200
# West     OFF-AP-10003849      178.9100
# Central  OFF-AP-10000179      178.9010
#          FUR-TA-10001039      178.8384
# East     OFF-PA-10000482      178.3180
# West     FUR-FU-10003708      178.3110
# Central  OFF-PA-10001970      177.9866
# West     TEC-AC-10002001      177.5889
#          FUR-BO-10002213      177.5332
#          TEC-MA-10001031      177.1980
#          TEC-PH-10004977      176.3910
# East     TEC-PH-10000441      176.3860
#          TEC-PH-10001079      176.1052
# West     OFF-PA-10001970      175.9558
# Central  TEC-PH-10001817      175.4200
# West     OFF-AP-10003287      175.3368
# East     FUR-FU-10001290      175.1360
#          FUR-FU-10002253      174.7658
# West     OFF-LA-10001474      174.0210
# East     FUR-FU-10004864      173.7002
#          OFF-ST-10001837      173.6056
# South    OFF-BI-10000977      173.2800
# West     FUR-TA-10001771      173.2350
# Central  FUR-TA-10001771      173.2350
# South    FUR-TA-10004534      172.9560
# East     OFF-PA-10004353      172.6272
# South    FUR-BO-10000711      172.4814
# East     OFF-AP-10004487      172.3984
# West     OFF-ST-10000585      171.8080
# Central  OFF-PA-10004475      171.4752
# South    OFF-PA-10001289      170.9316
# West     OFF-AR-10000380      170.9100
# East     OFF-AP-10002457      170.5795
# South    TEC-PH-10001619      170.5113
# East     TEC-PH-10001619      170.5113
# Central  TEC-PH-10001305      170.4852
#          OFF-PA-10000806      169.6194
#          OFF-PA-10001289      169.3812
#          TEC-AC-10003095      168.9870
# East     FUR-FU-10003535      168.9072
# South    OFF-AP-10001124      168.4384
# Central  OFF-PA-10002377      168.4040
# South    TEC-PH-10000455      168.1855
# East     TEC-PH-10000455      168.1855
# West     OFF-PA-10003790      168.1024
#          OFF-PA-10002222      168.1024
# South    OFF-PA-10001954      168.1024
#          TEC-PH-10003645      168.0744
# West     FUR-TA-10001768      168.0064
#          OFF-PA-10003641      167.7768
# East     FUR-FU-10004091      167.4610
# West     OFF-PA-10001125      167.2920
#          FUR-FU-10003394      166.5048
# Central  TEC-PH-10001580      166.0254
# West     FUR-FU-10002253      165.7484
# South    OFF-ST-10003306      165.7176
# East     TEC-PH-10004165      164.9940
# West     FUR-FU-10004973      164.6616
# Central  FUR-CH-10004875      164.4258
# East     OFF-BI-10002735      164.0018
#          TEC-PH-10001468      163.8180
# West     TEC-PH-10004094      163.7895
# East     TEC-PH-10004389      163.7870
#          FUR-CH-10000988      163.3396
# South    FUR-CH-10000988      163.3396
# Central  TEC-AC-10003911      163.1898
# South    TEC-AC-10003911      163.1898
#          TEC-AC-10002001      163.1898
# East     OFF-EN-10003296      162.8640
# Central  OFF-EN-10003296      162.8640
# South    OFF-PA-10002319      162.4044
# Central  TEC-AC-10001606      161.9838
# East     OFF-PA-10001815      161.4144
# Central  OFF-BI-10001989      161.1264
# West     OFF-PA-10004327      160.9440
#          OFF-PA-10002254      160.9180
# South    OFF-PA-10003892      160.9139
# East     FUR-CH-10004477      160.7496
# South    FUR-TA-10003392      160.1586
# East     OFF-PA-10001144      159.7824
# West     FUR-BO-10004015      159.5867
# Central  TEC-PH-10002310      158.7519
# West     TEC-PH-10004447      158.4486
# East     TEC-PH-10003484      157.4875
# Central  OFF-PA-10000474      157.3536
# South    OFF-BI-10001071      156.7510
# Central  TEC-MA-10003626      156.0470
#          TEC-PH-10001128      155.9896
# West     FUR-FU-10004091      155.8408
# East     FUR-FU-10004017      155.6850
# West     OFF-PA-10001497      155.5368
# South    FUR-CH-10002965      154.7546
# East     OFF-PA-10003656      154.0592
# West     FUR-CH-10002602      153.9996
# East     OFF-PA-10003039      153.3510
# South    OFF-BI-10001597      153.2652
# West     OFF-ST-10002974      152.4950
# East     FUR-BO-10003660      152.4762
# South    OFF-ST-10000689      152.1180
# Central  TEC-MA-10002981      152.0883
# South    OFF-AP-10000828      152.0232
# West     FUR-TA-10001539      151.6608
# East     OFF-BI-10001718      151.6326
# Central  TEC-PH-10000215      150.9840
# West     OFF-PA-10000994      150.9840
# South    TEC-AC-10000023      150.9840
# Central  OFF-ST-10001272      150.5005
# South    TEC-AC-10002926      150.4699
# West     OFF-PA-10003039      150.2530
# Central  OFF-EN-10004206      149.8956
# East     OFF-BI-10001765      149.6448
# South    TEC-PH-10004434      149.5450
# East     OFF-AP-10001293      149.1672
# West     TEC-PH-10002549      149.0676
# East     OFF-BI-10004584      148.5106
# South    TEC-AC-10004571      147.9852
# West     OFF-BI-10004330      147.9200
#          OFF-PA-10002377      147.9100
# East     FUR-CH-10002084      147.5880
#          TEC-PH-10002415      147.4750
# West     OFF-PA-10002923      146.8200
#          OFF-EN-10000056      146.2405
#          OFF-AP-10001205      146.0064
#          TEC-PH-10001578      145.7820
#          TEC-MA-10001148      145.5816
# South    OFF-EN-10002831      145.5570
# East     OFF-PA-10000474      145.3040
# South    FUR-CH-10004626      145.2816
#          FUR-CH-10001797      145.0696
# Central  TEC-PH-10004241      143.9968
#          TEC-PH-10003811      143.9880
#          TEC-AC-10001539      143.9820
# West     TEC-AC-10002567      143.9820
# East     FUR-CH-10003606      143.6288
#          OFF-PA-10000675      143.4650
# South    OFF-EN-10001453      143.3030
#          OFF-ST-10001490      142.7760
# West     OFF-PA-10000482      142.6544
# East     OFF-PA-10004039      142.1892
# Central  TEC-PH-10000441      141.1088
# West     FUR-BO-10004218      140.9800
#          FUR-BO-10004834      140.9568
# East     FUR-CH-10002439      140.8924
# West     OFF-BI-10002794      140.5614
# East     OFF-BI-10002854      140.1500
# West     TEC-MA-10003246      139.9900
# East     OFF-PA-10001033      139.7759
#          OFF-ST-10003470      139.7400
# Central  TEC-PH-10004667      139.0397
# East     FUR-FU-10000629      139.0032
# Central  OFF-BI-10001543      138.2016
# East     OFF-LA-10003510      137.9956
#          OFF-PA-10001357      137.9520
# West     OFF-ST-10003442      137.4408
#          OFF-ST-10001272      137.4135
# East     OFF-BI-10004593      137.2880
# Central  TEC-MA-10004241      137.2640
# South    OFF-PA-10001970      137.1510
# West     OFF-BI-10002133      136.5320
# East     TEC-PH-10002624      136.2971
# Central  TEC-PH-10002660      135.9800
# East     TEC-PH-10002660      135.9800
# West     OFF-PA-10004530      135.0048
# South    TEC-PH-10002834      134.9925
# East     OFF-AP-10000576      134.7400
# South    OFF-AP-10004540      134.6688
# Central  TEC-PH-10002555      134.6540
# East     OFF-PA-10002120      134.6520
#          OFF-PA-10001497      134.6520
# Central  TEC-PH-10001750      134.6196
#          OFF-EN-10000056      134.4168
# West     OFF-AR-10002067      134.1184
# East     OFF-ST-10003282      133.8624
# West     TEC-PH-10003505      133.6320
# Central  OFF-PA-10004071      133.1520
# East     OFF-BI-10002082      133.1200
#          FUR-FU-10001861      132.6960
# South    FUR-BO-10004015      131.9890
# West     OFF-PA-10000157      131.4684
# South    TEC-AC-10004659      131.3820
# Central  OFF-ST-10001932      131.3556
# South    FUR-CH-10004086      131.2785
# Central  TEC-PH-10003505      130.8480
# West     TEC-AC-10001772      130.7943
# Central  OFF-PA-10000100      130.7581
# East     OFF-AR-10001953      130.6206
# West     FUR-CH-10004886      130.4920
#          TEC-PH-10003072      130.4913
# East     OFF-ST-10001476      130.3217
# South    OFF-AP-10002651      130.2885
# West     TEC-MA-10001570      130.2075
# East     TEC-PH-10000730      129.9974
# West     OFF-BI-10004230      129.8704
# South    TEC-AC-10000892      129.6000
# East     TEC-PH-10001557      129.5865
# Central  OFF-ST-10001780      129.5780
# South    FUR-CH-10001891      129.5730
# Central  OFF-EN-10002831      129.3840
# East     OFF-ST-10000877      129.3786
# West     TEC-AC-10003174      129.3480
# East     FUR-BO-10003404      129.2940
# South    OFF-AP-10002118      129.0592
# Central  OFF-PA-10001790      128.7472
# South    FUR-CH-10000847      128.0312
#          TEC-AC-10002567      127.9840
# Central  OFF-ST-10004340      126.8472
# West     OFF-AP-10000576      126.8164
#          OFF-BI-10001597      126.2184
# South    OFF-BI-10003364      126.0144
# East     TEC-CO-10001766      125.9972
#          TEC-PH-10002597      125.9900
# South    TEC-PH-10003691      125.9900
#          TEC-PH-10002660      125.7815
# Central  TEC-PH-10001557      125.7469
# South    FUR-BO-10001519      125.5824
# West     FUR-FU-10001588      125.4740
#          OFF-PA-10003625      125.4690
# East     OFF-PA-10003823      125.4690
# West     TEC-PH-10002584      125.1980
# Central  OFF-ST-10000877      124.9554
#          TEC-PH-10000673      124.7808
# West     TEC-PH-10003012      124.7319
# Central  TEC-AC-10002253      124.6800
#          TEC-AC-10001772      124.5660
# West     OFF-BI-10004519      124.4850
# South    FUR-CH-10004477      124.2156
# Central  OFF-PA-10002581      123.9200
#          TEC-PH-10004977      123.4737
# West     FUR-FU-10002759      123.0768
#          TEC-AC-10004469      123.0460
# South    OFF-BI-10001718      122.8416
#          OFF-PA-10000357      122.3929
#          TEC-AC-10000844      122.3856
# West     OFF-AP-10003040      122.3768
#          OFF-PA-10000659      121.9698
# South    FUR-FU-10001185      121.5549
#          OFF-AR-10000380      121.5360
# East     OFF-EN-10004773      121.4416
# Central  TEC-AC-10004901      120.9758
# East     OFF-AP-10001564      120.9416
#          FUR-CH-10000665      120.7840
#          FUR-BO-10001811      120.3920
# South    TEC-CO-10000971      119.9960
# Central  TEC-PH-10001299      119.9920
# South    TEC-PH-10002447      119.4742
# Central  FUR-CH-10000595      119.2000
# East     TEC-PH-10002555      119.1170
# South    TEC-PH-10002483      118.9965
# Central  OFF-PA-10001033      118.8710
# East     FUR-FU-10004952      118.7858
# South    OFF-BI-10004492      118.7408
#          FUR-CH-10001146      118.7355
# West     FUR-TA-10004086      118.6524
# East     TEC-MA-10004255      118.3704
# South    OFF-EN-10002230      118.3413
# West     TEC-PH-10004531      117.8406
# East     OFF-EN-10000056      117.6147
# West     OFF-BI-10001524      117.4880
# East     OFF-PA-10003395      117.4320
# Central  OFF-PA-10003395      117.4320
# West     FUR-FU-10003039      117.3136
#          TEC-PH-10002310      117.3123
# Central  OFF-ST-10003282      117.1296
# South    FUR-CH-10002647      117.1170
# East     OFF-PA-10001289      116.6676
# South    OFF-PA-10000474      116.5976
#          OFF-SU-10002881      116.5934
#          TEC-AC-10003628      116.3612
# West     TEC-MA-10002428      116.2425
# South    OFF-PA-10001125      116.1750
# West     TEC-MA-10003176      115.8300
#          OFF-BI-10003876      115.5600
# East     TEC-AC-10001539      115.1856
# South    OFF-PA-10001357      114.9600
# West     OFF-PA-10003129      114.9385
# South    OFF-PA-10003228      114.9385
# West     OFF-BI-10004593      114.2320
#          TEC-PH-10001557      114.2281
#          TEC-PH-10001363      113.9980
#          TEC-AC-10001606      113.9886
#          TEC-AC-10000358      113.9700
# East     OFF-EN-10002230      113.3055
#          OFF-EN-10002500      113.1030
# West     TEC-PH-10002103      112.7880
#          FUR-CH-10000988      112.6480
#          OFF-AR-10000937      112.5740
# Central  OFF-AP-10002118      112.4064
# South    FUR-TA-10004607      112.3508
# West     OFF-AP-10004540      112.2240
#          OFF-ST-10003123      111.8544
#          OFF-ST-10003470      111.7920
#          OFF-AP-10001469      111.7828
#          TEC-PH-10002398      111.4900
#          OFF-AR-10002671      111.3024
# South    TEC-PH-10004006      111.2940
# West     OFF-BI-10002735      111.1644
#          OFF-PA-10004071      110.9600
# East     OFF-PA-10000157      110.0898
# South    OFF-AR-10000538      109.7850
# East     OFF-AP-10001154      109.7226
#          TEC-PH-10002075      109.6113
# Central  TEC-PH-10001578      109.3365
# West     OFF-BI-10002867      108.7996
# East     OFF-BI-10002867      108.7996
# West     OFF-ST-10000025      108.7902
# South    OFF-PA-10001144      108.7408
# East     OFF-PA-10000062      107.7216
# West     OFF-PA-10004475      107.7216
# South    OFF-PA-10001790      107.6096
#          FUR-FU-10002045      107.5932
# East     TEC-PH-10003885      107.5637
# West     FUR-CH-10000595      107.2800
# Central  FUR-TA-10003954      106.6248
# West     OFF-PA-10001144      106.5216
#          FUR-BO-10003894      106.4700
# Central  FUR-CH-10003817      106.2950
# East     FUR-CH-10003817      106.2950
# West     TEC-PH-10003580      106.1242
#          FUR-FU-10001488      105.9800
#          OFF-PA-10000241      105.3320
#          OFF-ST-10003805      105.2750
#          OFF-BI-10001543      105.0908
#          OFF-AP-10000891      104.8960
#          FUR-FU-10000758      104.8608
# Central  FUR-TA-10004575      104.7528
# West     TEC-AC-10001284      104.6808
# South    OFF-ST-10002974      104.5680
# West     TEC-MA-10002073      103.9992
#          OFF-AP-10001005      103.8180
# South    OFF-AP-10001271      103.4894
#          TEC-AC-10001432      103.1580
# West     OFF-ST-10003058      102.8775
# East     OFF-PA-10002923      102.7740
# West     TEC-PH-10002033      102.5352
# Central  OFF-PA-10003302      102.4216
# West     OFF-BI-10001670      101.7900
#          OFF-AP-10002867      101.7600
# East     OFF-AP-10002578      101.7536
#          FUR-FU-10001185      101.4504
#          TEC-PH-10002922      101.3940
#          FUR-FU-10000277      101.1264
# South    TEC-PH-10001615      100.8852
# West     TEC-PH-10000441      100.7920
# Central  OFF-ST-10000036      100.7658
#          TEC-PH-10003171      100.6880
# West     OFF-PA-10000418      100.6560
#          OFF-LA-10003923      100.6400
#          OFF-EN-10002504      100.5660
# East     OFF-PA-10000100      100.4255
#          OFF-BI-10004492      100.4244
# West     OFF-LA-10002762      100.1147
#          TEC-PH-10001918      100.0728
# East     FUR-CH-10002647       99.3720
# West     TEC-PH-10004165       98.9964
#          OFF-BI-10003684       98.9550
# South    OFF-PA-10003641       98.6612
#          TEC-PH-10002890       98.6232
# Central  TEC-AC-10001714       98.5283
# West     OFF-PA-10004039       98.5248
# Central  FUR-TA-10004147       98.5248
# South    TEC-PH-10004389       98.2722
# West     TEC-AC-10000158       98.2527
#          OFF-BI-10002498       98.1225
# East     OFF-PA-10004092       97.8800
# South    FUR-TA-10003473       97.7938
# West     OFF-PA-10000483       97.5870
#          OFF-PA-10000167       97.5870
# Central  TEC-PH-10001809       97.4675
#          FUR-BO-10002916       97.4586
# West     TEC-MA-10002859       97.1892
# South    OFF-AP-10000159       97.1348
# Central  OFF-PA-10000482       97.1264
# West     OFF-PA-10003127       97.0784
# East     OFF-PA-10002254       97.0784
# West     TEC-PH-10003645       96.9660
# Central  FUR-TA-10002855       96.5844
# East     OFF-AP-10001271       96.3522
# South    OFF-PA-10002254       96.0232
# Central  TEC-AC-10004171       95.9904
# West     TEC-PH-10001425       95.9880
#          TEC-PH-10000576       95.8930
# East     TEC-AC-10002647       95.7600
# West     FUR-FU-10000308       95.7572
# East     FUR-FU-10000521       94.7682
# Central  TEC-PH-10003484       94.4925
# West     OFF-BI-10004308       94.4100
# South    OFF-AP-10002534       94.2784
# Central  TEC-AC-10002473       94.2216
# South    OFF-PA-10002558       93.8840
# East     OFF-ST-10001496       93.6988
# Central  TEC-AC-10001990       93.5844
#          OFF-PA-10003641       93.3852
# West     FUR-FU-10002298       93.2232
# East     TEC-AC-10003590       93.2040
# West     FUR-FU-10004845       92.9700
# East     FUR-CH-10002965       92.4508
# Central  OFF-PA-10001878       92.4399
# West     FUR-FU-10003192       92.3936
# East     TEC-PH-10002115       92.3860
# West     FUR-FU-10001876       92.2432
#          OFF-PA-10003134       92.2368
# South    OFF-PA-10004327       91.9680
# East     OFF-PA-10001281       91.9680
#          OFF-PA-10003228       91.9508
# South    OFF-PA-10003129       91.9508
# Central  OFF-PA-10003228       91.9508
# West     OFF-ST-10000943       91.9156
# East     TEC-AC-10000844       91.7892
# West     TEC-AC-10001956       91.1240
#          TEC-PH-10003174       90.9930
#          FUR-CH-10000015       90.9720
# Central  OFF-AP-10000576       90.7350
# East     OFF-AP-10001394       90.7200
# West     OFF-PA-10001289       90.6984
# East     TEC-PH-10003589       90.6696
# South    FUR-CH-10000665       90.5880
#          TEC-MA-10000029       90.2871
# West     TEC-AC-10000865       90.2700
# East     TEC-CO-10004202       89.9970
# South    TEC-AC-10003116       89.9925
# Central  TEC-PH-10003437       89.9880
# West     TEC-AC-10004595       89.9640
# South    OFF-BI-10002082       89.8560
# West     TEC-AC-10001539       89.5888
# South    OFF-AP-10002578       89.0344
#          TEC-AC-10001109       88.7704
# West     OFF-PA-10001977       88.7680
# South    FUR-BO-10001608       88.7250
# Central  TEC-PH-10002415       88.4850
# West     FUR-FU-10004018       88.4466
# East     TEC-AC-10003095       88.3932
# West     OFF-AP-10004980       88.3536
# East     OFF-LA-10002762       88.3365
# West     TEC-AC-10000057       88.1706
#          TEC-AC-10004001       88.1295
# South    OFF-PA-10003395       88.0740
# East     TEC-PH-10003215       88.0530
# West     TEC-PH-10002680       87.9960
# Central  TEC-AC-10002402       87.9890
#          OFF-AR-10000380       87.3540
# South    FUR-CH-10004495       87.2842
# West     FUR-CH-10004675       87.2320
# South    OFF-AP-10003590       87.1800
#          OFF-AP-10001563       86.9582
# West     FUR-CH-10000785       86.8704
# East     TEC-PH-10002170       86.7876
# West     OFF-PA-10001363       86.5740
#          OFF-BI-10002082       86.5280
# South    OFF-PA-10004381       86.4720
#          TEC-PH-10003811       86.3928
# East     TEC-AC-10000736       86.3892
# West     TEC-PH-10002468       85.6737
# Central  TEC-AC-10000109       85.1048
# West     OFF-PA-10000380       85.0680
#          FUR-FU-10001473       85.0360
# South    OFF-PA-10003656       84.9436
# West     FUR-FU-10004848       84.8548
# Central  OFF-PA-10000157       84.5154
#          OFF-BI-10000977       84.5120
# West     FUR-CH-10000309       84.5020
#          TEC-PH-10002922       84.4950
# Central  TEC-PH-10000526       84.4712
# West     OFF-BI-10002854       84.0900
# East     OFF-PA-10001954       84.0512
# Central  TEC-AC-10003610       83.9860
# East     OFF-AR-10002135       83.8680
# West     FUR-FU-10000397       83.7480
# East     FUR-FU-10001095       83.6768
# South    OFF-PA-10001019       83.5164
# Central  TEC-PH-10002262       83.3140
#          OFF-SU-10002881       83.2810
# West     TEC-PH-10002563       83.1534
# Central  TEC-AC-10003023       83.1180
# South    TEC-AC-10003289       82.7586
# East     OFF-AP-10004336       82.5920
# South    FUR-FU-10001591       82.4720
# West     FUR-BO-10002598       82.3368
# East     OFF-PA-10000806       82.2906
# Central  OFF-PA-10000565       82.2906
#          FUR-FU-10000308       82.0776
# South    FUR-FU-10000308       82.0776
#          OFF-BI-10000069       81.9546
# West     OFF-BI-10003364       81.6760
# Central  OFF-ST-10003208       81.6570
# East     OFF-AR-10002987       81.3440
# South    FUR-CH-10002084       81.1734
# East     OFF-EN-10003040       81.1270
# West     OFF-ST-10003816       81.0474
#          OFF-BI-10002225       80.9088
# South    FUR-CH-10003846       80.7840
# East     FUR-CH-10000553       80.7772
# Central  OFF-BI-10002735       80.6285
# South    TEC-AC-10000109       80.6256
# Central  TEC-AC-10004859       80.4080
# West     FUR-TA-10001950       80.3682
# East     OFF-BI-10001510       80.2200
# South    OFF-BI-10000315       80.1378
#          FUR-CH-10003199       79.9056
# East     FUR-CH-10003199       79.9056
#          OFF-PA-10001977       79.8912
# Central  FUR-FU-10004188       79.7940
#          OFF-PA-10001497       79.6920
# East     OFF-PA-10000176       79.6740
# West     TEC-AC-10000580       79.1901
# East     OFF-EN-10004386       79.1670
# Central  TEC-AC-10004975       79.1640
# West     OFF-BI-10000977       79.0400
# East     TEC-PH-10002103       78.9516
#          OFF-EN-10003001       78.9412
# South    OFF-EN-10003001       78.9412
# West     OFF-EN-10002230       78.8942
# East     TEC-PH-10004434       78.8510
# South    FUR-FU-10003773       78.7248
#          OFF-AP-10000891       78.6720
# Central  OFF-BI-10003656       78.1954
# West     FUR-CH-10002774       77.9994
#          TEC-PH-10002496       77.9950
# East     OFF-BI-10001721       77.8232
# West     FUR-BO-10003404       77.5764
# South    TEC-AC-10002473       77.4774
# East     OFF-BI-10003984       77.3163
# West     FUR-CH-10003746       77.0352
# South    OFF-LA-10002762       76.5583
# Central  TEC-PH-10003885       76.5484
# East     FUR-FU-10001986       76.4700
# South    FUR-CH-10000422       76.4316
# Central  OFF-BI-10000666       76.4000
#          FUR-FU-10001185       76.0878
# East     OFF-PA-10000919       75.9696
# West     OFF-ST-10002370       75.9345
# South    FUR-FU-10001473       75.7896
# Central  OFF-AP-10002311       75.6910
# East     FUR-FU-10003806       75.6800
# South    FUR-FU-10003806       75.6800
#          FUR-TA-10004086       75.6624
# West     TEC-PH-10000895       75.5958
# East     TEC-AC-10002637       75.5958
# West     TEC-PH-10003691       75.5940
#          TEC-PH-10001580       75.5888
#          TEC-AC-10001109       75.5748
# Central  FUR-CH-10004853       75.4900
# West     TEC-AC-10000682       75.4845
# East     OFF-LA-10004544       75.4800
# South    FUR-TA-10003715       75.3732
# West     OFF-BI-10004001       75.3168
#          OFF-PA-10004101       75.1680
# Central  TEC-AC-10004353       74.9700
# South    FUR-FU-10004748       74.8098
# West     FUR-FU-10004748       74.8098
# South    FUR-CH-10004287       74.5740
# East     OFF-AR-10003903       74.5654
# South    FUR-CH-10002439       74.5216
# East     OFF-LA-10001158       74.5200
# West     OFF-ST-10000736       74.5016
# Central  OFF-ST-10001837       74.4024
# West     OFF-ST-10000036       74.0925
#          TEC-PH-10002415       73.7375
# East     OFF-EN-10004483       73.6490
# West     OFF-PA-10001295       73.6036
# East     TEC-PH-10002468       73.4346
# West     OFF-PA-10004092       73.4100
# East     OFF-PA-10002499       73.4100
#          OFF-BI-10000666       73.3440
# West     FUR-CH-10002758       73.1940
# South    TEC-PH-10001944       72.9750
# West     TEC-PH-10001944       72.9750
# South    OFF-AP-10002684       72.9480
# West     FUR-FU-10002813       72.8640
#          TEC-AC-10001714       72.5998
# East     FUR-CH-10002602       72.4704
# South    OFF-BI-10002026       72.4038
# Central  OFF-PA-10000176       72.0860
# West     TEC-PH-10001051       71.9928
#          TEC-PH-10004586       71.9900
# East     TEC-PH-10000193       71.7288
# West     OFF-ST-10003638       71.6652
#          TEC-AC-10002006       71.6352
# South    OFF-EN-10004483       71.6119
# East     OFF-PA-10000659       71.5734
#          OFF-ST-10003692       71.5375
#          FUR-FU-10001876       71.4560
# South    TEC-AC-10000420       71.3898
# East     TEC-PH-10000586       71.2692
#          OFF-EN-10000483       71.0650
#          TEC-AC-10001109       70.7764
# West     FUR-FU-10004460       70.7220
#          OFF-LA-10001074       70.6692
#          OFF-BI-10003007       70.5796
#          OFF-PA-10002986       70.5408
# East     TEC-AC-10004114       70.5028
# West     OFF-PA-10002005       70.5024
# East     OFF-AP-10001563       70.4410
# West     OFF-PA-10002968       70.3472
# Central  OFF-PA-10000595       70.3472
# West     FUR-BO-10004357       70.3430
# East     FUR-FU-10004960       70.3188
# Central  TEC-AC-10004469       70.3120
# East     OFF-LA-10001474       70.2190
# South    FUR-CH-10001394       70.1980
# West     TEC-AC-10004814       70.0977
# East     TEC-CO-10001943       69.9965
# Central  OFF-EN-10003055       69.9650
#          OFF-PA-10003823       69.7050
# South    FUR-BO-10003441       69.6762
# Central  OFF-LA-10003923       69.5600
# East     OFF-ST-10000604       69.5200
# West     OFF-ST-10000604       69.5200
#          TEC-PH-10003215       69.4840
# East     FUR-CH-10003981       69.3846
# Central  OFF-PA-10001815       69.1776
# West     TEC-AC-10004568       69.1353
# East     TEC-PH-10000526       69.1128
#          TEC-PH-10004614       69.0000
#          OFF-PA-10003129       68.9631
# West     OFF-PA-10003892       68.9631
# East     FUR-FU-10000076       68.7312
# Central  TEC-AC-10003116       68.6925
# South    OFF-AR-10002240       68.6868
# Central  OFF-AP-10002350       68.5776
# West     TEC-PH-10001254       68.5746
# Central  FUR-CH-10003061       68.3924
# South    FUR-FU-10001468       68.3920
# East     OFF-AR-10000380       68.3640
# West     OFF-AP-10001394       68.0400
#          FUR-CH-10004853       67.9410
# East     TEC-AC-10001013       67.6599
#          TEC-PH-10004536       67.4950
# West     OFF-BI-10004224       67.2800
#          OFF-BI-10001294       67.2750
# South    TEC-PH-10001425       67.1916
# West     FUR-CH-10001891       67.1860
# Central  TEC-MA-10001016       67.1790
# South    TEC-PH-10003505       66.8160
# West     OFF-AP-10002765       66.7548
# East     OFF-BI-10000962       66.7070
#          OFF-ST-10002276       66.6880
# West     TEC-PH-10001079       66.6344
# East     OFF-PA-10001125       66.6070
# Central  OFF-LA-10003498       66.6000
# West     OFF-LA-10003498       66.6000
#          FUR-FU-10001861       66.5420
# Central  TEC-AC-10004761       66.1095
# West     OFF-AP-10004336       66.0736
# East     TEC-AC-10002926       65.9868
#          TEC-AC-10000171       65.9813
# South    TEC-PH-10002538       65.9634
# West     TEC-PH-10003095       65.8500
# Central  TEC-PH-10003095       65.8500
# East     OFF-BI-10004001       65.7744
# West     FUR-TA-10003008       65.7180
# East     FUR-CH-10000422       65.5128
# West     OFF-AR-10004648       65.2860
# East     OFF-PA-10000241       65.0580
# South    OFF-ST-10000060       64.9800
# West     TEC-AC-10001990       64.7892
# East     FUR-CH-10004754       64.7568
# Central  OFF-PA-10001019       64.7352
#          TEC-AC-10003174       64.6740
# East     TEC-AC-10003174       64.6740
# West     TEC-PH-10001700       64.6702
# East     TEC-PH-10002538       64.4470
# Central  TEC-PH-10002170       64.3908
# West     OFF-AP-10002998       64.3302
# Central  TEC-AC-10003590       64.2072
#          OFF-BI-10003876       64.2000
# South    TEC-AC-10001114       63.9840
# Central  TEC-AC-10001114       63.9840
# West     FUR-FU-10003268       63.9680
# East     OFF-ST-10003123       63.9168
# West     OFF-AR-10003903       63.9132
# Central  OFF-PA-10004082       63.8400
# West     TEC-AC-10000710       63.7776
# East     OFF-PA-10001295       63.7392
#          OFF-AR-10001955       63.4880
#          OFF-ST-10000777       63.4368
# West     OFF-ST-10000777       63.4368
# East     OFF-BI-10004236       63.4176
# Central  OFF-AR-10001953       63.3312
# East     OFF-PA-10002713       63.2960
# West     OFF-PA-10003022       63.2270
# East     FUR-FU-10002878       63.2256
# Central  FUR-FU-10000293       63.1740
# West     FUR-TA-10004154       63.1070
#          OFF-ST-10001590       63.0864
#          TEC-AC-10003063       63.0000
#          TEC-PH-10003484       62.9950
# Central  TEC-PH-10002726       62.9880
# South    TEC-PH-10001819       62.9860
# Central  FUR-TA-10002356       62.9064
# South    OFF-EN-10000927       62.8075
# East     OFF-EN-10000927       62.8075
# West     TEC-AC-10004864       62.7972
# South    OFF-AP-10002670       62.5320
# West     FUR-FU-10004960       62.5056
# Central  TEC-PH-10002890       62.4312
#          TEC-AC-10004518       62.4000
# South    FUR-FU-10002878       62.3712
#          OFF-EN-10001335       62.3580
#          FUR-FU-10003192       62.1880
# Central  TEC-PH-10000562       62.1544
# South    OFF-PA-10004071       62.1376
# West     OFF-PA-10001509       61.7550
#          FUR-FU-10004093       61.6140
#          OFF-PA-10003441       61.4304
# East     OFF-EN-10003286       61.1892
# Central  OFF-EN-10000483       61.0000
#          TEC-PH-10001254       60.9552
# West     OFF-AP-10000692       60.8100
#          FUR-FU-10002501       60.7984
#          TEC-AC-10001552       60.7194
# South    FUR-TA-10001520       60.6645
# East     FUR-CH-10004875       60.5030
# South    TEC-PH-10000441       60.4752
# East     FUR-BO-10002824       60.3920
# West     FUR-CH-10002647       60.3330
# East     TEC-MA-10003173       60.3060
# South    OFF-PA-10000675       60.2553
# Central  OFF-BI-10001718       60.1412
# East     TEC-CO-10000971       59.9980
# West     FUR-FU-10001475       59.7856
# East     OFF-AP-10004708       59.7542
# South    FUR-FU-10000076       59.7402
# East     OFF-BI-10001524       59.5832
#          OFF-ST-10000136       59.5500
#          OFF-ST-10004946       59.5100
# South    OFF-PA-10000312       59.3840
#          FUR-FU-10004270       59.1110
# West     FUR-FU-10000023       58.9000
#          OFF-LA-10004545       58.8910
# South    OFF-AP-10001205       58.8384
# East     FUR-FU-10002045       58.6872
# West     FUR-FU-10004090       58.6872
# East     TEC-PH-10001300       58.6600
# West     OFF-AP-10000055       58.4640
# East     FUR-FU-10000308       58.4492
# West     OFF-ST-10000464       58.3968
#          FUR-CH-10004698       58.3056
#          FUR-BO-10004409       58.2036
# East     TEC-PH-10004093       57.9474
# West     OFF-AP-10004708       57.8512
# East     OFF-SU-10002573       57.8490
#          TEC-AC-10002399       57.8208
#          TEC-PH-10000923       57.5616
# ...
# Central  FUR-CH-10002965      -36.1764
#          FUR-BO-10002824      -36.2352
# South    FUR-BO-10001337      -36.2940
# Central  FUR-FU-10004909      -36.3600
# West     FUR-FU-10004904      -36.4704
# Central  FUR-BO-10003034      -36.6744
# East     FUR-TA-10001520      -37.1124
#          OFF-ST-10001128      -37.7332
# Central  OFF-BI-10002794      -38.1114
#          OFF-AP-10002457      -38.7205
# West     FUR-CH-10002372      -38.8704
# East     OFF-ST-10001370      -39.0390
# West     FUR-CH-10001973      -39.9528
#          TEC-PH-10001448      -39.9920
#          OFF-BI-10002429      -40.1808
#          FUR-CH-10004289      -40.3116
# Central  OFF-BI-10000962      -40.3496
#          OFF-ST-10001522      -40.4756
#          FUR-FU-10003553      -41.2620
# West     OFF-BI-10003676      -41.3952
# Central  FUR-BO-10003441      -41.4018
# East     FUR-BO-10003034      -41.9136
# Central  FUR-BO-10002268      -42.1096
#          FUR-FU-10003930      -42.4926
#          FUR-CH-10002647      -42.5880
# South    OFF-BI-10003876      -42.8000
# West     FUR-CH-10000513      -42.8967
# Central  FUR-TA-10001866      -43.0296
# West     FUR-CH-10000422      -43.6752
# Central  FUR-FU-10000222      -43.8480
#          OFF-ST-10001418      -43.9056
#          FUR-CH-10001146      -44.2298
#          OFF-ST-10003994      -44.2350
#          FUR-TA-10002530      -45.2940
#          FUR-FU-10003708      -45.4875
#          FUR-FU-10001475      -45.7184
# West     FUR-TA-10002774      -46.2390
# Central  FUR-FU-10001095      -46.6048
# East     TEC-PH-10001305      -47.0304
# Central  FUR-TA-10003469      -47.1750
#          FUR-CH-10001545      -47.8716
# East     FUR-FU-10004904      -48.6272
# West     FUR-TA-10004607      -48.7839
# East     FUR-TA-10004607      -48.7839
#          FUR-TA-10001676      -48.8730
#          TEC-PH-10004080      -48.9528
# Central  FUR-CH-10000422      -49.1346
# West     TEC-PH-10004188      -49.4802
# Central  OFF-BI-10002082      -49.9200
#          FUR-CH-10001215      -50.0980
# East     TEC-PH-10003092      -50.5890
#          OFF-BI-10003007      -51.1896
# South    OFF-BI-10003091      -51.5154
# East     FUR-CH-10000015      -51.9840
#          OFF-ST-10003479      -52.5690
# Central  FUR-FU-10002759      -52.7472
#          OFF-AP-10002578      -52.8336
#          OFF-AP-10003287      -53.0088
# East     FUR-BO-10003433      -53.2856
# West     FUR-TA-10003954      -53.3124
#          FUR-TA-10001520      -53.5275
# Central  FUR-FU-10004864      -53.7096
# East     OFF-BI-10001658      -53.8272
#          FUR-CH-10003396      -53.8860
# Central  FUR-CH-10002602      -54.3528
#          OFF-AP-10000240      -54.5496
# East     FUR-CH-10000513      -54.5958
# South    OFF-ST-10001418      -54.8820
# East     TEC-AC-10001142      -55.3000
# Central  OFF-BI-10002353      -55.5840
#          FUR-FU-10003247      -55.5970
# South    TEC-MA-10002178      -55.6560
# Central  FUR-CH-10004983      -56.3430
# South    FUR-TA-10000617      -56.8875
# East     OFF-ST-10002344      -58.3056
# Central  FUR-CH-10003396      -58.5048
# East     TEC-PH-10002200      -58.9228
#          OFF-BI-10003719      -59.8800
# West     OFF-ST-10001370      -60.3330
#          TEC-PH-10003800      -60.4086
#          FUR-CH-10003833      -60.9800
# East     FUR-BO-10002853      -61.4550
# Central  OFF-BI-10000474      -61.5552
#          FUR-FU-10002703      -61.8720
# East     FUR-TA-10004086      -61.9056
#          TEC-PH-10002584      -62.5990
#          FUR-CH-10004860      -62.6076
#          FUR-TA-10001307      -62.9010
# Central  OFF-ST-10003716      -63.0056
#          FUR-CH-10003535      -63.4192
# East     OFF-ST-10001713      -63.5880
# Central  OFF-ST-10000563      -63.9600
#          FUR-TA-10001676      -63.9792
# West     OFF-ST-10001128      -64.3684
# East     TEC-PH-10000141      -64.6702
# South    OFF-ST-10000736      -64.7840
# Central  OFF-ST-10000025      -64.8924
#          FUR-FU-10004306      -66.0620
# East     OFF-ST-10002756      -66.3019
# South    OFF-BI-10002429      -66.9680
# Central  FUR-FU-10004748      -67.1370
#          OFF-AP-10004136      -67.6170
# South    FUR-BO-10002213      -67.6704
# Central  FUR-FU-10004973      -67.8240
# South    OFF-ST-10000676      -67.8510
# East     TEC-PH-10003645      -67.8762
# Central  OFF-ST-10002344      -68.0232
# South    FUR-CH-10002044      -68.1096
# West     FUR-CH-10003968      -68.1408
# Central  FUR-CH-10002126      -68.3144
#          OFF-BI-10001575      -69.3952
#          OFF-ST-10003470      -69.8700
# West     TEC-PH-10003555      -70.3494
# Central  OFF-BI-10003684      -70.3680
#          FUR-BO-10004360      -70.8312
#          OFF-AP-10002403      -71.2962
# East     TEC-MA-10002694      -71.3958
# Central  FUR-TA-10002622      -71.8116
# South    OFF-ST-10004123      -72.7840
# East     FUR-CH-10003833      -73.1760
# West     OFF-ST-10004804      -73.6164
# East     FUR-BO-10004709      -74.2144
# South    TEC-AC-10002637      -75.5958
# Central  FUR-FU-10000277      -75.8448
#          TEC-PH-10000038      -76.7088
#          FUR-FU-10004848      -77.6250
#          OFF-AP-10004708      -77.6424
#          FUR-FU-10004597      -78.2550
#          FUR-BO-10004690      -78.3636
#          FUR-FU-10003919      -78.5088
# East     OFF-ST-10002790      -79.0195
# Central  OFF-BI-10000309      -80.2094
# South    FUR-BO-10003965      -81.4410
# West     FUR-CH-10000863      -81.5292
# East     FUR-TA-10002622      -82.0704
# Central  OFF-BI-10000632      -83.3472
# East     OFF-SU-10000157      -83.5170
# Central  OFF-BI-10002854      -84.0900
# East     TEC-PH-10001817      -85.9200
#          FUR-CH-10000863      -86.0586
# Central  OFF-BI-10001098      -86.1614
#          OFF-AP-10004336      -87.1488
#          OFF-ST-10004804      -88.0308
# East     OFF-ST-10002554      -88.0380
#          FUR-TA-10004152      -88.7040
#          FUR-BO-10001798      -89.0664
#          FUR-BO-10002213      -90.1764
# Central  FUR-BO-10001811      -90.2940
#          FUR-CH-10002044      -90.3762
#          OFF-AP-10003040      -90.7740
# South    OFF-ST-10001522      -91.9900
# East     TEC-PH-10002824      -92.6955
# Central  OFF-BI-10002133      -92.8760
# East     TEC-PH-10000562      -93.2316
#          FUR-BO-10004409      -93.6936
# Central  FUR-FU-10004952      -95.2476
#          FUR-TA-10001705      -95.6700
#          FUR-CH-10002331      -96.1146
# West     OFF-BI-10000778      -96.7840
# Central  TEC-MA-10001972      -97.7200
#          FUR-TA-10003008      -98.5770
# West     FUR-BO-10002202      -98.8018
# East     OFF-BI-10002133      -98.8680
# West     FUR-TA-10000198      -99.1764
# Central  FUR-TA-10000849      -99.2664
#          FUR-TA-10003569     -100.2450
# South    OFF-BI-10004224     -100.9200
#          FUR-TA-10001705     -102.0480
# West     FUR-BO-10003660     -103.8606
#          FUR-CH-10003396     -103.9230
# East     FUR-TA-10002041     -103.9882
# Central  OFF-BI-10001597     -104.9088
# East     FUR-TA-10003469     -105.4500
# Central  FUR-FU-10004622     -105.6900
# South    FUR-TA-10001039     -105.7554
# East     FUR-TA-10001086     -106.3930
# Central  OFF-AP-10003849     -107.3460
# East     TEC-PH-10001299     -107.9928
#          TEC-PH-10001128     -107.9928
# West     FUR-CH-10001714     -108.6408
# Central  OFF-AP-10004980     -108.8304
# East     FUR-CH-10002880     -110.6910
# South    TEC-MA-10004002     -111.4995
#          OFF-BI-10004593     -113.1840
# West     FUR-CH-10003774     -114.6348
#          FUR-BO-10001337     -114.9310
#          FUR-TA-10004575     -116.3920
# Central  FUR-BO-10000112     -117.8820
# East     FUR-TA-10003392     -118.0116
# Central  FUR-TA-10001768     -118.1295
# East     FUR-TA-10003569     -120.2940
# Central  FUR-CH-10000513     -120.8907
#          TEC-MA-10002210     -121.2705
# East     TEC-PH-10004667     -121.4910
#          TEC-PH-10001795     -121.5983
#          FUR-TA-10000617     -122.8770
#          FUR-CH-10001482     -123.1212
# Central  OFF-AP-10004487     -126.8592
# East     FUR-CH-10003298     -127.0506
# Central  OFF-BI-10001524     -127.5584
#          OFF-ST-10001511     -129.3000
# South    FUR-CH-10003298     -129.6702
# Central  FUR-TA-10004607     -130.0904
#          OFF-AP-10001563     -130.1944
#          OFF-AP-10001564     -130.2448
#          OFF-ST-10003656     -130.5464
# East     FUR-TA-10002356     -131.0550
# Central  OFF-AP-10000891     -131.1200
# East     OFF-ST-10001809     -131.1518
# Central  FUR-TA-10004442     -131.9510
# East     FUR-TA-10003748     -131.9594
#          TEC-PH-10002680     -131.9940
# West     OFF-ST-10002743     -134.0952
# Central  OFF-AP-10001947     -135.0184
#          FUR-FU-10000193     -135.1168
# West     FUR-TA-10002607     -136.1088
# Central  FUR-BO-10001601     -136.2192
#          OFF-BI-10002429     -136.3712
#          FUR-BO-10003893     -137.9760
#          OFF-ST-10002574     -138.1400
#          FUR-BO-10004218     -138.1604
# West     FUR-CH-10003956     -138.4110
# East     FUR-BO-10004695     -139.3546
#          FUR-TA-10000849     -140.1408
# West     FUR-TA-10001039     -141.0072
# East     FUR-TA-10000198     -143.2548
# West     FUR-BO-10003450     -143.7904
# Central  OFF-BI-10000778     -145.1760
# South    OFF-BI-10004584     -145.3508
# Central  OFF-ST-10004123     -145.5680
# East     FUR-CH-10003774     -146.4778
# South    FUR-TA-10003008     -147.8655
# East     FUR-TA-10003008     -147.8655
# West     FUR-CH-10001190     -149.5890
# Central  FUR-TA-10001889     -152.7156
# East     FUR-TA-10002607     -153.1224
# Central  FUR-TA-10004086     -154.7640
# West     FUR-TA-10001086     -155.0298
#          FUR-CH-10004860     -155.5092
# East     FUR-BO-10004015     -155.9870
#          FUR-TA-10002645     -157.0095
#          OFF-BI-10004330     -157.1650
# Central  FUR-FU-10000723     -157.4292
# West     FUR-CH-10000225     -157.9110
# East     FUR-TA-10001039     -158.2032
# Central  FUR-TA-10000688     -159.0305
# East     FUR-BO-10004467     -159.9840
# Central  FUR-TA-10002774     -160.2952
# West     FUR-TA-10004289     -161.8750
#          FUR-CH-10000229     -162.5880
# Central  FUR-CH-10002880     -164.8066
# East     TEC-MA-10003589     -164.9538
# West     FUR-CH-10002880     -166.0365
#          OFF-ST-10001097     -167.2700
# South    FUR-TA-10001095     -167.3184
# East     OFF-BI-10003650     -168.3136
# South    OFF-BI-10000778     -169.3720
# West     FUR-TA-10003238     -170.8038
# East     FUR-FU-10001468     -170.9800
#          TEC-MA-10004521     -172.4925
# Central  FUR-TA-10002228     -173.3472
# West     FUR-BO-10000468     -175.8596
# Central  OFF-AP-10004233     -177.2232
# West     FUR-TA-10002041     -177.4971
# Central  FUR-CH-10001973     -177.5680
#          OFF-AP-10000055     -178.6400
#          OFF-AP-10003217     -178.9668
#          OFF-AP-10002867     -179.7760
#          FUR-FU-10004904     -182.3520
# South    FUR-CH-10003312     -182.6370
# Central  FUR-TA-10001539     -184.8366
#          OFF-AP-10000026     -186.5682
# West     OFF-ST-10001809     -186.8464
# Central  FUR-TA-10002607     -189.9852
#          FUR-BO-10003965     -190.0290
# West     FUR-BO-10001567     -190.8522
#          FUR-BO-10001608     -191.6460
# East     FUR-TA-10004575     -192.0468
#          FUR-TA-10001932     -192.3840
# Central  FUR-FU-10003773     -194.8240
#          OFF-BI-10002026     -197.5554
# East     FUR-BO-10001972     -199.6170
#          OFF-BI-10004224     -201.8400
# West     FUR-TA-10001889     -203.6208
# South    OFF-SU-10000646     -204.3145
# East     FUR-TA-10004175     -204.6360
# West     FUR-TA-10003469     -205.3500
# East     OFF-BI-10004632     -205.4325
# South    FUR-TA-10001857     -205.7055
# East     FUR-CH-10002024     -210.2940
#          FUR-BO-10004218     -211.4700
#          FUR-TA-10003715     -213.5574
# Central  FUR-TA-10000577     -219.3723
#          FUR-CH-10003298     -220.0464
# East     FUR-BO-10003272     -220.9800
#          FUR-BO-10000780     -221.0780
#          TEC-PH-10002789     -223.0657
#          TEC-PH-10003580     -225.2432
#          OFF-SU-10000646     -237.9663
# Central  FUR-FU-10002298     -239.7168
#          FUR-FU-10003394     -240.6624
# East     FUR-BO-10004357     -241.1760
# Central  OFF-AP-10001242     -241.4400
#          FUR-FU-10002116     -247.4850
# West     FUR-BO-10002268     -247.7988
# South    FUR-TA-10002903     -249.3216
# West     TEC-MA-10003337     -251.9874
# Central  TEC-MA-10003353     -251.9958
#          FUR-FU-10002918     -252.0146
#          OFF-AP-10002684     -255.3180
# South    OFF-BI-10004519     -257.2690
# East     FUR-CH-10003312     -258.5016
# West     TEC-PH-10000038     -263.0016
#          FUR-TA-10003715     -263.8062
# Central  TEC-MA-10000488     -263.9967
#          FUR-TA-10001932     -269.3376
# South    TEC-MA-10001856     -272.5800
# Central  FUR-TA-10002041     -277.8995
# West     FUR-TA-10002530     -279.3130
# Central  TEC-MA-10004679     -279.6780
# South    OFF-ST-10004459     -281.5050
# East     FUR-TA-10002228     -283.3560
#          FUR-TA-10004442     -283.9815
# Central  FUR-CH-10003774     -293.8654
# East     FUR-TA-10000577     -295.9785
# Central  FUR-CH-10000229     -298.0780
# West     OFF-SU-10002881     -299.8116
# East     TEC-PH-10001530     -305.1801
#          FUR-TA-10002903     -306.4578
# Central  FUR-TA-10002533     -306.7050
#          FUR-CH-10000863     -311.0188
#          FUR-BO-10004834     -317.1528
# East     TEC-MA-10000904     -319.1916
# Central  OFF-AP-10000390     -329.2920
#          OFF-ST-10002743     -336.3744
# South    OFF-BI-10004390     -336.7840
# Central  FUR-TA-10004534     -337.6760
# East     FUR-TA-10002530     -339.7050
# West     FUR-TA-10000849     -347.4324
# Central  FUR-FU-10000576     -356.7280
# West     FUR-BO-10003546     -363.5280
# East     TEC-PH-10002645     -374.9925
# West     FUR-TA-10002356     -377.4384
#          TEC-MA-10003356     -386.9570
#          OFF-BI-10003650     -399.7448
# East     FUR-BO-10001918     -405.6696
#          FUR-TA-10001539     -417.0672
# South    FUR-TA-10004289     -420.0000
# East     FUR-TA-10004915     -425.2640
# West     FUR-TA-10004256     -425.7480
# Central  FUR-FU-10003601     -426.1026
#          FUR-FU-10001468     -427.4500
# West     FUR-TA-10001932     -436.0704
#          FUR-BO-10004467     -439.9560
# Central  OFF-AP-10002518     -453.8490
# South    FUR-TA-10000577     -459.6372
# East     FUR-TA-10001889     -466.6310
# Central  OFF-AP-10000828     -470.5480
# South    FUR-TA-10002533     -489.2675
# West     FUR-BO-10002613     -491.7150
# East     FUR-BO-10004834     -493.3488
#          OFF-ST-10002574     -497.3040
#          TEC-MA-10001681     -506.4570
#          FUR-TA-10001095     -508.9268
# Central  OFF-BI-10003925     -512.1468
#          FUR-TA-10002645     -525.6405
#          FUR-BO-10003272     -534.7716
#          FUR-TA-10004256     -538.4460
#          FUR-BO-10000780     -546.6656
# West     FUR-CH-10003312     -547.9110
# East     FUR-TA-10001950     -553.6476
#          TEC-MA-10004679     -559.3560
# Central  FUR-TA-10004289     -566.5625
# South    TEC-MA-10002073     -571.9956
# East     TEC-PH-10000560     -587.9832
# Central  FUR-TA-10002958     -600.2540
# East     FUR-TA-10003473     -605.5693
# Central  OFF-BI-10001359     -636.8629
# South    FUR-TA-10001768     -648.3997
# East     OFF-ST-10004459     -656.8450
# Central  FUR-FU-10003806     -681.1200
# East     FUR-TA-10002958     -720.3048
#          FUR-TA-10003954     -734.5264
#          FUR-TA-10003238     -754.8426
# Central  OFF-SU-10000151     -786.0144
# West     FUR-BO-10001972     -802.0974
# Central  OFF-AP-10002651     -929.3913
# East     TEC-MA-10002210     -935.9595
# West     TEC-MA-10001695     -938.2800
# East     TEC-MA-10000864     -950.4000
# South    FUR-TA-10001950     -968.8833
# East     TEC-MA-10001148    -1027.7004
#          OFF-BI-10000545    -1065.3720
# South    FUR-TA-10001889    -1111.4302
# Central  OFF-BI-10004584    -1147.0074
#          OFF-BI-10004632    -1160.3235
# East     FUR-TA-10004154    -1187.5590
# Central  TEC-MA-10000822    -1189.9930
# East     OFF-SU-10002881    -1199.2464
# South    OFF-BI-10004995    -1306.5504
# Central  OFF-AP-10002534    -1378.8216
#          OFF-BI-10003527    -1525.1880
# South    TEC-MA-10002412    -1811.0784
#          OFF-BI-10000545    -1978.5480
#          FUR-TA-10000198    -2865.0960
# Central  OFF-BI-10004995    -3048.6176
# West     TEC-MA-10000822    -3399.9800
# South    TEC-MA-10004125    -3839.9904
# East     TEC-MA-10000418    -9239.9692
# Name: Profit, dtype: float64

# %%
df_store[(df_store['Region']=='East') & ((df_store['Product ID']=='TEC-CO-10004722') | (df_store['Product ID']=='TEC-MA-10003979') | (df_store['Product ID']=='TEC-MA-10001047') | (df_store['Product ID']=='TEC-MA-10000045') )]
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 1093  CA-2014-160766 2014-09-14 2014-09-14        Same Day    DM-13015
# 3512  CA-2015-114811 2015-11-08 2015-11-08        Same Day    KD-16495
# 3543  CA-2015-169796 2015-11-09 2015-11-14  Standard Class    Dp-13240
# 4268  US-2016-143819 2016-03-01 2016-03-05  Standard Class    KD-16270
# 4524  US-2016-107440 2016-04-16 2016-04-20  Standard Class    BS-11365
# 4742  CA-2016-143714 2016-05-23 2016-05-27  Standard Class    CC-12370
# 8832  CA-2017-143112 2017-10-05 2017-10-09  Standard Class    TS-21370
# 8986  CA-2017-127180 2017-10-22 2017-10-24     First Class    TA-21385
# 9334  CA-2017-166709 2017-11-17 2017-11-22  Standard Class    HL-15040
#
#            Customer Name      Segment        Country           City  \
# 1093       Darrin Martin     Consumer  United States  New York City
# 3512       Keith Dawkins    Corporate  United States  New York City
# 3543         Dean percer  Home Office  United States  New York City
# 4268       Karen Daniels     Consumer  United States        Yonkers
# 4524        Bill Shonely    Corporate  United States       Lakewood
# 4742  Christopher Conant     Consumer  United States   Philadelphia
# 8832        Todd Sumrall    Corporate  United States  New York City
# 8986        Tom Ashbrook  Home Office  United States  New York City
# 9334        Hunter Lopez     Consumer  United States         Newark
#
#              State  ...  Region       Product ID    Category Sub-Category  \
# 1093      New York  ...    East  TEC-MA-10003979  Technology     Machines
# 3512      New York  ...    East  TEC-MA-10000045  Technology     Machines
# 3543      New York  ...    East  TEC-MA-10000045  Technology     Machines
# 4268      New York  ...    East  TEC-MA-10003979  Technology     Machines
# 4524    New Jersey  ...    East  TEC-MA-10001047  Technology     Machines
# 4742  Pennsylvania  ...    East  TEC-CO-10004722  Technology      Copiers
# 8832      New York  ...    East  TEC-MA-10001047  Technology     Machines
# 8986      New York  ...    East  TEC-CO-10004722  Technology      Copiers
# 9334      Delaware  ...    East  TEC-CO-10004722  Technology      Copiers
#
#                                           Product Name      Sales  Quantity  \
# 1093                 Ativa V4110MDD Micro-Cut Shredder   2799.960         4
# 3512                 Zebra ZM400 Thermal Label Printer   4643.800         4
# 3543                 Zebra ZM400 Thermal Label Printer   2321.900         2
# 4268                 Ativa V4110MDD Micro-Cut Shredder   4899.930         7
# 4524  3D Systems Cube Printer, 2nd Generation, Magenta   9099.930         7
# 4742             Canon imageCLASS 2200 Advanced Copier   8399.976         4
# 8832  3D Systems Cube Printer, 2nd Generation, Magenta   5199.960         4
# 8986             Canon imageCLASS 2200 Advanced Copier  11199.968         4
# 9334             Canon imageCLASS 2200 Advanced Copier  10499.970         3
#
#       Discount     Profit  unit_price
# 1093       0.0  1371.9804      699.99
# 3512       0.0  2229.0240     1160.95
# 3543       0.0  1114.5120     1160.95
# 4268       0.0  2400.9657      699.99
# 4524       0.0  2365.9818     1299.99
# 4742       0.4  1119.9968     3499.99
# 8832       0.0  1351.9896     1299.99
# 8986       0.2  3919.9888     3499.99
# 9334       0.0  5039.9856     3499.99
#
# [9 rows x 21 columns]

# %% [markdown]
# **Get the Regions worst performing product --> Giving no profit at all (profit in negative or 0)**

# %%
df_store.groupby(by=['Region','Product ID'])['Profit'].sum().round(4).sort_values(ascending=True)
# Out:
# Region   Product ID
# East     TEC-MA-10000418    -9239.9692
# South    TEC-MA-10004125    -3839.9904
# West     TEC-MA-10000822    -3399.9800
# Central  OFF-BI-10004995    -3048.6176
# South    FUR-TA-10000198    -2865.0960
#          OFF-BI-10000545    -1978.5480
#          TEC-MA-10002412    -1811.0784
# Central  OFF-BI-10003527    -1525.1880
#          OFF-AP-10002534    -1378.8216
# South    OFF-BI-10004995    -1306.5504
# East     OFF-SU-10002881    -1199.2464
# Central  TEC-MA-10000822    -1189.9930
# East     FUR-TA-10004154    -1187.5590
# Central  OFF-BI-10004632    -1160.3235
#          OFF-BI-10004584    -1147.0074
# South    FUR-TA-10001889    -1111.4302
# East     OFF-BI-10000545    -1065.3720
#          TEC-MA-10001148    -1027.7004
# South    FUR-TA-10001950     -968.8833
# East     TEC-MA-10000864     -950.4000
# West     TEC-MA-10001695     -938.2800
# East     TEC-MA-10002210     -935.9595
# Central  OFF-AP-10002651     -929.3913
# West     FUR-BO-10001972     -802.0974
# Central  OFF-SU-10000151     -786.0144
# East     FUR-TA-10003238     -754.8426
#          FUR-TA-10003954     -734.5264
#          FUR-TA-10002958     -720.3048
# Central  FUR-FU-10003806     -681.1200
# East     OFF-ST-10004459     -656.8450
# South    FUR-TA-10001768     -648.3997
# Central  OFF-BI-10001359     -636.8629
# East     FUR-TA-10003473     -605.5693
# Central  FUR-TA-10002958     -600.2540
# East     TEC-PH-10000560     -587.9832
# South    TEC-MA-10002073     -571.9956
# Central  FUR-TA-10004289     -566.5625
# East     TEC-MA-10004679     -559.3560
#          FUR-TA-10001950     -553.6476
# West     FUR-CH-10003312     -547.9110
# Central  FUR-BO-10000780     -546.6656
#          FUR-TA-10004256     -538.4460
#          FUR-BO-10003272     -534.7716
#          FUR-TA-10002645     -525.6405
#          OFF-BI-10003925     -512.1468
# East     FUR-TA-10001095     -508.9268
#          TEC-MA-10001681     -506.4570
#          OFF-ST-10002574     -497.3040
#          FUR-BO-10004834     -493.3488
# West     FUR-BO-10002613     -491.7150
# South    FUR-TA-10002533     -489.2675
# Central  OFF-AP-10000828     -470.5480
# East     FUR-TA-10001889     -466.6310
# South    FUR-TA-10000577     -459.6372
# Central  OFF-AP-10002518     -453.8490
# West     FUR-BO-10004467     -439.9560
#          FUR-TA-10001932     -436.0704
# Central  FUR-FU-10001468     -427.4500
#          FUR-FU-10003601     -426.1026
# West     FUR-TA-10004256     -425.7480
# East     FUR-TA-10004915     -425.2640
# South    FUR-TA-10004289     -420.0000
# East     FUR-TA-10001539     -417.0672
#          FUR-BO-10001918     -405.6696
# West     OFF-BI-10003650     -399.7448
#          TEC-MA-10003356     -386.9570
#          FUR-TA-10002356     -377.4384
# East     TEC-PH-10002645     -374.9925
# West     FUR-BO-10003546     -363.5280
# Central  FUR-FU-10000576     -356.7280
# West     FUR-TA-10000849     -347.4324
# East     FUR-TA-10002530     -339.7050
# Central  FUR-TA-10004534     -337.6760
# South    OFF-BI-10004390     -336.7840
# Central  OFF-ST-10002743     -336.3744
#          OFF-AP-10000390     -329.2920
# East     TEC-MA-10000904     -319.1916
# Central  FUR-BO-10004834     -317.1528
#          FUR-CH-10000863     -311.0188
#          FUR-TA-10002533     -306.7050
# East     FUR-TA-10002903     -306.4578
#          TEC-PH-10001530     -305.1801
# West     OFF-SU-10002881     -299.8116
# Central  FUR-CH-10000229     -298.0780
# East     FUR-TA-10000577     -295.9785
# Central  FUR-CH-10003774     -293.8654
# East     FUR-TA-10004442     -283.9815
#          FUR-TA-10002228     -283.3560
# South    OFF-ST-10004459     -281.5050
# Central  TEC-MA-10004679     -279.6780
# West     FUR-TA-10002530     -279.3130
# Central  FUR-TA-10002041     -277.8995
# South    TEC-MA-10001856     -272.5800
# Central  FUR-TA-10001932     -269.3376
#          TEC-MA-10000488     -263.9967
# West     FUR-TA-10003715     -263.8062
#          TEC-PH-10000038     -263.0016
# East     FUR-CH-10003312     -258.5016
# South    OFF-BI-10004519     -257.2690
# Central  OFF-AP-10002684     -255.3180
#          FUR-FU-10002918     -252.0146
#          TEC-MA-10003353     -251.9958
# West     TEC-MA-10003337     -251.9874
# South    FUR-TA-10002903     -249.3216
# West     FUR-BO-10002268     -247.7988
# Central  FUR-FU-10002116     -247.4850
#          OFF-AP-10001242     -241.4400
# East     FUR-BO-10004357     -241.1760
# Central  FUR-FU-10003394     -240.6624
#          FUR-FU-10002298     -239.7168
# East     OFF-SU-10000646     -237.9663
#          TEC-PH-10003580     -225.2432
#          TEC-PH-10002789     -223.0657
#          FUR-BO-10000780     -221.0780
#          FUR-BO-10003272     -220.9800
# Central  FUR-CH-10003298     -220.0464
#          FUR-TA-10000577     -219.3723
# East     FUR-TA-10003715     -213.5574
#          FUR-BO-10004218     -211.4700
#          FUR-CH-10002024     -210.2940
# South    FUR-TA-10001857     -205.7055
# East     OFF-BI-10004632     -205.4325
# West     FUR-TA-10003469     -205.3500
# East     FUR-TA-10004175     -204.6360
# South    OFF-SU-10000646     -204.3145
# West     FUR-TA-10001889     -203.6208
# East     OFF-BI-10004224     -201.8400
#          FUR-BO-10001972     -199.6170
# Central  OFF-BI-10002026     -197.5554
#          FUR-FU-10003773     -194.8240
# East     FUR-TA-10001932     -192.3840
#          FUR-TA-10004575     -192.0468
# West     FUR-BO-10001608     -191.6460
#          FUR-BO-10001567     -190.8522
# Central  FUR-BO-10003965     -190.0290
#          FUR-TA-10002607     -189.9852
# West     OFF-ST-10001809     -186.8464
# Central  OFF-AP-10000026     -186.5682
#          FUR-TA-10001539     -184.8366
# South    FUR-CH-10003312     -182.6370
# Central  FUR-FU-10004904     -182.3520
#          OFF-AP-10002867     -179.7760
#          OFF-AP-10003217     -178.9668
#          OFF-AP-10000055     -178.6400
#          FUR-CH-10001973     -177.5680
# West     FUR-TA-10002041     -177.4971
# Central  OFF-AP-10004233     -177.2232
# West     FUR-BO-10000468     -175.8596
# Central  FUR-TA-10002228     -173.3472
# East     TEC-MA-10004521     -172.4925
#          FUR-FU-10001468     -170.9800
# West     FUR-TA-10003238     -170.8038
# South    OFF-BI-10000778     -169.3720
# East     OFF-BI-10003650     -168.3136
# South    FUR-TA-10001095     -167.3184
# West     OFF-ST-10001097     -167.2700
#          FUR-CH-10002880     -166.0365
# East     TEC-MA-10003589     -164.9538
# Central  FUR-CH-10002880     -164.8066
# West     FUR-CH-10000229     -162.5880
#          FUR-TA-10004289     -161.8750
# Central  FUR-TA-10002774     -160.2952
# East     FUR-BO-10004467     -159.9840
# Central  FUR-TA-10000688     -159.0305
# East     FUR-TA-10001039     -158.2032
# West     FUR-CH-10000225     -157.9110
# Central  FUR-FU-10000723     -157.4292
# East     OFF-BI-10004330     -157.1650
#          FUR-TA-10002645     -157.0095
#          FUR-BO-10004015     -155.9870
# West     FUR-CH-10004860     -155.5092
#          FUR-TA-10001086     -155.0298
# Central  FUR-TA-10004086     -154.7640
# East     FUR-TA-10002607     -153.1224
# Central  FUR-TA-10001889     -152.7156
# West     FUR-CH-10001190     -149.5890
# East     FUR-TA-10003008     -147.8655
# South    FUR-TA-10003008     -147.8655
# East     FUR-CH-10003774     -146.4778
# Central  OFF-ST-10004123     -145.5680
# South    OFF-BI-10004584     -145.3508
# Central  OFF-BI-10000778     -145.1760
# West     FUR-BO-10003450     -143.7904
# East     FUR-TA-10000198     -143.2548
# West     FUR-TA-10001039     -141.0072
# East     FUR-TA-10000849     -140.1408
#          FUR-BO-10004695     -139.3546
# West     FUR-CH-10003956     -138.4110
# Central  FUR-BO-10004218     -138.1604
#          OFF-ST-10002574     -138.1400
#          FUR-BO-10003893     -137.9760
#          OFF-BI-10002429     -136.3712
#          FUR-BO-10001601     -136.2192
# West     FUR-TA-10002607     -136.1088
# Central  FUR-FU-10000193     -135.1168
#          OFF-AP-10001947     -135.0184
# West     OFF-ST-10002743     -134.0952
# East     TEC-PH-10002680     -131.9940
#          FUR-TA-10003748     -131.9594
# Central  FUR-TA-10004442     -131.9510
# East     OFF-ST-10001809     -131.1518
# Central  OFF-AP-10000891     -131.1200
# East     FUR-TA-10002356     -131.0550
# Central  OFF-ST-10003656     -130.5464
#          OFF-AP-10001564     -130.2448
#          OFF-AP-10001563     -130.1944
#          FUR-TA-10004607     -130.0904
# South    FUR-CH-10003298     -129.6702
# Central  OFF-ST-10001511     -129.3000
#          OFF-BI-10001524     -127.5584
# East     FUR-CH-10003298     -127.0506
# Central  OFF-AP-10004487     -126.8592
# East     FUR-CH-10001482     -123.1212
#          FUR-TA-10000617     -122.8770
#          TEC-PH-10001795     -121.5983
#          TEC-PH-10004667     -121.4910
# Central  TEC-MA-10002210     -121.2705
#          FUR-CH-10000513     -120.8907
# East     FUR-TA-10003569     -120.2940
# Central  FUR-TA-10001768     -118.1295
# East     FUR-TA-10003392     -118.0116
# Central  FUR-BO-10000112     -117.8820
# West     FUR-TA-10004575     -116.3920
#          FUR-BO-10001337     -114.9310
#          FUR-CH-10003774     -114.6348
# South    OFF-BI-10004593     -113.1840
#          TEC-MA-10004002     -111.4995
# East     FUR-CH-10002880     -110.6910
# Central  OFF-AP-10004980     -108.8304
# West     FUR-CH-10001714     -108.6408
# East     TEC-PH-10001128     -107.9928
#          TEC-PH-10001299     -107.9928
# Central  OFF-AP-10003849     -107.3460
# East     FUR-TA-10001086     -106.3930
# South    FUR-TA-10001039     -105.7554
# Central  FUR-FU-10004622     -105.6900
# East     FUR-TA-10003469     -105.4500
# Central  OFF-BI-10001597     -104.9088
# East     FUR-TA-10002041     -103.9882
# West     FUR-CH-10003396     -103.9230
#          FUR-BO-10003660     -103.8606
# South    FUR-TA-10001705     -102.0480
#          OFF-BI-10004224     -100.9200
# Central  FUR-TA-10003569     -100.2450
#          FUR-TA-10000849      -99.2664
# West     FUR-TA-10000198      -99.1764
# East     OFF-BI-10002133      -98.8680
# West     FUR-BO-10002202      -98.8018
# Central  FUR-TA-10003008      -98.5770
#          TEC-MA-10001972      -97.7200
# West     OFF-BI-10000778      -96.7840
# Central  FUR-CH-10002331      -96.1146
#          FUR-TA-10001705      -95.6700
#          FUR-FU-10004952      -95.2476
# East     FUR-BO-10004409      -93.6936
#          TEC-PH-10000562      -93.2316
# Central  OFF-BI-10002133      -92.8760
# East     TEC-PH-10002824      -92.6955
# South    OFF-ST-10001522      -91.9900
# Central  OFF-AP-10003040      -90.7740
#          FUR-CH-10002044      -90.3762
#          FUR-BO-10001811      -90.2940
# East     FUR-BO-10002213      -90.1764
#          FUR-BO-10001798      -89.0664
#          FUR-TA-10004152      -88.7040
#          OFF-ST-10002554      -88.0380
# Central  OFF-ST-10004804      -88.0308
#          OFF-AP-10004336      -87.1488
#          OFF-BI-10001098      -86.1614
# East     FUR-CH-10000863      -86.0586
#          TEC-PH-10001817      -85.9200
# Central  OFF-BI-10002854      -84.0900
# East     OFF-SU-10000157      -83.5170
# Central  OFF-BI-10000632      -83.3472
# East     FUR-TA-10002622      -82.0704
# West     FUR-CH-10000863      -81.5292
# South    FUR-BO-10003965      -81.4410
# Central  OFF-BI-10000309      -80.2094
# East     OFF-ST-10002790      -79.0195
# Central  FUR-FU-10003919      -78.5088
#          FUR-BO-10004690      -78.3636
#          FUR-FU-10004597      -78.2550
#          OFF-AP-10004708      -77.6424
#          FUR-FU-10004848      -77.6250
#          TEC-PH-10000038      -76.7088
#          FUR-FU-10000277      -75.8448
# South    TEC-AC-10002637      -75.5958
# East     FUR-BO-10004709      -74.2144
# West     OFF-ST-10004804      -73.6164
# East     FUR-CH-10003833      -73.1760
# South    OFF-ST-10004123      -72.7840
# Central  FUR-TA-10002622      -71.8116
# East     TEC-MA-10002694      -71.3958
# Central  OFF-AP-10002403      -71.2962
#          FUR-BO-10004360      -70.8312
#          OFF-BI-10003684      -70.3680
# West     TEC-PH-10003555      -70.3494
# Central  OFF-ST-10003470      -69.8700
#          OFF-BI-10001575      -69.3952
#          FUR-CH-10002126      -68.3144
# West     FUR-CH-10003968      -68.1408
# South    FUR-CH-10002044      -68.1096
# Central  OFF-ST-10002344      -68.0232
# East     TEC-PH-10003645      -67.8762
# South    OFF-ST-10000676      -67.8510
# Central  FUR-FU-10004973      -67.8240
# South    FUR-BO-10002213      -67.6704
# Central  OFF-AP-10004136      -67.6170
#          FUR-FU-10004748      -67.1370
# South    OFF-BI-10002429      -66.9680
# East     OFF-ST-10002756      -66.3019
# Central  FUR-FU-10004306      -66.0620
#          OFF-ST-10000025      -64.8924
# South    OFF-ST-10000736      -64.7840
# East     TEC-PH-10000141      -64.6702
# West     OFF-ST-10001128      -64.3684
# Central  FUR-TA-10001676      -63.9792
#          OFF-ST-10000563      -63.9600
# East     OFF-ST-10001713      -63.5880
# Central  FUR-CH-10003535      -63.4192
#          OFF-ST-10003716      -63.0056
# East     FUR-TA-10001307      -62.9010
#          FUR-CH-10004860      -62.6076
#          TEC-PH-10002584      -62.5990
#          FUR-TA-10004086      -61.9056
# Central  FUR-FU-10002703      -61.8720
#          OFF-BI-10000474      -61.5552
# East     FUR-BO-10002853      -61.4550
# West     FUR-CH-10003833      -60.9800
#          TEC-PH-10003800      -60.4086
#          OFF-ST-10001370      -60.3330
# East     OFF-BI-10003719      -59.8800
#          TEC-PH-10002200      -58.9228
# Central  FUR-CH-10003396      -58.5048
# East     OFF-ST-10002344      -58.3056
# South    FUR-TA-10000617      -56.8875
# Central  FUR-CH-10004983      -56.3430
# South    TEC-MA-10002178      -55.6560
# Central  FUR-FU-10003247      -55.5970
#          OFF-BI-10002353      -55.5840
# East     TEC-AC-10001142      -55.3000
# South    OFF-ST-10001418      -54.8820
# East     FUR-CH-10000513      -54.5958
# Central  OFF-AP-10000240      -54.5496
#          FUR-CH-10002602      -54.3528
# East     FUR-CH-10003396      -53.8860
#          OFF-BI-10001658      -53.8272
# Central  FUR-FU-10004864      -53.7096
# West     FUR-TA-10001520      -53.5275
#          FUR-TA-10003954      -53.3124
# East     FUR-BO-10003433      -53.2856
# Central  OFF-AP-10003287      -53.0088
#          OFF-AP-10002578      -52.8336
#          FUR-FU-10002759      -52.7472
# East     OFF-ST-10003479      -52.5690
#          FUR-CH-10000015      -51.9840
# South    OFF-BI-10003091      -51.5154
# East     OFF-BI-10003007      -51.1896
#          TEC-PH-10003092      -50.5890
# Central  FUR-CH-10001215      -50.0980
#          OFF-BI-10002082      -49.9200
# West     TEC-PH-10004188      -49.4802
# Central  FUR-CH-10000422      -49.1346
# East     TEC-PH-10004080      -48.9528
#          FUR-TA-10001676      -48.8730
# West     FUR-TA-10004607      -48.7839
# East     FUR-TA-10004607      -48.7839
#          FUR-FU-10004904      -48.6272
# Central  FUR-CH-10001545      -47.8716
#          FUR-TA-10003469      -47.1750
# East     TEC-PH-10001305      -47.0304
# Central  FUR-FU-10001095      -46.6048
# West     FUR-TA-10002774      -46.2390
# Central  FUR-FU-10001475      -45.7184
#          FUR-FU-10003708      -45.4875
#          FUR-TA-10002530      -45.2940
#          OFF-ST-10003994      -44.2350
#          FUR-CH-10001146      -44.2298
#          OFF-ST-10001418      -43.9056
#          FUR-FU-10000222      -43.8480
# West     FUR-CH-10000422      -43.6752
# Central  FUR-TA-10001866      -43.0296
# West     FUR-CH-10000513      -42.8967
# South    OFF-BI-10003876      -42.8000
# Central  FUR-CH-10002647      -42.5880
#          FUR-FU-10003930      -42.4926
#          FUR-BO-10002268      -42.1096
# East     FUR-BO-10003034      -41.9136
# Central  FUR-BO-10003441      -41.4018
# West     OFF-BI-10003676      -41.3952
# Central  FUR-FU-10003553      -41.2620
#          OFF-ST-10001522      -40.4756
#          OFF-BI-10000962      -40.3496
# West     FUR-CH-10004289      -40.3116
#          OFF-BI-10002429      -40.1808
#          TEC-PH-10001448      -39.9920
#          FUR-CH-10001973      -39.9528
# East     OFF-ST-10001370      -39.0390
# West     FUR-CH-10002372      -38.8704
# Central  OFF-AP-10002457      -38.7205
#          OFF-BI-10002794      -38.1114
# East     OFF-ST-10001128      -37.7332
#          FUR-TA-10001520      -37.1124
# Central  FUR-BO-10003034      -36.6744
# West     FUR-FU-10004904      -36.4704
# Central  FUR-FU-10004909      -36.3600
# South    FUR-BO-10001337      -36.2940
# Central  FUR-BO-10002824      -36.2352
#          FUR-CH-10002965      -36.1764
# East     FUR-BO-10001519      -36.0468
# Central  FUR-BO-10000362      -35.9058
#          OFF-BI-10004233      -35.8176
# West     FUR-CH-10001482      -35.3646
# South    FUR-TA-10004575      -34.9176
# East     FUR-CH-10000847      -34.9176
#          OFF-BI-10004781      -34.9140
# Central  OFF-SU-10003505      -34.7580
# East     FUR-TA-10001771      -34.6470
# West     FUR-BO-10003159      -34.4940
# East     TEC-PH-10001700      -34.3148
# Central  OFF-AP-10000696      -33.8870
# South    OFF-ST-10002182      -33.8418
# Central  OFF-ST-10000689      -33.8040
# West     OFF-ST-10000689      -33.8040
# Central  FUR-FU-10003039      -33.6414
# South    OFF-BI-10002854      -33.6360
# Central  OFF-BI-10003429      -33.3591
#          TEC-AC-10002842      -33.3200
# South    FUR-CH-10002880      -33.2073
# Central  OFF-BI-10003166      -33.0624
#          OFF-ST-10000934      -32.7840
#          FUR-CH-10001802      -32.6646
# South    TEC-PH-10000127      -32.3838
# Central  OFF-ST-10001809      -32.3388
# East     FUR-BO-10003159      -32.1944
# Central  OFF-BI-10001510      -32.0880
# West     FUR-CH-10001545      -31.9144
# Central  FUR-FU-10001602      -31.8612
#          OFF-BI-10000343      -31.7186
# West     FUR-TA-10001857      -31.6470
# Central  OFF-AP-10004036      -31.5360
# East     TEC-AC-10004855      -31.4910
# Central  OFF-BI-10002824      -31.3320
# West     TEC-PH-10004833      -31.0700
# Central  OFF-ST-10000991      -31.0419
#          FUR-FU-10001986      -30.5880
#          FUR-TA-10004915      -30.3760
#          FUR-BO-10003546      -30.2940
#          TEC-AC-10002076      -29.9400
#          FUR-FU-10002364      -29.7414
#          FUR-CH-10003973      -29.7408
# East     FUR-FU-10000293      -29.4812
# West     OFF-ST-10001522      -29.4368
# South    FUR-TA-10001676      -29.3238
# Central  OFF-BI-10003291      -29.2455
#          OFF-BI-10002706      -29.1312
#          OFF-ST-10002485      -29.0136
# West     FUR-CH-10000749      -28.9568
# East     TEC-AC-10000580      -28.7964
# South    OFF-BI-10004001      -28.6272
# West     TEC-AC-10004227      -28.3182
# South    FUR-CH-10004860      -28.2744
# Central  FUR-CH-10003981      -28.2678
# South    FUR-TA-10004152      -28.2240
# West     TEC-AC-10001314      -27.9944
# South    OFF-BI-10004781      -27.9312
#          FUR-BO-10003433      -27.8820
# Central  FUR-FU-10004587      -27.6408
#          TEC-AC-10004855      -27.2922
# East     OFF-BI-10001575      -27.2624
# South    OFF-BI-10002133      -26.9640
# West     OFF-ST-10001418      -26.8312
# East     OFF-ST-10003641      -26.7920
# Central  FUR-CH-10003199      -26.6352
# East     FUR-FU-10002298      -26.6352
# Central  OFF-BI-10000050      -26.4990
#          FUR-FU-10001473      -26.4714
#          OFF-BI-10002799      -26.4180
# South    OFF-BI-10001636      -26.3016
# East     OFF-BI-10001098      -26.2974
# South    OFF-BI-10003984      -26.2476
# Central  OFF-BI-10003708      -26.0750
#          OFF-BI-10003638      -25.9290
#          OFF-BI-10000285      -25.8720
# South    OFF-BI-10001196      -25.7370
# Central  OFF-AP-10002439      -25.5492
#          FUR-CH-10001708      -25.3764
#          OFF-ST-10002790      -25.1090
# East     OFF-BI-10003364      -25.0862
# West     OFF-BI-10003694      -25.0560
# Central  FUR-FU-10001588      -24.8030
#          OFF-AP-10004868      -24.7086
# South    OFF-ST-10000934      -24.5880
# West     FUR-FU-10002918      -24.5646
# Central  OFF-ST-10004337      -24.4960
# East     TEC-PH-10002844      -24.4930
# Central  OFF-BI-10002827      -24.4426
# South    FUR-CH-10003833      -24.3920
# East     TEC-MA-10000752      -24.2760
# Central  FUR-FU-10002553      -24.1890
#          FUR-FU-10000175      -23.8902
#          OFF-BI-10004140      -23.5725
# East     TEC-PH-10004522      -23.3960
# South    OFF-BI-10003982      -23.2624
#          OFF-ST-10002301      -23.1876
#          OFF-SU-10003505      -23.1720
# Central  FUR-TA-10004154      -22.9480
#          OFF-BI-10003707      -22.8900
#          OFF-AP-10000358      -22.8448
# East     OFF-BI-10004230      -22.7964
# South    OFF-ST-10001469      -22.6716
# Central  OFF-BI-10001670      -22.6200
#          FUR-FU-10001546      -22.4280
# East     TEC-AC-10002550      -22.3776
# West     TEC-MA-10004086      -21.9450
# East     OFF-BI-10002353      -21.6160
# Central  TEC-AC-10001767      -21.5946
# East     FUR-FU-10003773      -21.4704
# Central  OFF-BI-10004209      -21.3060
#          FUR-FU-10003849      -21.2520
# South    OFF-BI-10004817      -21.0848
# East     FUR-CH-10004495      -21.0686
# Central  OFF-BI-10002194      -21.0672
# East     TEC-PH-10001924      -20.9970
# Central  FUR-FU-10001967      -20.9895
# West     OFF-BI-10000315      -20.8890
# East     OFF-ST-10003994      -20.6430
# Central  OFF-BI-10001072      -20.6176
# South    OFF-BI-10004465      -20.5920
#          OFF-BI-10001575      -20.4468
# East     OFF-BI-10003166      -20.2048
#          FUR-TA-10004147      -20.1528
# Central  OFF-BI-10000773      -20.0500
# East     OFF-BI-10001525      -20.0025
#          OFF-BI-10001107      -19.9824
# Central  FUR-FU-10003878      -19.8640
#          OFF-BI-10002571      -19.7604
#          FUR-FU-10000965      -19.7372
#          FUR-FU-10001756      -19.6112
#          OFF-AP-10002082      -19.6020
#          OFF-SU-10003567      -19.5840
# East     OFF-ST-10004804      -19.5624
# Central  TEC-MA-10003230      -19.4700
#          FUR-FU-10004671      -19.4370
#          OFF-ST-10002301      -19.3230
#          OFF-BI-10004094      -19.2045
#          OFF-BI-10004817      -19.1680
#          FUR-FU-10000758      -19.0656
# South    TEC-PH-10004897      -18.6813
# Central  OFF-ST-10000642      -18.6722
# South    TEC-AC-10002600      -18.5850
# Central  OFF-AP-10004859      -18.4912
#          OFF-BI-10001628      -18.2525
# South    FUR-FU-10000723      -18.1808
# East     TEC-MA-10002930      -18.0385
# West     TEC-PH-10000127      -17.9910
# South    OFF-BI-10002982      -17.9784
# East     FUR-CH-10002372      -17.8156
# Central  FUR-FU-10002030      -17.7840
# East     OFF-BI-10000474      -17.6330
# Central  OFF-ST-10003479      -17.5230
#          FUR-FU-10002501      -17.4432
#          FUR-BO-10003966      -17.0980
#          OFF-BI-10001617      -17.0610
# East     TEC-PH-10004908      -16.9980
#          TEC-PH-10002293      -16.7916
#          OFF-BI-10002071      -16.7328
# Central  OFF-BI-10001071      -16.6348
# West     TEC-AC-10002550      -16.6140
# South    TEC-PH-10003555      -16.5528
# Central  OFF-BI-10002414      -16.5396
# South    TEC-MA-10003626      -16.4260
# East     OFF-ST-10003656      -16.3183
#          FUR-CH-10004698      -16.1960
#          TEC-PH-10003187      -15.9920
# West     TEC-PH-10003187      -15.9920
# South    FUR-CH-10001482      -15.7176
# East     TEC-PH-10004897      -15.5844
# Central  FUR-FU-10001215      -15.5268
# West     TEC-PH-10004774      -15.4581
# South    OFF-BI-10003166      -15.1536
# Central  OFF-AP-10003278      -15.0876
# West     FUR-BO-10001811      -15.0490
# East     TEC-PH-10003437      -14.9980
# Central  OFF-BI-10004236      -14.9736
#          OFF-ST-10004180      -14.8832
#          OFF-BI-10002103      -14.7730
# West     OFF-ST-10002554      -14.6730
# East     TEC-PH-10004531      -14.6428
# West     TEC-PH-10001527      -14.6030
# Central  OFF-BI-10004364      -14.5530
# South    FUR-BO-10001972      -14.5176
# Central  TEC-AC-10002942      -14.4900
# West     FUR-BO-10003965      -14.4784
# Central  FUR-FU-10003194      -14.4750
#          FUR-BO-10002202      -14.4588
# West     FUR-CH-10003298      -14.4078
# Central  FUR-FU-10000820      -14.2716
#          OFF-BI-10001757      -14.1696
# East     FUR-TA-10003837      -14.1639
# Central  OFF-AP-10001303      -13.9300
#          OFF-BI-10004002      -13.8400
# East     OFF-BI-10001153      -13.8160
# Central  OFF-BI-10001721      -13.6832
# South    FUR-CH-10001545      -13.6776
# Central  OFF-AP-10000027      -13.5800
# East     OFF-BI-10001267      -13.5740
#          TEC-PH-10002549      -13.5516
# Central  TEC-AC-10001552      -13.4379
# East     FUR-CH-10004886      -13.4330
# Central  OFF-ST-10000636      -13.3920
#          OFF-BI-10001132      -13.3424
# East     TEC-PH-10001433      -13.3341
# Central  OFF-BI-10001679      -13.3200
#          FUR-BO-10004467      -12.9987
#          OFF-ST-10002583      -12.9920
# East     OFF-ST-10002583      -12.9920
# Central  OFF-AP-10000124      -12.9792
#          OFF-ST-10001469      -12.9552
# South    OFF-BI-10003305      -12.9168
# West     FUR-BO-10001918      -12.8784
# Central  FUR-FU-10001379      -12.8256
# West     FUR-BO-10002206      -12.6882
#          FUR-CH-10003061      -12.5986
#          OFF-BI-10002931      -12.5820
# East     FUR-CH-10004540      -12.3408
#          OFF-BI-10004099      -12.2880
#          OFF-ST-10002486      -12.2848
#          OFF-BI-10002103      -12.1660
# South    FUR-CH-10000225      -12.1470
# East     OFF-ST-10004963      -12.1120
# Central  FUR-FU-10001940      -12.0992
#          FUR-FU-10003832      -12.0064
# South    OFF-BI-10004654      -11.9370
# Central  OFF-BI-10001308      -11.9320
#          OFF-BI-10002813      -11.7810
# West     OFF-BI-10003984      -11.6973
#          TEC-PH-10000148      -11.6910
# Central  FUR-BO-10004709      -11.5960
#          OFF-BI-10004001      -11.5872
#          FUR-BO-10003159      -11.4980
# East     OFF-BI-10001982      -11.4240
# Central  FUR-FU-10001424      -11.3490
#          FUR-FU-10002505      -11.3232
#          FUR-FU-10002396      -11.3220
#          OFF-ST-10002182      -11.2806
#          OFF-BI-10003196      -11.2200
# South    TEC-AC-10004227      -11.1714
# Central  OFF-BI-10002609      -11.1452
# East     FUR-CH-10001973      -11.0980
# Central  OFF-BI-10001765      -11.0848
# East     OFF-ST-10001522      -11.0388
# West     OFF-BI-10001036      -10.9680
# Central  OFF-SU-10004498      -10.9480
# West     OFF-FA-10001883      -10.8920
# East     OFF-BI-10000069      -10.8072
#          OFF-ST-10000642      -10.6998
# South    OFF-ST-10000078      -10.6068
# Central  OFF-AP-10001626      -10.5030
# East     OFF-BI-10001757      -10.4304
# Central  OFF-BI-10004492      -10.4214
#          FUR-FU-10003535      -10.4196
# South    TEC-AC-10003832      -10.2996
# Central  OFF-BI-10002412      -10.1500
#          FUR-FU-10004666      -10.0602
# South    OFF-BI-10004209      -10.0500
# West     OFF-BI-10000279       -9.9705
# Central  FUR-FU-10003691       -9.8800
# East     TEC-PH-10000148       -9.8724
# South    OFF-BI-10000948       -9.8463
# East     OFF-BI-10003196       -9.7240
# Central  OFF-ST-10000736       -9.7176
# South    OFF-ST-10000046       -9.6930
# West     FUR-BO-10000330       -9.6784
# Central  OFF-BI-10002557       -9.5550
#          FUR-FU-10000550       -9.4122
# East     OFF-BI-10003638       -9.2880
# Central  TEC-AC-10002323       -9.2820
# South    OFF-BI-10000773       -9.2230
# East     TEC-PH-10001870       -9.1845
#          TEC-PH-10003357       -9.1788
# South    TEC-PH-10000169       -9.1530
# Central  FUR-FU-10004415       -9.0944
# East     TEC-PH-10003931       -8.9985
# Central  TEC-PH-10004188       -8.9964
# South    OFF-BI-10001098       -8.9796
#          OFF-BI-10002794       -8.6058
# East     OFF-BI-10002794       -8.6058
# South    OFF-BI-10002498       -8.5974
# Central  OFF-BI-10001890       -8.5920
#          OFF-ST-10001713       -8.4784
#          OFF-AP-10002191       -8.3972
# South    TEC-AC-10004396       -8.1675
# Central  OFF-BI-10001787       -8.1096
# East     FUR-CH-10000225       -8.0980
# West     FUR-CH-10003846       -8.0784
# Central  OFF-ST-10000046       -8.0775
# East     OFF-BI-10000977       -7.9040
#          OFF-BI-10000285       -7.8400
# Central  TEC-PH-10003555       -7.8166
#          TEC-PH-10000169       -7.7970
# East     OFF-BI-10000216       -7.7820
# South    OFF-BI-10000216       -7.7820
#          OFF-BI-10000301       -7.7640
# East     OFF-ST-10002301       -7.7292
# South    OFF-BI-10003694       -7.7256
#          OFF-BI-10004099       -7.6800
#          OFF-BI-10001757       -7.5768
# Central  FUR-FU-10004091       -7.5104
# East     OFF-ST-10004180       -7.4416
# Central  FUR-FU-10001025       -7.4358
# East     TEC-PH-10004348       -7.3960
# Central  OFF-AP-10000804       -7.3920
# West     OFF-BI-10001758       -7.3692
# South    OFF-BI-10001031       -7.3692
# Central  OFF-ST-10000419       -7.3332
# East     OFF-BI-10004410       -7.3255
# Central  TEC-PH-10001527       -7.3015
# South    OFF-BI-10003712       -7.2177
#          TEC-MA-10004626       -7.2000
# Central  TEC-AC-10000580       -7.1991
#          TEC-AC-10003441       -7.1190
# South    OFF-BI-10001679       -7.1040
# West     OFF-BI-10003274       -7.0048
# East     OFF-BI-10002072       -6.9520
# West     OFF-BI-10002813       -6.9300
# Central  FUR-FU-10001196       -6.9240
#          OFF-BI-10003676       -6.8992
#          FUR-FU-10004053       -6.8816
# South    OFF-BI-10004140       -6.7350
# Central  OFF-BI-10004224       -6.7280
#          FUR-CH-10004477       -6.6979
# West     OFF-ST-10002485       -6.5940
# Central  TEC-PH-10000307       -6.5700
#          OFF-BI-10002003       -6.5670
#          OFF-BI-10002982       -6.5376
# West     TEC-AC-10004396       -6.5340
# Central  OFF-AP-10003971       -6.5340
# South    OFF-BI-10000546       -6.4512
# Central  OFF-AP-10004249       -6.3441
#          OFF-ST-10002957       -6.3360
#          OFF-ST-10000321       -6.3120
#          FUR-FU-10004963       -6.3000
# West     FUR-TA-10001676       -6.2202
# Central  FUR-FU-10002456       -6.1880
#          FUR-CH-10004540       -6.1704
# East     OFF-BI-10001249       -6.1248
# West     OFF-BI-10003350       -6.1248
#          OFF-ST-10001963       -6.0846
# Central  OFF-BI-10000315       -6.0768
#          FUR-CH-10001714       -6.0356
# South    OFF-BI-10001553       -6.0324
#          OFF-BI-10004022       -6.0048
# East     TEC-PH-10002583       -5.9970
# West     TEC-PH-10002583       -5.9970
#          OFF-BI-10001982       -5.9840
# Central  FUR-FU-10003489       -5.9409
# South    OFF-BI-10003669       -5.9400
#          OFF-BI-10000201       -5.9040
#          OFF-ST-10002554       -5.8692
#          OFF-BI-10004410       -5.8604
# Central  FUR-FU-10000260       -5.8248
#          OFF-BI-10002071       -5.8100
# South    OFF-BI-10002976       -5.6994
# West     TEC-PH-10004897       -5.6943
# Central  OFF-BI-10004738       -5.6820
#          FUR-TA-10004767       -5.6784
# East     OFF-BI-10001759       -5.6007
# Central  OFF-ST-10000129       -5.5515
# East     OFF-BI-10000773       -5.5338
# West     FUR-CH-10003535       -5.4882
# Central  OFF-BI-10002012       -5.4720
# East     TEC-AC-10004227       -5.4558
# Central  OFF-BI-10004141       -5.4060
# South    OFF-BI-10001097       -5.2332
# East     OFF-BI-10000494       -5.2200
# Central  OFF-AP-10004655       -5.2072
# West     OFF-BI-10001116       -5.1744
# Central  TEC-AC-10002718       -5.1065
#          OFF-BI-10002432       -5.0094
# East     OFF-BI-10002799       -4.9728
# Central  TEC-AC-10004396       -4.9005
# West     OFF-BI-10000773       -4.8922
# East     FUR-BO-10002268       -4.8588
#          TEC-AC-10002134       -4.8528
# Central  OFF-BI-10003784       -4.8384
#          FUR-FU-10002111       -4.8048
#          OFF-BI-10000279       -4.7685
# South    OFF-ST-10002289       -4.7670
# East     OFF-FA-10000053       -4.7628
# Central  OFF-BI-10004465       -4.7520
# East     TEC-AC-10003023       -4.7496
#          TEC-AC-10003441       -4.7460
# Central  FUR-FU-10000023       -4.7120
# South    OFF-BI-10001116       -4.6464
#          OFF-BI-10003727       -4.5980
# West     OFF-BI-10001132       -4.5192
# Central  OFF-BI-10000138       -4.4928
#          OFF-AP-10002203       -4.4660
# West     OFF-BI-10000831       -4.4352
# East     OFF-ST-10001469       -4.3184
#          OFF-BI-10004308       -4.1960
# Central  OFF-SU-10000432       -4.1640
# South    TEC-AC-10002942       -4.1400
# West     OFF-SU-10002301       -4.1134
# East     TEC-PH-10002923       -4.0689
#          OFF-BI-10004022       -4.0032
# Central  FUR-FU-10004586       -3.9840
#          FUR-FU-10002240       -3.9400
# East     FUR-FU-10000193       -3.8976
# Central  OFF-BI-10004099       -3.8400
# East     OFF-BI-10004141       -3.8160
# South    OFF-BI-10001525       -3.8100
# West     OFF-BI-10004738       -3.7880
# East     OFF-SU-10002189       -3.7715
# Central  OFF-FA-10000254       -3.7680
#          OFF-AP-10001634       -3.7584
# West     OFF-BI-10002824       -3.7300
# Central  OFF-BI-10000201       -3.6900
#          OFF-BI-10002160       -3.6576
#          TEC-AC-10004227       -3.6372
# South    OFF-SU-10004498       -3.6064
# Central  OFF-BI-10000014       -3.6003
# South    OFF-BI-10000822       -3.5508
#          OFF-ST-10001370       -3.5490
# West     TEC-PH-10000307       -3.5040
# South    OFF-BI-10001153       -3.4540
# Central  OFF-BI-10004967       -3.4320
#          OFF-AP-10004052       -3.3970
# East     OFF-BI-10001132       -3.3894
# West     FUR-TA-10003837       -3.3506
# East     OFF-BI-10003712       -3.3388
# Central  OFF-SU-10001935       -3.3136
# East     OFF-ST-10000736       -3.2392
# Central  OFF-BI-10002049       -3.2274
# East     OFF-SU-10001225       -3.1648
# South    OFF-BI-10001308       -3.1400
# West     OFF-BI-10003707       -3.0520
# Central  OFF-BI-10003314       -2.9884
#          OFF-ST-10000352       -2.9740
# East     OFF-BI-10001116       -2.9568
# Central  OFF-BI-10004022       -2.8356
# South    OFF-BI-10002414       -2.7566
# Central  TEC-AC-10002167       -2.7000
# South    TEC-AC-10002167       -2.7000
# East     OFF-BI-10002827       -2.6544
# South    OFF-SU-10001225       -2.6496
#          OFF-BI-10000848       -2.6256
# West     OFF-SU-10000432       -2.6025
# Central  FUR-CH-10003606       -2.5648
# South    OFF-BI-10000042       -2.5632
# West     OFF-BI-10000088       -2.5254
# East     OFF-BI-10000014       -2.5093
#          OFF-BI-10003094       -2.4288
# South    OFF-BI-10004002       -2.4220
# West     OFF-SU-10003567       -2.4000
# Central  OFF-FA-10004395       -2.3550
# South    OFF-BI-10001982       -2.2848
#          FUR-FU-10001602       -2.2758
# West     OFF-BI-10002049       -2.2494
# East     TEC-PH-10002070       -2.2490
# Central  OFF-ST-10000107       -2.2200
# East     OFF-FA-10004838       -2.2134
#          OFF-SU-10004498       -2.1896
# Central  FUR-FU-10000320       -2.1376
#          FUR-FU-10001861       -2.1340
# East     TEC-PH-10004875       -2.0774
# Central  FUR-CH-10000553       -2.0364
# South    OFF-BI-10002954       -2.0108
# Central  TEC-AC-10001314       -1.9996
# South    TEC-MA-10000423       -1.9791
# Central  OFF-BI-10001922       -1.9602
#          OFF-BI-10000145       -1.9344
# West     OFF-BI-10001634       -1.8928
#          TEC-AC-10002217       -1.8800
# South    TEC-MA-10003493       -1.8295
# Central  OFF-BI-10000494       -1.8270
# South    OFF-SU-10003936       -1.8126
#          OFF-BI-10004506       -1.8106
# East     TEC-PH-10002890       -1.8096
#          TEC-AC-10002335       -1.7495
# Central  FUR-FU-10002191       -1.6752
# West     OFF-BI-10001460       -1.6665
#          OFF-FA-10004395       -1.6485
#          FUR-CH-10001146       -1.6157
# South    OFF-ST-10000617       -1.5496
# Central  TEC-AC-10003038       -1.5215
#          TEC-AC-10001383       -1.4994
# South    OFF-BI-10000138       -1.4976
# Central  TEC-AC-10000199       -1.4280
# East     TEC-AC-10000199       -1.4280
# Central  FUR-FU-10001935       -1.4060
#          FUR-FU-10004020       -1.3675
#          OFF-FA-10000053       -1.3608
#          TEC-AC-10004127       -1.3584
# West     OFF-BI-10004352       -1.3500
# Central  OFF-BI-10003727       -1.3376
#          OFF-SU-10001225       -1.3248
#          FUR-FU-10002963       -1.3208
# South    FUR-FU-10000193       -1.2992
# Central  OFF-BI-10000756       -1.2720
#          OFF-ST-10001505       -1.2558
# South    OFF-ST-10000798       -1.2490
# Central  OFF-AP-10002906       -1.1100
# South    TEC-AC-10002335       -1.0497
#          OFF-SU-10000432       -1.0410
# Central  OFF-BI-10003982       -1.0385
# East     FUR-CH-10002774       -1.0196
# Central  FUR-FU-10001918       -0.9933
# West     OFF-ST-10000321       -0.9468
# East     OFF-BI-10002949       -0.9120
# South    TEC-AC-10004877       -0.8280
# East     OFF-BI-10004656       -0.8208
# South    TEC-AC-10002718       -0.7295
# East     OFF-FA-10001135       -0.7128
# West     OFF-FA-10003472       -0.6048
# Central  TEC-AC-10000387       -0.6008
# East     OFF-BI-10002609       -0.5364
#          OFF-FA-10004968       -0.5236
#          OFF-SU-10001935       -0.5232
# Central  OFF-BI-10001097       -0.4984
# East     OFF-BI-10003727       -0.4180
# West     OFF-FA-10004838       -0.3906
# East     TEC-AC-10001542       -0.3444
# West     FUR-FU-10000820       -0.3398
# South    TEC-PH-10003187        0.0000
#          OFF-ST-10002574        0.0000
#          OFF-ST-10004337        0.0000
# Central  OFF-ST-10001097        0.0000
# West     FUR-CH-10004997        0.0000
#          FUR-CH-10002961        0.0000
# East     OFF-ST-10001097        0.0000
#          OFF-ST-10004123        0.0000
#          OFF-ST-10000934        0.0000
# West     OFF-ST-10000934        0.0000
#          OFF-FA-10003467        0.0000
# South    FUR-BO-10002824        0.0000
#          FUR-CH-10002961        0.0000
# Central  TEC-AC-10001635        0.0000
#          FUR-TA-10004619        0.0000
# South    FUR-FU-10001488        0.0000
# East     FUR-TA-10004619        0.0000
# South    FUR-CH-10002024        0.0000
#          TEC-PH-10004833        0.0000
# East     OFF-ST-10004337        0.0000
# Central  FUR-CH-10002758        0.0000
# West     FUR-CH-10002024        0.0000
# East     OFF-ST-10003324        0.0000
# West     OFF-FA-10000254        0.0000
# Central  FUR-CH-10001270        0.0000
# West     OFF-ST-10002957        0.0000
# Central  OFF-BI-10002225       -0.0000
# South    OFF-BI-10001191        0.0000
# Central  OFF-FA-10003467        0.0000
# West     OFF-ST-10002574        0.0000
# Central  FUR-BO-10003894        0.0000
# East     OFF-SU-10003936        0.0636
# West     OFF-FA-10000053        0.1134
# Central  OFF-BI-10002393        0.1148
# East     OFF-SU-10003002        0.1512
# South    OFF-SU-10003002        0.1512
# West     OFF-FA-10001135        0.1980
#          OFF-FA-10004968        0.2244
# Central  TEC-PH-10000148        0.2598
# West     OFF-SU-10002189        0.2779
# Central  OFF-FA-10003472        0.3024
# South    OFF-FA-10000053        0.3024
#          OFF-ST-10000321        0.3156
#          OFF-ST-10004835        0.3348
#          TEC-AC-10002380        0.3399
#          OFF-SU-10002522        0.3492
# East     OFF-AR-10002221        0.3640
# Central  OFF-SU-10001574        0.3650
# South    OFF-AR-10000940        0.4116
#          OFF-SU-10001212        0.4160
#          OFF-AR-10002467        0.4172
#          FUR-FU-10001852        0.4176
# East     FUR-FU-10003247        0.4196
# South    TEC-AC-10003709        0.4752
#          OFF-AR-10003087        0.4984
# East     TEC-AC-10003063        0.5000
# Central  OFF-AR-10000369        0.5004
# East     FUR-FU-10003724        0.5022
# South    OFF-AR-10001868        0.5040
# West     OFF-SU-10004661        0.5100
#          OFF-FA-10002701        0.5376
# South    OFF-FA-10001883        0.5446
# Central  OFF-AR-10002221        0.5460
#          TEC-AC-10004877        0.5520
# South    OFF-ST-10002486        0.5584
# East     OFF-FA-10000490        0.5828
# South    OFF-AP-10003622        0.5850
#          OFF-AR-10003958        0.5904
# East     OFF-AR-10003958        0.5904
# West     OFF-AR-10000127        0.5904
# East     OFF-AR-10000896        0.5904
# Central  TEC-PH-10000376        0.5994
# East     TEC-AC-10000057        0.5998
#          OFF-FA-10003472        0.6048
#          OFF-AR-10002335        0.6192
# South    OFF-AR-10002335        0.6192
# West     OFF-ST-10000617        0.6258
# Central  OFF-AR-10004752        0.6408
# West     OFF-FA-10002676        0.6516
# East     OFF-BI-10000848        0.6564
# Central  OFF-ST-10004835        0.6696
# South    OFF-FA-10000490        0.6696
# Central  OFF-LA-10000262        0.6786
# South    OFF-ST-10000419        0.6790
# Central  OFF-AR-10003190        0.6912
# South    TEC-PH-10003655        0.6930
# Central  TEC-PH-10004071        0.6993
# East     OFF-AR-10001972        0.7056
#          OFF-FA-10004395        0.7065
# South    TEC-AC-10002370        0.7092
# East     OFF-AP-10004052        0.7110
# Central  OFF-AR-10003087        0.7120
# East     OFF-AR-10000369        0.7228
# Central  OFF-BI-10002954        0.7312
# West     OFF-AR-10002257        0.7348
# Central  OFF-AR-10002257        0.7348
# South    TEC-AC-10003433        0.7425
# East     OFF-BI-10002498        0.7476
# Central  OFF-AR-10001547        0.7735
# East     OFF-BI-10002764        0.7752
# Central  OFF-FA-10001332        0.7776
# South    TEC-PH-10000148        0.7794
# Central  OFF-AR-10001246        0.7938
# East     OFF-BI-10003274        0.7960
#          OFF-AR-10001118        0.8088
# West     OFF-SU-10001225        0.8096
# East     OFF-ST-10000419        0.8148
# West     OFF-AR-10000475        0.8162
#          OFF-BI-10004967        0.8320
# South    TEC-AC-10000199        0.8330
# West     OFF-FA-10003021        0.8460
#          TEC-AC-10001553        0.8495
# Central  OFF-LA-10002381        0.8624
#          OFF-AR-10004707        0.8680
# East     OFF-BI-10000145        0.8736
# South    OFF-ST-10002485        0.8792
#          OFF-AR-10001022        0.8804
# East     OFF-AR-10003481        0.8856
# Central  OFF-AR-10000634        0.8988
# South    OFF-AR-10000634        0.8988
# Central  FUR-CH-10004754        0.8994
#          TEC-PH-10000004        0.8994
# East     OFF-BI-10003529        0.9088
# Central  OFF-FA-10003059        0.9412
# West     OFF-ST-10000419        0.9506
# Central  OFF-ST-10002352        0.9576
#          OFF-BI-10003094        0.9856
# South    OFF-ST-10000876        0.9952
# Central  TEC-PH-10004897        0.9990
# South    OFF-AR-10003183        1.0020
# East     OFF-SU-10004115        1.0178
# Central  OFF-AR-10002804        1.0269
#          OFF-AR-10003514        1.0348
# South    OFF-LA-10000081        1.0500
#          OFF-AR-10004027        1.0584
# Central  OFF-ST-10003572        1.0620
# East     OFF-PA-10000327        1.0700
#          OFF-LA-10004178        1.0738
# South    OFF-AR-10000390        1.0738
# East     TEC-AC-10000158        1.0797
# West     OFF-AR-10000369        1.0842
#          OFF-BI-10003196        1.1220
# East     OFF-BI-10004140        1.1225
# Central  OFF-FA-10001561        1.1336
#          OFF-AR-10002067        1.1904
#          OFF-AR-10004790        1.1970
# East     TEC-AC-10003289        1.1994
# South    OFF-LA-10002368        1.2006
# East     OFF-BI-10004182        1.2064
# South    FUR-FU-10003708        1.2130
#          OFF-AR-10003156        1.2192
# East     FUR-FU-10001852        1.2528
#          OFF-AP-10001634        1.2528
#          OFF-BI-10003350        1.2760
# Central  OFF-BI-10000948        1.2843
#          OFF-BI-10000301        1.2940
#          OFF-BI-10004040        1.2950
# South    OFF-AP-10003914        1.3000
# West     OFF-BI-10000494        1.3050
# East     OFF-BI-10000138        1.3104
# South    OFF-AR-10001246        1.3230
# East     TEC-AC-10003433        1.3365
# West     OFF-FA-10001332        1.3536
# East     TEC-PH-10000169        1.3560
# South    OFF-LA-10004272        1.3583
# West     TEC-AC-10003657        1.3596
# South    OFF-BI-10004876        1.3622
# East     OFF-BI-10002557        1.3650
#          TEC-PH-10000576        1.3699
# South    FUR-FU-10003981        1.3728
#          TEC-PH-10003442        1.3750
# West     TEC-PH-10003442        1.3750
# Central  TEC-PH-10003442        1.3750
# East     OFF-BI-10003355        1.3944
# South    OFF-SU-10000946        1.4364
#          OFF-AR-10000246        1.4456
# West     OFF-FA-10000735        1.4600
# Central  OFF-ST-10000617        1.4602
# West     OFF-LA-10000134        1.4784
# East     TEC-PH-10000347        1.4850
#          OFF-AR-10004752        1.4952
# Central  OFF-SU-10001165        1.5012
#          TEC-AC-10002217        1.5040
#          OFF-AR-10004956        1.5066
#          OFF-AR-10001868        1.5120
# West     OFF-AR-10000823        1.5288
# Central  OFF-SU-10001664        1.5426
# South    OFF-ST-10004804        1.5444
# East     OFF-AP-10002906        1.5540
#          OFF-ST-10000649        1.5700
#          FUR-FU-10000206        1.5714
# Central  OFF-AR-10003405        1.5795
# West     OFF-BI-10004465        1.5840
# East     TEC-PH-10003800        1.5897
#          TEC-PH-10003655        1.6038
# West     OFF-AR-10001473        1.6072
#          OFF-ST-10000344        1.6116
# South    OFF-ST-10002344        1.6196
# West     OFF-ST-10002301        1.6272
# East     OFF-AR-10000475        1.6324
# Central  TEC-AC-10004510        1.6360
# South    OFF-LA-10002945        1.6380
# West     OFF-BI-10003529        1.6472
# South    OFF-PA-10004675        1.6510
# East     OFF-AR-10004269        1.6520
#          OFF-EN-10002600        1.6520
# South    OFF-LA-10001175        1.6704
# West     OFF-AR-10002578        1.6704
# East     OFF-ST-10002182        1.6712
#          OFF-ST-10004835        1.6740
# South    OFF-PA-10000682        1.6762
# East     OFF-BI-10004967        1.6848
# South    OFF-BI-10003314        1.6870
# East     OFF-SU-10004782        1.6900
#          TEC-AC-10002558        1.7055
# Central  OFF-AR-10001954        1.7115
# West     FUR-FU-10001756        1.7136
# East     OFF-FA-10004248        1.7138
#          OFF-BI-10002393        1.7220
# South    OFF-LA-10002195        1.7248
# East     OFF-LA-10000134        1.7248
# Central  OFF-LA-10002271        1.7248
# East     FUR-FU-10002885        1.7352
# West     TEC-PH-10002185        1.7375
# South    OFF-AR-10002766        1.7514
# West     OFF-AR-10001022        1.7608
# East     OFF-AR-10001022        1.7608
# South    OFF-BI-10004236        1.7616
# Central  OFF-LA-10000973        1.7640
# West     OFF-AR-10001683        1.7730
#          OFF-AR-10000422        1.7739
# South    OFF-AR-10003732        1.7792
# East     OFF-BI-10004716        1.7808
# South    OFF-AR-10004790        1.7955
# Central  TEC-AC-10003289        1.7991
#          OFF-LA-10002787        1.8000
# West     OFF-LA-10003714        1.8000
# East     TEC-AC-10000387        1.8024
# Central  OFF-PA-10004355        1.8144
#          OFF-PA-10003953        1.8144
# East     OFF-SU-10004290        1.8468
# Central  FUR-FU-10001706        1.8480
#          OFF-PA-10003001        1.8704
# West     OFF-SU-10001212        1.8720
# East     OFF-FA-10003021        1.8800
# Central  TEC-AC-10002134        1.8872
#          FUR-FU-10002445        1.8960
# East     OFF-AR-10001177        1.9024
#          OFF-BI-10000301        1.9410
# South    OFF-SU-10004115        1.9629
# West     OFF-AR-10002833        1.9656
# East     OFF-BI-10004826        1.9812
# Central  OFF-LA-10000248        1.9926
# South    OFF-AR-10000422        1.9929
#          OFF-AR-10002804        2.0049
#          OFF-AR-10004956        2.0088
#          OFF-AP-10000804        2.0160
# Central  OFF-LA-10002368        2.0358
#          OFF-AR-10000823        2.0384
# East     OFF-BI-10003981        2.0430
# Central  OFF-AR-10001419        2.0650
# South    OFF-AR-10001770        2.0748
# East     OFF-AR-10001770        2.0748
#          FUR-FU-10002506        2.0784
#          OFF-ST-10000617        2.0860
# Central  OFF-LA-10003714        2.1000
# West     OFF-AR-10004272        2.1000
#          OFF-AR-10002221        2.1060
#          OFF-BI-10002897        2.1286
# East     OFF-PA-10004610        2.1400
#          OFF-BI-10004817        2.1564
# West     OFF-AR-10001216        2.1684
# East     OFF-EN-10003072        2.1728
# South    FUR-FU-10002597        2.1736
# East     TEC-AC-10002345        2.1750
# Central  OFF-AP-10001205        2.1792
#          OFF-AR-10000799        2.1888
# East     OFF-ST-10001325        2.2008
#          TEC-AC-10000487        2.2066
# South    OFF-AR-10001315        2.2176
# East     OFF-AR-10003251        2.2240
# Central  OFF-AR-10003338        2.2320
# South    OFF-BI-10002824        2.2380
#          OFF-AR-10002833        2.2386
#          OFF-ST-10002562        2.2512
# East     TEC-AC-10002217        2.2560
# Central  OFF-FA-10003021        2.2560
# South    OFF-AR-10000657        2.2575
#          OFF-AR-10002656        2.2712
#          TEC-AC-10002399        2.2824
# East     FUR-FU-10003981        2.2880
#          OFF-SU-10004768        2.2960
# West     OFF-AR-10000315        2.3025
# East     OFF-BI-10002982        2.3154
# West     OFF-PA-10004000        2.3177
# Central  OFF-AR-10004817        2.3220
# South    OFF-AR-10001374        2.3328
#          OFF-FA-10001332        2.3328
# West     OFF-AR-10004078        2.3360
# South    OFF-AP-10000358        2.3364
# West     OFF-PA-10004948        2.3406
# Central  OFF-LA-10004425        2.3409
# West     OFF-AP-10002222        2.3409
# East     OFF-BI-10003291        2.3571
# South    OFF-AP-10002287        2.3598
# ...
# West     OFF-AP-10000240      217.1288
# East     TEC-AC-10002567      217.5728
# West     TEC-AC-10003033      217.7670
# Central  OFF-AP-10001058      218.2518
#          TEC-PH-10001336      219.2830
# South    OFF-BI-10000632      219.6546
# Central  TEC-AC-10003198      220.1160
#          TEC-PH-10003072      220.4853
# West     OFF-PA-10000100      220.9361
#          OFF-BI-10003656      220.9870
# East     TEC-AC-10001606      221.9778
# South    TEC-PH-10002033      222.1596
# West     OFF-ST-10002292      222.5880
#          TEC-MA-10004241      223.0540
# South    OFF-ST-10003208      223.1958
# West     TEC-MA-10003183      223.9860
# South    FUR-CH-10002331      224.2674
# East     FUR-CH-10004997      225.5760
#          TEC-MA-10004626      225.6000
# Central  OFF-ST-10002011      226.3626
# South    TEC-PH-10000526      226.5364
# Central  OFF-AP-10001005      228.0850
# West     TEC-AC-10002842      228.4800
#          OFF-EN-10001453      229.2848
# South    TEC-PH-10002563      229.3018
# West     OFF-PA-10001815      230.5920
# Central  FUR-TA-10000198      231.4116
# East     OFF-AP-10003217      231.9940
# Central  TEC-PH-10004042      232.1254
# South    FUR-FU-10003553      233.8180
#          OFF-EN-10000056      233.9848
# East     TEC-AC-10000892      234.0000
# West     OFF-BI-10001718      234.8066
#          OFF-AP-10001391      235.5264
#          FUR-CH-10004086      236.3013
# Central  TEC-PH-10002922      236.5860
# West     TEC-PH-10001530      236.9821
# East     OFF-AP-10000179      238.1234
# West     FUR-CH-10000155      239.2400
#          FUR-FU-10004188      239.3820
# East     TEC-AC-10002473      239.5272
#          OFF-PA-10000357      239.6736
# South    TEC-AC-10004171      239.9760
#          TEC-MA-10003183      239.9850
# East     OFF-ST-10000036      240.0597
# Central  FUR-TA-10001950      241.1046
#          FUR-CH-10004626      242.1360
#          FUR-CH-10003379      242.2330
#          OFF-ST-10003816      243.1422
# West     OFF-EN-10003296      244.2960
#          TEC-AC-10001908      244.9755
# East     TEC-CO-10001046      244.9965
# Central  OFF-ST-10001496      245.0584
#          OFF-ST-10003306      245.7192
# South    TEC-PH-10000369      246.9404
# East     TEC-PH-10003601      247.4850
#          OFF-BI-10004519      248.9700
# South    FUR-FU-10003664      249.1506
# West     TEC-AC-10002253      249.3600
#          OFF-ST-10001526      250.2864
# East     FUR-CH-10000155      251.2020
# South    TEC-AC-10004469      252.4840
# East     OFF-BI-10004390      252.5880
# West     OFF-AP-10000828      253.3720
# Central  TEC-AC-10004659      255.4650
# East     FUR-FU-10000965      255.5448
# West     TEC-AC-10000474      256.4730
# Central  TEC-PH-10004536      256.4810
# East     FUR-CH-10004287      256.8660
# West     FUR-CH-10004063      257.3820
# East     OFF-AP-10002518      258.0710
# West     OFF-EN-10001434      258.2790
#          TEC-AC-10000736      259.1676
#          TEC-AC-10000892      259.2000
#          FUR-TA-10000688      259.2415
#          FUR-TA-10000617      259.4070
# South    OFF-BI-10001359      260.1271
# East     FUR-CH-10000749      260.6112
# Central  TEC-PH-10004120      263.0208
# East     TEC-PH-10001578      263.2175
# Central  TEC-PH-10004345      263.8900
# West     TEC-AC-10004171      263.9736
# Central  TEC-AC-10001908      264.9735
#          TEC-PH-10001835      265.4232
# South    OFF-ST-10003716      265.5236
# West     OFF-PA-10001736      266.5088
#          TEC-AC-10000844      268.5684
#          TEC-PH-10001760      268.6500
#          OFF-BI-10002026      269.1108
# East     TEC-MA-10004552      269.3080
#          OFF-AP-10003779      269.7240
# Central  TEC-CO-10001943      269.9865
#          FUR-CH-10002084      270.5780
# West     FUR-CH-10004495      270.8820
# East     FUR-BO-10002545      271.4192
# West     FUR-FU-10001215      271.7190
# South    FUR-TA-10002530      271.7640
# West     TEC-AC-10001465      272.4000
#          FUR-FU-10000576      272.7920
# East     TEC-PH-10004094      272.9825
# West     OFF-PA-10000062      273.1512
#          FUR-FU-10004864      273.9566
#          OFF-PA-10000806      274.3020
# South    OFF-BI-10004632      274.4910
# West     OFF-PA-10003228      275.8524
# Central  OFF-PA-10000357      275.8627
# East     FUR-CH-10003746      276.0428
#          OFF-ST-10000585      277.5360
# Central  TEC-PH-10002103      278.2104
# East     OFF-AP-10000938      278.7048
#          FUR-BO-10002598      280.3710
# West     FUR-BO-10002916      280.4072
# East     FUR-CH-10001394      280.7920
# Central  TEC-AC-10004145      282.4887
# South    FUR-CH-10001270      284.6250
#          FUR-FU-10004665      284.9184
# Central  FUR-FU-10004665      284.9184
#          OFF-ST-10000078      286.3836
# West     FUR-FU-10001979      288.4288
#          FUR-CH-10002320      288.8820
#          OFF-AP-10001242      289.7280
# South    OFF-AP-10002734      290.3016
#          TEC-PH-10001128      293.9804
#          TEC-PH-10003273      294.8166
# West     OFF-LA-10003510      294.9198
#          TEC-AC-10002926      295.4409
# East     TEC-MA-10002859      296.0671
# South    TEC-PH-10003601      296.9820
#          FUR-FU-10002937      297.6900
# Central  OFF-PA-10000418      297.7740
# East     TEC-PH-10002447      298.6855
# South    OFF-PA-10004359      301.9680
# West     OFF-ST-10004340      302.1948
# South    OFF-PA-10000100      304.1458
# East     OFF-ST-10000689      304.2360
#          TEC-AC-10002842      304.6400
# West     OFF-AP-10003590      305.1300
# Central  OFF-AP-10003590      305.1300
# East     OFF-AP-10002311      305.5164
#          TEC-PH-10002310      305.5824
# South    FUR-CH-10004853      306.4894
# Central  FUR-BO-10002545      307.9564
# West     TEC-AC-10000420      309.3558
#          OFF-PA-10000357      309.5968
# East     FUR-FU-10004306      310.8800
# West     OFF-ST-10001780      310.9872
#          FUR-TA-10003392      311.8878
# East     TEC-AC-10002402      311.9610
# South    TEC-CO-10003236      311.9948
#          FUR-CH-10002602      314.0384
#          FUR-TA-10003238      314.0586
# West     TEC-PH-10002726      314.9400
# East     TEC-PH-10003691      314.9750
# West     TEC-CO-10004202      314.9895
# South    FUR-TA-10001086      316.1392
# East     TEC-PH-10001336      317.3154
# South    OFF-BI-10004318      318.3016
# East     FUR-BO-10000362      319.7326
#          TEC-AC-10004571      319.9680
#          TEC-PH-10000895      320.3822
# South    OFF-AP-10003057      322.1829
# East     TEC-PH-10001760      322.3800
# Central  TEC-PH-10001494      323.9460
#          FUR-CH-10000015      324.9000
# East     TEC-AC-10002800      327.4345
#          TEC-PH-10001459      327.5922
# South    FUR-CH-10003379      327.7270
# West     OFF-AP-10004487      335.0384
# Central  TEC-CO-10001449      335.9944
# South    TEC-AC-10003198      336.6480
# Central  OFF-LA-10003930      337.2033
# East     OFF-AP-10002118      337.2192
# Central  TEC-PH-10001363      341.9940
# South    TEC-PH-10001530      343.5266
# Central  TEC-CO-10004202      344.9885
# East     OFF-PA-10003302      345.1856
#          OFF-PA-10000418      348.1020
#          FUR-FU-10000576      348.3344
# West     OFF-ST-10000142      349.3392
# Central  FUR-TA-10000617      350.4270
# West     FUR-CH-10001394      350.9900
# East     TEC-PH-10004977      354.7419
# South    FUR-CH-10002073      354.8052
# East     TEC-AC-10004666      355.4466
#          FUR-CH-10004983      355.7658
#          FUR-CH-10003379      356.2250
#          TEC-PH-10003012      357.2568
# West     TEC-MA-10000418      359.9988
# South    TEC-PH-10002352      362.6870
# West     FUR-TA-10002903      363.5940
# East     TEC-MA-10003356      364.4595
#          FUR-BO-10002613      365.2740
# Central  OFF-BI-10004519      373.4550
# West     TEC-PH-10002200      373.9320
# Central  TEC-PH-10002584      375.5940
# East     FUR-CH-10001215      375.7350
# Central  TEC-PH-10001760      376.1100
# East     FUR-FU-10002937      377.0740
# West     TEC-AC-10004571      377.9622
#          TEC-CO-10001943      377.9811
# Central  FUR-FU-10003664      378.0216
#          TEC-PH-10003645      378.1674
#          TEC-AC-10003832      381.4424
# West     OFF-PA-10003395      381.6540
# Central  FUR-CH-10002073      383.9310
# South    FUR-TA-10002645      386.8350
# West     FUR-TA-10003748      388.4088
# South    FUR-TA-10004915      388.8128
#          OFF-PA-10000994      390.0420
# East     FUR-CH-10004218      393.8220
#          TEC-PH-10001944      394.0650
# Central  FUR-CH-10000988      394.2680
# East     OFF-BI-10003656      394.3768
#          TEC-AC-10004171      395.9604
# West     TEC-AC-10003911      396.7752
# Central  FUR-CH-10004675      396.9056
# South    OFF-ST-10003805      400.0450
# West     TEC-PH-10001459      403.1904
#          OFF-PA-10001878      404.4857
# South    TEC-CO-10004202      404.9865
# West     FUR-TA-10001705      408.1920
# Central  FUR-CH-10004086      411.3393
# West     OFF-AP-10002534      412.4680
# East     TEC-AC-10001432      412.6320
# South    TEC-AC-10002049      415.3950
#          TEC-PH-10000560      419.9880
# Central  OFF-BI-10003650      420.7840
#          OFF-BI-10003091      421.0824
# South    FUR-CH-10001854      421.1760
# East     OFF-BI-10001071      422.2680
#          TEC-AC-10002001      422.3736
# South    FUR-CH-10000309      422.5100
#          OFF-AP-10002518      425.3722
# West     TEC-PH-10001817      426.0200
#          OFF-ST-10001490      428.3280
#          OFF-AP-10003057      429.5772
# South    TEC-AC-10001838      429.9785
# West     TEC-AC-10003610      431.9280
#          TEC-MA-10000488      431.9946
#          TEC-PH-10001795      433.9930
# East     TEC-PH-10004539      436.5669
#          FUR-CH-10001708      437.0380
#          FUR-CH-10000454      439.1640
#          FUR-CH-10002335      439.7398
#          TEC-CO-10001571      439.9920
# West     TEC-AC-10000990      440.7648
# Central  TEC-AC-10000990      440.7648
# West     TEC-AC-10003095      441.9660
#          FUR-TA-10000577      442.2267
#          OFF-ST-10002615      443.4716
# Central  FUR-TA-10001095      444.4395
# East     OFF-AP-10000828      448.8304
# South    FUR-CH-10000015      450.5280
# Central  TEC-PH-10003012      454.2705
# West     TEC-PH-10002885      454.8810
#          FUR-TA-10002958      464.5444
# East     TEC-CO-10002313      467.9922
#          FUR-CH-10000785      477.7872
#          FUR-CH-10002320      481.4700
# Central  TEC-CO-10001766      485.9892
# East     FUR-CH-10004675      488.4992
# West     OFF-ST-10000046      491.1120
# South    FUR-TA-10001932      493.7856
# West     TEC-CO-10001571      494.9910
# South    TEC-AC-10003174      495.8340
# East     OFF-BI-10003925      496.6272
# South    OFF-ST-10001526      500.5728
#          FUR-TA-10003569      501.2250
# West     OFF-PA-10000675      502.1275
# East     OFF-AP-10002651      503.7822
#          OFF-ST-10000078      503.8230
# Central  TEC-PH-10000895      503.9720
# West     TEC-AC-10004975      507.9690
# East     OFF-AP-10000891      511.3680
#          OFF-BI-10004600      515.1860
#          OFF-PA-10001970      515.3418
# Central  TEC-PH-10004165      516.9812
# South    TEC-PH-10000984      517.4136
# East     TEC-AC-10004145      517.4793
# Central  FUR-CH-10004495      517.6856
#          FUR-CH-10003746      519.9876
# West     OFF-SU-10000151      524.0096
#          OFF-ST-10003208      526.2340
# South    TEC-AC-10003870      527.9840
# East     TEC-PH-10001494      530.9115
# West     FUR-TA-10004619      541.6540
# Central  TEC-PH-10002624      545.1884
# East     TEC-PH-10002834      548.9695
# West     OFF-PA-10004359      549.4140
# Central  OFF-ST-10001490      553.2570
# East     FUR-CH-10002073      553.3902
# Central  FUR-CH-10004063      554.8012
# South    FUR-CH-10000454      561.1540
#          OFF-LA-10003930      567.2487
# West     OFF-AP-10002684      583.5840
#          FUR-FU-10002937      585.4570
# East     OFF-BI-10004318      588.1660
# Central  FUR-CH-10002335      589.3420
# East     TEC-PH-10002114      592.7896
#          TEC-PH-10000984      603.6492
# West     OFF-BI-10003091      604.7460
# Central  FUR-CH-10000847      605.2384
# East     TEC-PH-10001835      606.6816
#          FUR-CH-10004086      609.7157
# West     OFF-LA-10003930      613.4544
# East     OFF-BI-10003091      618.1848
# West     TEC-MA-10004002      621.2115
# East     OFF-ST-10001780      621.9744
# West     FUR-CH-10001215      626.2250
#          FUR-TA-10001307      629.0100
# South    TEC-CO-10001046      629.9910
#          TEC-AC-10004145      632.4747
# West     OFF-ST-10003306      634.2984
# East     OFF-ST-10001526      637.7490
# South    OFF-BI-10003650      641.6956
# East     FUR-CH-10000595      643.6800
# West     OFF-BI-10004600      643.9825
# East     OFF-AP-10003849      644.0760
# West     FUR-CH-10004287      646.3080
# East     TEC-MA-10004212      648.5624
# West     OFF-AP-10001058      654.7554
#          TEC-CO-10000971      659.9780
# Central  TEC-AC-10003033      673.0980
#          FUR-CH-10001854      673.8816
# South    FUR-BO-10004695      676.8652
# West     OFF-BI-10004584      682.5168
# East     FUR-CH-10002331      687.0414
#          TEC-AC-10001838      693.9653
# West     TEC-CO-10002313      701.9883
# Central  TEC-CO-10001571      714.9870
#          OFF-PA-10000994      721.3680
#          FUR-CH-10000454      731.9400
# East     OFF-AP-10000275      735.0336
# Central  TEC-PH-10001795      743.9880
# South    FUR-CH-10004063      746.4078
# Central  OFF-AP-10003057      751.7601
# South    TEC-CO-10001943      751.9624
# West     OFF-AP-10002651      755.6733
# South    TEC-PH-10002496      764.3510
# Central  FUR-CH-10002320      770.3520
# East     TEC-PH-10004586      791.8900
# West     OFF-ST-10000078      795.5100
# East     TEC-PH-10003072      796.4469
# West     FUR-CH-10003973      803.0016
# Central  TEC-CO-10002313      803.9866
# West     TEC-CO-10002095      824.9835
# Central  TEC-AC-10004666      829.3754
# West     OFF-BI-10004632      845.1975
# South    OFF-AP-10002945      850.8395
# West     TEC-CO-10004115      869.9826
# South    TEC-AC-10003033      871.0680
# Central  TEC-CO-10001046      874.9875
# East     OFF-ST-10002011      880.2990
# West     TEC-MA-10000984      881.3700
#          OFF-ST-10001496      890.1386
# East     OFF-ST-10001490      892.3500
# South    TEC-PH-10000730      909.9818
# West     OFF-AP-10000275      918.7920
# East     TEC-MA-10002428      976.4370
#          OFF-ST-10000142     1031.3824
# West     TEC-AC-10001838     1031.9484
#          TEC-CO-10001046     1049.9850
#          OFF-BI-10004995     1061.5722
# Central  TEC-CO-10002095     1074.9785
# South    TEC-PH-10001459     1091.9740
# East     OFF-ST-10003208     1101.4622
#          OFF-AP-10002945     1106.3920
# West     OFF-BI-10004390     1136.6460
# East     TEC-PH-10002885     1156.6974
# Central  OFF-BI-10004600     1159.1685
# East     TEC-MA-10000488     1159.9855
#          OFF-ST-10002615     1169.1524
#          TEC-CO-10004115     1194.9761
#          TEC-CO-10002095     1224.9755
# West     OFF-BI-10003925     1257.0876
# South    OFF-BI-10003925     1276.4871
# Central  OFF-AP-10002945     1289.7885
# East     TEC-AC-10003033     1323.0995
# West     TEC-CO-10003236     1379.9770
# East     OFF-BI-10004995     1415.4296
# South    TEC-MA-10000864     1416.8000
#          TEC-CO-10001449     1439.9760
#          TEC-MA-10000010     1459.2000
# West     TEC-CO-10001766     1480.4671
#          TEC-AC-10003832     1589.7207
#          OFF-BI-10001120     1644.2913
# East     TEC-MA-10003673     1668.2050
# Central  OFF-BI-10001120     1700.9910
# West     TEC-AC-10003870     1715.9480
# South    TEC-MA-10001127     1854.9894
# East     TEC-AC-10002049     1855.4652
# West     TEC-AC-10002049     1938.7404
# East     TEC-MA-10002927     1995.9900
# West     TEC-CO-10001449     2183.9636
# East     TEC-MA-10001127     2239.9872
# West     TEC-CO-10003763     2267.9676
# Central  TEC-CO-10003763     2302.9671
# East     OFF-BI-10003527     2414.8810
#          OFF-BI-10001359     2610.2409
#          TEC-CO-10001449     3023.9496
# West     OFF-BI-10003527     3050.3760
# East     TEC-MA-10000045     3343.5360
#          TEC-MA-10001047     3717.9714
#          TEC-MA-10003979     3772.9461
# Central  OFF-BI-10000545     3804.9000
# South    OFF-BI-10003527     3812.9700
# West     TEC-CO-10004722     6719.9808
# Central  TEC-CO-10004722     8399.9760
# East     TEC-CO-10004722    10079.9712
# Name: Profit, dtype: float64

# %% [markdown]
# **Which product in which city is giving most profit**

# %%
df_store.groupby(by=['City','Product ID','Product Name'])['Profit'].sum().round(4).sort_values(ascending=False)
# Out:
# City               Product ID       Product Name
# Lafayette          TEC-CO-10004722  Canon imageCLASS 2200 Advanced Copier                                                                                              8399.9760
# Seattle            TEC-CO-10004722  Canon imageCLASS 2200 Advanced Copier                                                                                              6719.9808
# Newark             TEC-CO-10004722  Canon imageCLASS 2200 Advanced Copier                                                                                              5039.9856
# Detroit            OFF-BI-10000545  GBC Ibimaster 500 Manual ProClick Binding System                                                                                   4946.3700
# Minneapolis        OFF-BI-10001120  Ibico EPK-21 Electric Binding System                                                                                               4630.4755
# New York City      TEC-CO-10004722  Canon imageCLASS 2200 Advanced Copier                                                                                              3919.9888
# Atlanta            OFF-BI-10003527  Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind                                                        3812.9700
# New York City      TEC-MA-10000045  Zebra ZM400 Thermal Label Printer                                                                                                  3343.5360
# Arlington          TEC-MA-10001127  HP Designjet T520 Inkjet Large Format Printer - 24" Color                                                                          2799.9840
# Providence         TEC-CO-10001449  Hewlett Packard LaserJet 3310 Copier                                                                                               2591.9568
# Jackson            OFF-BI-10004995  GBC DocuBind P400 Electric Binding System                                                                                          2504.2216
# Yonkers            TEC-MA-10003979  Ativa V4110MDD Micro-Cut Shredder                                                                                                  2400.9657
# Lakewood           TEC-MA-10001047  3D Systems Cube Printer, 2nd Generation, Magenta                                                                                   2365.9818
# Springfield        TEC-CO-10003763  Canon PC1060 Personal Laser Copier                                                                                                 2302.9671
# New York City      TEC-MA-10001127  HP Designjet T520 Inkjet Large Format Printer - 24" Color                                                                          2239.9872
#                    TEC-MA-10002927  Canon imageCLASS MF7460 Monochrome Digital Laser Multifunction Copier                                                              1995.9900
# Midland            OFF-BI-10003527  Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind                                                        1906.4850
# Sacramento         OFF-BI-10003527  Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind                                                        1906.4850
# Los Angeles        TEC-AC-10003870  Logitech Z-906 Speaker sys - home theater - 5.1-CH                                                                                 1715.9480
# New York City      TEC-MA-10003673  Hewlett-Packard Desktjet 6988DT Refurbished Printer                                                                                1668.2050
# North Las Vegas    OFF-BI-10001120  Ibico EPK-21 Electric Binding System                                                                                               1644.2913
# Seattle            TEC-CO-10001766  Canon PC940 Copier                                                                                                                 1480.4671
# Mobile             TEC-MA-10000010  Hewlett-Packard Deskjet 3050a All-in-One Color Inkjet Printer                                                                      1459.2000
# New York City      OFF-BI-10001359  GBC DocuBind TL300 Electric Binding System                                                                                         1453.1238
# Atlanta            TEC-CO-10001449  Hewlett Packard LaserJet 3310 Copier                                                                                               1439.9760
# Florence           TEC-MA-10000864  Cisco 9971 IP Video Phone Charcoal                                                                                                 1416.8000
# New York City      OFF-BI-10004995  GBC DocuBind P400 Electric Binding System                                                                                          1415.4296
# Great Falls        TEC-CO-10003236  Canon Image Class D660 Copier                                                                                                      1379.9770
# New York City      TEC-MA-10003979  Ativa V4110MDD Micro-Cut Shredder                                                                                                  1371.9804
#                    TEC-MA-10001047  3D Systems Cube Printer, 2nd Generation, Magenta                                                                                   1351.9896
# Los Angeles        TEC-CO-10001449  Hewlett Packard LaserJet 3310 Copier                                                                                               1343.9776
# San Francisco      TEC-CO-10003763  Canon PC1060 Personal Laser Copier                                                                                                 1322.9811
# Virginia Beach     OFF-BI-10003925  Fellowes PB300 Plastic Comb Binding Machine                                                                                        1276.4871
# Columbia           OFF-BI-10003527  Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind                                                        1270.9900
# Roswell            OFF-BI-10001359  GBC DocuBind TL300 Electric Binding System                                                                                         1264.7559
# Jamestown          TEC-PH-10002885  Apple iPhone 5                                                                                                                     1228.1787
# New York City      TEC-MA-10000488  Bady BDG101FRU Card Printer                                                                                                        1159.9855
#                    OFF-BI-10003527  Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind                                                        1143.8910
# Philadelphia       TEC-CO-10004722  Canon imageCLASS 2200 Advanced Copier                                                                                              1119.9968
# Seattle            TEC-AC-10002049  Plantronics Savi W720 Multi-Device Wireless Headset System                                                                         1113.9480
#                    OFF-BI-10004600  Ibico Ibimaster 300 Manual Binding System                                                                                          1103.9700
#                    OFF-BI-10004995  GBC DocuBind P400 Electric Binding System                                                                                          1061.5722
# Los Angeles        TEC-CO-10001046  Canon Imageclass D680 Copier / Fax                                                                                                 1049.9850
# New York City      TEC-CO-10004115  Sharp AL-1530CS Digital Copier                                                                                                     1014.9797
# Burlington         FUR-BO-10004834  Riverside Palais Royal Lawyers Bookcase, Royale Cherry Finish                                                                      1013.1270
# New York City      TEC-AC-10003033  Plantronics CS510 - Over-the-Head monaural Wireless Headset System                                                                  979.9515
# Los Angeles        TEC-CO-10003763  Canon PC1060 Personal Laser Copier                                                                                                  944.9865
# Seattle            OFF-BI-10003925  Fellowes PB300 Plastic Comb Binding Machine                                                                                         942.8157
# Springfield        TEC-PH-10000730  Samsung Galaxy S4 Active                                                                                                            909.9818
# Warwick            TEC-CO-10002095  Hewlett Packard 610 Color Digital Copier / Printer                                                                                  899.9820
# Los Angeles        OFF-BI-10004390  GBC DocuBind 200 Manual Binding Machine                                                                                             884.0580
# Chicago            TEC-CO-10001046  Canon Imageclass D680 Copier / Fax                                                                                                  874.9875
# New York City      TEC-PH-10004586  Wilson SignalBoost 841262 DB PRO Amplifier Kit                                                                                      863.8800
# Fayetteville       OFF-BI-10001359  GBC DocuBind TL300 Electric Binding System                                                                                          843.1706
# Minneapolis        OFF-BI-10001359  GBC DocuBind TL300 Electric Binding System                                                                                          843.1706
# Morristown         OFF-BI-10001359  GBC DocuBind TL300 Electric Binding System                                                                                          843.1706
# Huntington Beach   TEC-CO-10001449  Hewlett Packard LaserJet 3310 Copier                                                                                                839.9860
# Jackson            TEC-AC-10004666  Maxell iVDR EX 500GB Cartridge                                                                                                      829.3754
# Indianapolis       OFF-AP-10002945  Honeywell Enviracaire Portable HEPA Air Cleaner for 17' x 22' Room                                                                  793.7160
# Newark             OFF-ST-10002011  Smead Adjustable Mobile File Trolley with Lockable Top                                                                              792.2691
# San Diego          TEC-AC-10003832  Logitech P710e Mobile Speakerphone                                                                                                  782.7696
# Minneapolis        FUR-CH-10002320  Hon Pagoda Stacking Chairs                                                                                                          770.3520
# New York City      TEC-MA-10002428  Fellowes Powershred HS-440 4-Sheet High Security Shredder                                                                           767.2005
#                    OFF-ST-10002615  Dual Level, Single-Width Filing Carts                                                                                               765.9964
# Columbus           TEC-PH-10001459  Samsung Galaxy Mega 6.3                                                                                                             764.3818
# Seattle            OFF-BI-10003527  Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind                                                         762.5940
# Henderson          OFF-BI-10003650  GBC DocuBind 300 Electric Binding Machine                                                                                           757.4112
# Independence       OFF-BI-10003650  GBC DocuBind 300 Electric Binding Machine                                                                                           757.4112
# Newport News       TEC-CO-10001943  Canon PC-428 Personal Copier                                                                                                        751.9624
# Columbia           OFF-AP-10003057  Honeywell Enviracaire Portable HEPA Air Cleaner for 16' x 20' Room                                                                  751.7601
# Henderson          FUR-CH-10004063  Global Deluxe High-Back Manager's Chair                                                                                             746.4078
# Omaha              TEC-PH-10001795  ClearOne CHATAttach 160 - speaker phone                                                                                             743.9880
# Providence         TEC-AC-10002049  Plantronics Savi W720 Multi-Device Wireless Headset System                                                                          742.6320
# Morristown         OFF-AP-10000275  Sanyo Counter Height Refrigerator with Crisper, 3.6 Cubic Foot, Stainless Steel/Black                                               735.0336
# Buffalo            OFF-BI-10001359  GBC DocuBind TL300 Electric Binding System                                                                                          726.5619
# Des Moines         TEC-CO-10002313  Canon PC1080F Personal Copier                                                                                                       701.9883
# Arlington          TEC-PH-10002496  Cisco SPA301                                                                                                                        701.9550
# Detroit            FUR-CH-10002024  HON 5400 Series Task Chairs for Big and Tall                                                                                        700.9800
# Richmond           OFF-AP-10002945  Honeywell Enviracaire Portable HEPA Air Cleaner for 17' x 22' Room                                                                  694.5015
# San Francisco      OFF-BI-10004584  GBC ProClick 150 Presentation Binding System                                                                                        682.5168
# Detroit            TEC-MA-10000822  Lexmark MX611dhe Monochrome Laser Printer                                                                                           679.9960
# Madison            FUR-CH-10001854  Office Star - Professional Matrix Back Chair with 2-to-1 Synchro Tilt and Mesh Fabric Seat                                          673.8816
# New York City      TEC-PH-10003072  Panasonic KX-TG9541B DECT 6.0 Digital 2-Line Expandable Cordless Phone With Digital Answering System                                661.4559
# Brentwood          OFF-AP-10001058  Sanyo 2.5 Cubic Foot Mid-Size Office Refrigerators                                                                                  654.7554
# Springfield        TEC-AC-10003033  Plantronics CS510 - Over-the-Head monaural Wireless Headset System                                                                  653.3010
# Washington         TEC-MA-10004212  Cisco SPA525G2 5-Line IP Phone                                                                                                      648.5624
# New York City      TEC-PH-10001494  Polycom CX600 IP Phone VoIP phone                                                                                                   647.8920
# Columbia           OFF-ST-10003208  Adjustable Depth Letter/Legal Cart                                                                                                  631.4808
# Richmond           TEC-CO-10001046  Canon Imageclass D680 Copier / Fax                                                                                                  629.9910
# New York City      TEC-PH-10002834  Google Nexus 5                                                                                                                      629.9650
# Seattle            FUR-TA-10001307  SAFCO PlanMaster Heigh-Adjustable Drafting Table Base, 43w x 30d x 30-37h, Black                                                    629.0100
# New York City      OFF-AP-10003849  Hoover Shoulder Vac Commercial Portable Vacuum                                                                                      626.1850
# Fort Worth         TEC-CO-10002095  Hewlett Packard 610 Color Digital Copier / Printer                                                                                  624.9875
# Plainfield         OFF-ST-10001780  Tennsco 16-Compartment Lockers with Coat Rack                                                                                       621.9744
# Los Angeles        TEC-MA-10004002  Zebra GX420t Direct Thermal/Thermal Transfer Printer                                                                                621.2115
# Seattle            FUR-TA-10001889  Bush Advantage Collection Racetrack Conference Table                                                                                610.8624
# New York City      FUR-CH-10004086  Hon 4070 Series Pagoda Armless Upholstered Stacking Chairs                                                                          609.7157
# Newark             TEC-AC-10002049  Plantronics Savi W720 Multi-Device Wireless Headset System                                                                          607.6080
# New York City      TEC-PH-10001835  Jawbone JAMBOX Wireless Bluetooth Speaker                                                                                           606.6816
# Santa Ana          TEC-AC-10001838  Razer Tiamat Over Ear 7.1 Surround Sound PC Gaming Headset                                                                          601.9699
# New York City      TEC-AC-10001838  Razer Tiamat Over Ear 7.1 Surround Sound PC Gaming Headset                                                                          601.9699
#                    TEC-PH-10002114  Xiaomi Mi3                                                                                                                          592.7896
# Franklin           FUR-CH-10000454  Hon Deluxe Fabric Upholstered Stacking Chairs, Rounded Back                                                                         585.5520
# Providence         OFF-ST-10000142  Deluxe Rollaway Locking File with Drawer                                                                                            582.2320
# Lakeville          FUR-CH-10004063  Global Deluxe High-Back Manager's Chair                                                                                             580.5394
# Houston            TEC-CO-10002313  Canon PC1080F Personal Copier                                                                                                       569.9905
# Los Angeles        TEC-AC-10002049  Plantronics Savi W720 Multi-Device Wireless Headset System                                                                          556.9740
# New York City      FUR-CH-10002073  Hon Olson Stacker Chairs                                                                                                            553.3902
# Richmond           TEC-PH-10002624  Samsung Galaxy S4 Mini                                                                                                              545.1884
# Appleton           TEC-AC-10003033  Plantronics CS510 - Over-the-Head monaural Wireless Headset System                                                                  544.4175
# Indianapolis       FUR-CH-10003746  Hon 4070 Series Pagoda Round Back Stacking Chairs                                                                                   539.2464
# Huntsville         TEC-AC-10003870  Logitech Z-906 Speaker sys - home theater - 5.1-CH                                                                                  527.9840
# San Francisco      OFF-SU-10000151  High Speed Automatic Electric Letter Opener                                                                                         524.0096
# Tulsa              FUR-CH-10004495  Global Leather and Oak Executive Chair, Black                                                                                       523.7052
# Dover              TEC-AC-10004145  Logitech diNovo Edge Keyboard                                                                                                       517.4793
# Henderson          TEC-AC-10004145  Logitech diNovo Edge Keyboard                                                                                                       517.4793
# Los Angeles        OFF-ST-10001496  Standard Rollaway File with Lock                                                                                                    515.3434
# Henderson          FUR-CH-10000454  Hon Deluxe Fabric Upholstered Stacking Chairs, Rounded Back                                                                         512.3580
# New York City      OFF-AP-10000891  Kensington 7 Outlet MasterPiece HOMEOFFICE Power Control Center                                                                     511.3680
# San Francisco      OFF-AP-10002684  Acco 7-Outlet Masterpiece Power Center, Wihtout Fax/Phone Line Protection                                                           510.6360
# Beverly            OFF-AP-10002651  Hoover Upright Vacuum With Dirt Cup                                                                                                 503.7822
# San Diego          TEC-MA-10000984  Okidata MB760 Printer                                                                                                               503.6400
# Indianapolis       OFF-BI-10004600  Ibico Ibimaster 300 Manual Binding System                                                                                           496.7865
# Lakeville          OFF-AP-10002945  Honeywell Enviracaire Portable HEPA Air Cleaner for 17' x 22' Room                                                                  496.0725
# New York City      TEC-PH-10000984  Panasonic KX-TG9471B                                                                                                                493.8948
# Harrisonburg       FUR-TA-10001932  Chromcraft 48" x 96" Racetrack Double Pedestal Table                                                                                493.7856
# Seattle            FUR-TA-10002958  Bevis Oval Conference Table, Walnut                                                                                                 488.0326
# Evanston           TEC-CO-10001766  Canon PC940 Copier                                                                                                                  485.9892
# Providence         OFF-ST-10001490  Hot File 7-Pocket, Floor Stand                                                                                                      481.8690
# Cranston           FUR-CH-10002320  Hon Pagoda Stacking Chairs                                                                                                          481.4700
# Henderson          FUR-TA-10003392  Global Adaptabilities Conference Tables                                                                                             480.4758
# Lawrence           TEC-CO-10002313  Canon PC1080F Personal Copier                                                                                                       467.9922
# New York City      FUR-CH-10000595  Safco Contoured Stacking Chairs                                                                                                     464.8800
# Torrance           OFF-AP-10000275  Sanyo Counter Height Refrigerator with Crisper, 3.6 Cubic Foot, Stainless Steel/Black                                               459.3960
# Los Angeles        OFF-AP-10000275  Sanyo Counter Height Refrigerator with Crisper, 3.6 Cubic Foot, Stainless Steel/Black                                               459.3960
# New York City      OFF-BI-10000545  GBC Ibimaster 500 Manual ProClick Binding System                                                                                    456.5880
# Rochester          OFF-BI-10000545  GBC Ibimaster 500 Manual ProClick Binding System                                                                                    456.5880
# Indianapolis       TEC-CO-10002095  Hewlett Packard 610 Color Digital Copier / Printer                                                                                  449.9910
# Des Moines         TEC-CO-10002095  Hewlett Packard 610 Color Digital Copier / Printer                                                                                  449.9910
# Lehi               TEC-CO-10000971  Hewlett Packard 310 Color Digital Copier                                                                                            449.9850
# Columbus           FUR-FU-10002937  GE 48" Fluorescent Tube, Cool White Energy Saver, 34 Watts, 30/Box                                                                  446.5350
# Los Angeles        TEC-AC-10000990  Imation Bio 2GB USB Flash Drive Imation Corp                                                                                        440.7648
# New York City      FUR-CH-10000454  Hon Deluxe Fabric Upholstered Stacking Chairs, Rounded Back                                                                         439.1640
# San Francisco      TEC-CO-10004115  Sharp AL-1530CS Digital Copier                                                                                                      434.9913
# San Diego          TEC-CO-10004115  Sharp AL-1530CS Digital Copier                                                                                                      434.9913
# Los Angeles        OFF-AP-10003057  Honeywell Enviracaire Portable HEPA Air Cleaner for 16' x 20' Room                                                                  429.5772
# Milwaukee          FUR-CH-10004675  Lifetime Advantage Folding Chairs, 4/Carton                                                                                         427.4368
# Detroit            FUR-CH-10004086  Hon 4070 Series Pagoda Armless Upholstered Stacking Chairs                                                                          423.0085
# Columbia           FUR-CH-10000309  Global Comet Stacking Arm Chair                                                                                                     422.5100
# Hampton            OFF-BI-10001359  GBC DocuBind TL300 Electric Binding System                                                                                          421.5853
# Detroit            OFF-BI-10003091  GBC DocuBind TL200 Manual Binding Machine                                                                                           421.0824
# New York City      FUR-CH-10002024  HON 5400 Series Task Chairs for Big and Tall                                                                                        420.5880
# San Francisco      OFF-AP-10002651  Hoover Upright Vacuum With Dirt Cup                                                                                                 419.8185
# Burbank            TEC-MA-10001148  Swingline SM12-08 MicroCut Jam Free Shredder                                                                                        415.9896
# New York City      TEC-AC-10001432  Enermax Aurora Lite Keyboard                                                                                                        412.6320
# Detroit            FUR-CH-10002335  Hon GuestStacker Chair                                                                                                              412.5394
# Westminster        OFF-AP-10002534  3.6 Cubic Foot Counter Height Office Refrigerator                                                                                   412.4680
# Columbus           OFF-BI-10004632  Ibico Hi-Tech Manual Binding System                                                                                                 411.7365
# Franklin           FUR-BO-10002545  Atlantic Metals Mobile 3-Shelf Bookcases, Custom Colors                                                                             407.1288
# Burlington         OFF-ST-10001526  Iceberg Mobile Mega Data/Printer Cart                                                                                               406.7154
# Seattle            FUR-TA-10001705  Bush Advantage Collection Round Conference Table                                                                                    401.8140
# New York City      TEC-AC-10004171  Razer Kraken 7.1 Surround Sound Over Ear USB Gaming Headset                                                                         395.9604
# Dubuque            FUR-CH-10000988  Hon Olson Stacker Stools                                                                                                            394.2680
# Los Angeles        TEC-AC-10003832  Logitech P710e Mobile Speakerphone                                                                                                  391.3848
# Wilmington         OFF-BI-10003656  Fellowes PB200 Plastic Comb Binding Machine                                                                                         390.9770
# Jackson            FUR-TA-10004915  Office Impressions End Table, 20-1/2"H x 24"W x 20"D                                                                                388.8128
# Omaha              FUR-FU-10003664  Electrix Architect's Clamp-On Swing Arm Lamp, Black                                                                                 387.5676
# Springfield        FUR-TA-10002645  Hon Rectangular Conference Tables                                                                                                   386.8350
# Kent               OFF-LA-10003930  Dot Matrix Printer Tape Reel Labels, White, 5000/Box                                                                                385.3752
# Oklahoma City      FUR-CH-10002073  Hon Olson Stacker Chairs                                                                                                            383.9310
# Los Angeles        OFF-PA-10000675  Xerox 1919                                                                                                                          381.6169
#                    OFF-BI-10003527  Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind                                                         381.2970
# Seattle            OFF-BI-10004632  Ibico Hi-Tech Manual Binding System                                                                                                 381.2375
# Milwaukee          FUR-CH-10000847  Global Executive Mid-Back Manager's Chair                                                                                           378.2740
# Columbus           TEC-PH-10003645  Aastra 57i VoIP phone                                                                                                               378.1674
# Seattle            TEC-AC-10004571  Logitech G700s Rechargeable Gaming Mouse                                                                                            377.9622
# Los Angeles        TEC-MA-10000984  Okidata MB760 Printer                                                                                                               377.7300
# Houston            TEC-PH-10001760  Bose SoundLink Bluetooth Speaker                                                                                                    376.1100
# New York City      FUR-CH-10001215  Global Troy Executive Leather Low-Back Tilter                                                                                       375.7350
# Richmond           OFF-ST-10001526  Iceberg Mobile Mega Data/Printer Cart                                                                                               375.4296
# San Francisco      TEC-CO-10002095  Hewlett Packard 610 Color Digital Copier / Printer                                                                                  374.9925
# New York City      TEC-PH-10002200  Aastra 6757i CT Wireless VoIP phone                                                                                                 374.8656
# Atlanta            FUR-BO-10004695  O'Sullivan 2-Door Barrister Bookcase in Odessa Pine                                                                                 374.6286
# Muskogee           TEC-PH-10000895  Polycom VVX 310 VoIP phone                                                                                                          374.3792
# Columbia           FUR-CH-10002331  Hon 4700 Series Mobuis Mid-Back Task Chairs with Adjustable Arms                                                                    373.7790
# New York City      TEC-AC-10002049  Plantronics Savi W720 Multi-Device Wireless Headset System                                                                          371.3160
# Seattle            FUR-TA-10004575  Hon 5100 Series Wood Tables                                                                                                         366.6348
# New York City      TEC-MA-10003356  Panasonic KX MC6040 Color Laser Multifunction Printer                                                                               364.4595
# Los Angeles        TEC-PH-10002885  Apple iPhone 5                                                                                                                      363.9048
#                    OFF-ST-10002615  Dual Level, Single-Width Filing Carts                                                                                               362.8404
# Bellingham         TEC-AC-10004975  Plantronics Audio 995 Wireless Stereo Headset                                                                                       362.8350
# Montgomery         TEC-PH-10002352  Avaya IP Phone 1140E VoIP phone                                                                                                     362.6870
# Roswell            OFF-AP-10002518  Kensington 7 Outlet MasterPiece Power Center                                                                                        361.2994
# San Francisco      TEC-MA-10000418  Cubify CubeX 3D Printer Double Head Print                                                                                           359.9988
# New York City      TEC-PH-10004165  Mitel MiVoice 5330e IP Phone                                                                                                        357.4870
# Lakewood           TEC-PH-10004539  Wireless Extenders zBoost YX545 SOHO Signal Booster                                                                                 357.1911
# Greenwood          FUR-CH-10003379  Global Commerce Series High-Back Swivel/Tilt Chairs                                                                                 356.2250
# Seattle            FUR-TA-10003748  Bevis 36 x 72 Conference Tables                                                                                                     356.0414
# Columbia           TEC-AC-10004666  Maxell iVDR EX 500GB Cartridge                                                                                                      355.4466
# New York City      OFF-BI-10003656  Fellowes PB200 Plastic Comb Binding Machine                                                                                         353.5792
# Long Beach         TEC-PH-10001578  Polycom SoundStation2 EX Conference phone                                                                                           352.3065
# San Francisco      OFF-PA-10003395  Xerox 1941                                                                                                                          352.2960
# New York City      TEC-PH-10002885  Apple iPhone 5                                                                                                                      350.9082
# Broken Arrow       FUR-TA-10000617  Hon Practical Foundations 30 x 60 Training Table, Light Gray/Charcoal                                                               350.4270
# Seattle            OFF-ST-10000142  Deluxe Rollaway Locking File with Drawer                                                                                            349.3392
# New York City      OFF-ST-10000142  Deluxe Rollaway Locking File with Drawer                                                                                            349.3392
# Lafayette          FUR-TA-10003473  Bretford Rectangular Conference Table Tops                                                                                          346.0396
# Seattle            TEC-AC-10001838  Razer Tiamat Over Ear 7.1 Surround Sound PC Gaming Headset                                                                          343.9828
# Columbus           FUR-CH-10000015  Hon Multipurpose Stacking Arm Chairs                                                                                                342.2280
# Chicago            TEC-PH-10001363  Apple iPhone 5S                                                                                                                     341.9940
# New York City      OFF-AP-10002118  1.7 Cubic Foot Compact "Cube" Office Refrigerators                                                                                  337.2192
# Burlington         TEC-PH-10002555  Nortel Meridian M5316 Digital phone                                                                                                 336.6350
# Chicago            TEC-CO-10001449  Hewlett Packard LaserJet 3310 Copier                                                                                                335.9944
# Los Angeles        OFF-AP-10002651  Hoover Upright Vacuum With Dirt Cup                                                                                                 335.8548
# Seattle            FUR-TA-10004619  Hon Non-Folding Utility Tables                                                                                                      334.5510
# Burbank            OFF-ST-10000078  Tennsco 6- and 18-Compartment Lockers                                                                                               334.1142
# New York City      OFF-BI-10004519  GBC DocuBind P100 Manual Binding Machine                                                                                            331.9600
# Maple Grove        OFF-BI-10004600  Ibico Ibimaster 300 Manual Binding System                                                                                           331.1910
# Lafayette          OFF-BI-10004600  Ibico Ibimaster 300 Manual Binding System                                                                                           331.1910
# Plainfield         OFF-BI-10004600  Ibico Ibimaster 300 Manual Binding System                                                                                           331.1910
# Inglewood          TEC-CO-10001571  Sharp 1540cs Digital Laser Copier                                                                                                   329.9940
# New York City      TEC-CO-10001571  Sharp 1540cs Digital Laser Copier                                                                                                   329.9940
# Jackson            FUR-TA-10001095  Chromcraft Round Conference Tables                                                                                                  329.4081
# New York City      TEC-PH-10001459  Samsung Galaxy Mega 6.3                                                                                                             327.5922
# Tallahassee        TEC-PH-10001459  Samsung Galaxy Mega 6.3                                                                                                             327.5922
# Clinton            TEC-PH-10000895  Polycom VVX 310 VoIP phone                                                                                                          327.5818
# Jackson            TEC-PH-10001494  Polycom CX600 IP Phone VoIP phone                                                                                                   323.9460
# Springfield        OFF-AP-10003057  Honeywell Enviracaire Portable HEPA Air Cleaner for 16' x 20' Room                                                                  322.1829
# Fayetteville       OFF-BI-10004318  Ibico EB-19 Dual Function Manual Binding System                                                                                     318.3016
# Washington         FUR-CH-10000309  Global Comet Stacking Arm Chair                                                                                                     316.8825
# Decatur            FUR-TA-10001086  SAFCO PlanMaster Boards, 60w x 37-1/2d, White Melamine                                                                              316.1392
# Marietta           OFF-ST-10003805  24 Capacity Maxi Data Binder Racks, Pearl                                                                                           315.8250
# Dover              OFF-BI-10003091  GBC DocuBind TL200 Manual Binding Machine                                                                                           315.8118
# Franklin           OFF-ST-10003208  Adjustable Depth Letter/Legal Cart                                                                                                  315.7404
# San Francisco      OFF-ST-10003208  Adjustable Depth Letter/Legal Cart                                                                                                  315.7404
# Decatur            TEC-CO-10004202  Brother DCP1000 Digital 3 in 1 Multifunction Machine                                                                                314.9895
# Hempstead          OFF-BI-10004318  Ibico EB-19 Dual Function Manual Binding System                                                                                     314.8418
# San Francisco      OFF-BI-10003925  Fellowes PB300 Plastic Comb Binding Machine                                                                                         314.2719
# New York City      OFF-BI-10003925  Fellowes PB300 Plastic Comb Binding Machine                                                                                         314.2719
# Chesapeake         FUR-TA-10003238  Chromcraft Bull-Nose Wood 48" x 96" Rectangular Conference Tables                                                                   314.0586
# Louisville         FUR-CH-10002602  DMI Arturo Collection Mission-style Design Wood Chair                                                                               314.0384
# New York City      FUR-CH-10002331  Hon 4700 Series Mobuis Mid-Back Task Chairs with Adjustable Arms                                                                    313.2624
# Philadelphia       OFF-AP-10002945  Honeywell Enviracaire Portable HEPA Air Cleaner for 17' x 22' Room                                                                  312.6760
# Orlando            TEC-CO-10003236  Canon Image Class D660 Copier                                                                                                       311.9948
# Edmonds            FUR-TA-10002903  Bevis Round Bullnose 29" High Table Top                                                                                             311.6520
# Anaheim            OFF-ST-10001780  Tennsco 16-Compartment Lockers with Coat Rack                                                                                       310.9872
# Springfield        FUR-CH-10002073  Hon Olson Stacker Chairs                                                                                                            307.1448
# Mobile             FUR-CH-10004853  Global Manager's Adjustable Task Chair, Storm                                                                                       306.4894
# Madison            OFF-AP-10003590  Hoover WindTunnel Plus Canister Vacuum                                                                                              305.1300
# Pleasant Grove     OFF-AP-10003590  Hoover WindTunnel Plus Canister Vacuum                                                                                              305.1300
# Los Angeles        OFF-BI-10004632  Ibico Hi-Tech Manual Binding System                                                                                                 304.9900
# Charlotte          TEC-AC-10002049  Plantronics Savi W720 Multi-Device Wireless Headset System                                                                          303.8040
# Los Angeles        OFF-BI-10003091  GBC DocuBind TL200 Manual Binding Machine                                                                                           302.3730
# Watertown          OFF-BI-10003091  GBC DocuBind TL200 Manual Binding Machine                                                                                           302.3730
# Seattle            OFF-BI-10003091  GBC DocuBind TL200 Manual Binding Machine                                                                                           302.3730
# Richmond           OFF-PA-10004359  Multicolor Computer Printout Paper                                                                                                  301.9680
# Huntsville         OFF-PA-10000994  Xerox 1915                                                                                                                          301.9680
# Superior           OFF-PA-10000994  Xerox 1915                                                                                                                          301.9680
# Springfield        FUR-TA-10003569  Bretford CR8500 Series Meeting Room Furniture                                                                                       300.7350
# Philadelphia       TEC-AC-10003033  Plantronics CS510 - Over-the-Head monaural Wireless Headset System                                                                  300.2545
# New York City      TEC-PH-10002447  AT&T CL83451 4-Handset Telephone                                                                                                    298.6855
# Columbus           OFF-PA-10000418  Xerox 189                                                                                                                           297.7740
# Los Angeles        FUR-FU-10002937  GE 48" Fluorescent Tube, Cool White Energy Saver, 34 Watts, 30/Box                                                                  297.6900
# Columbia           OFF-AP-10002945  Honeywell Enviracaire Portable HEPA Air Cleaner for 17' x 22' Room                                                                  297.6435
# Franklin           OFF-AP-10002945  Honeywell Enviracaire Portable HEPA Air Cleaner for 17' x 22' Room                                                                  297.6435
# Oceanside          TEC-MA-10002859  Ativa MDM8000 8-Sheet Micro-Cut Shredder                                                                                            296.0671
# Meriden            FUR-CH-10002335  Hon GuestStacker Chair                                                                                                              294.6710
# Inglewood          OFF-BI-10003650  GBC DocuBind 300 Electric Binding Machine                                                                                           294.5488
# New York City      OFF-BI-10003650  GBC DocuBind 300 Electric Binding Machine                                                                                           294.5488
# Athens             TEC-PH-10001128  Motorola Droid Maxx                                                                                                                 293.9804
# ...
# Philadelphia       FUR-TA-10002530  Iceberg OfficeWorks 42" Round Tables                                                                                               -339.7050
# Long Beach         FUR-TA-10003238  Chromcraft Bull-Nose Wood 48" x 96" Rectangular Conference Tables                                                                  -347.1174
# Dallas             FUR-FU-10003601  Deflect-o RollaMat Studded, Beveled Mat for Medium Pile Carpeting                                                                  -348.6294
# Amarillo           FUR-CH-10002024  HON 5400 Series Task Chairs for Big and Tall                                                                                       -350.4900
# Chicago            FUR-FU-10000576  Luxo Professional Fluorescent Magnifier Lamp with Clamp-Mount Base                                                                 -356.7280
# Phoenix            FUR-BO-10004467  Bestar Classic Bookcase                                                                                                            -356.9643
# Denver             FUR-BO-10003546  Hon 4-Shelf Metal Bookcases                                                                                                        -363.5280
# Philadelphia       TEC-PH-10002645  LG G2                                                                                                                              -374.9925
# Troy               FUR-BO-10001918  Sauder Forest Hills Library with Doors, Woodland Oak Finish                                                                        -376.6932
# Pasadena           FUR-FU-10003806  Tenex Chairmat w/ Average Lip, 45" x 53"                                                                                           -378.4000
# Fort Lauderdale    FUR-TA-10000577  Bretford CR4500 Series Slim Rectangular Table                                                                                      -383.0310
# Dublin             TEC-MA-10001148  Swingline SM12-08 MicroCut Jam Free Shredder                                                                                       -383.9904
# Philadelphia       TEC-PH-10002200  Samsung Galaxy Note 2                                                                                                              -386.3916
# Phoenix            TEC-MA-10003356  Panasonic KX MC6040 Color Laser Multifunction Printer                                                                              -386.9570
# Chicago            OFF-AP-10003849  Hoover Shoulder Vac Commercial Portable Vacuum                                                                                     -393.6020
# Bloomington        FUR-TA-10004534  Bevis 44 x 96 Conference Tables                                                                                                    -407.6820
# Philadelphia       OFF-BI-10001359  GBC DocuBind TL300 Electric Binding System                                                                                         -412.6154
# Houston            OFF-BI-10004584  GBC ProClick 150 Presentation Binding System                                                                                       -417.0936
# Jacksonville       FUR-TA-10004289  BoxOffice By Design Rectangular and Half-Moon Meeting Room Tables                                                                  -420.0000
# Waco               OFF-BI-10004632  Ibico Hi-Tech Manual Binding System                                                                                                -426.9860
# Round Rock         FUR-FU-10001468  Tenex Antistatic Computer Chair Mats                                                                                               -427.4500
# Aurora             FUR-TA-10002958  Bevis Oval Conference Table, Walnut                                                                                                -430.6170
# Dallas             FUR-BO-10003272  O'Sullivan Living Dimensions 5-Shelf Bookcases                                                                                     -437.5404
# New York City      FUR-TA-10003473  Bretford Rectangular Conference Table Tops                                                                                         -447.5947
# Phoenix            FUR-TA-10001932  Chromcraft 48" x 96" Racetrack Double Pedestal Table                                                                               -448.8960
# San Antonio        OFF-AP-10002518  Kensington 7 Outlet MasterPiece Power Center                                                                                       -453.8490
# Jacksonville       FUR-TA-10001889  Bush Advantage Collection Racetrack Conference Table                                                                               -458.1468
# Phoenix            OFF-BI-10004600  Ibico Ibimaster 300 Manual Binding System                                                                                          -459.9875
# Philadelphia       OFF-BI-10003650  GBC DocuBind 300 Electric Binding Machine                                                                                          -462.8624
# Marion             FUR-TA-10004154  Riverside Furniture Oval Coffee Table, Oval End Table, End Table with Drawer                                                       -464.6970
# Aurora             FUR-TA-10004575  Hon 5100 Series Wood Tables                                                                                                        -465.5680
# New York City      FUR-TA-10001889  Bush Advantage Collection Racetrack Conference Table                                                                               -466.6310
# Chicago            OFF-AP-10000828  Avanti 4.4 Cu. Ft. Refrigerator                                                                                                    -470.5480
# Yuma               TEC-MA-10001148  Swingline SM12-08 MicroCut Jam Free Shredder                                                                                       -479.9880
# Philadelphia       FUR-TA-10002958  Bevis Oval Conference Table, Walnut                                                                                                -480.2032
#                    TEC-MA-10001681  Lexmark MarkNet N8150 Wireless Print Server                                                                                        -506.4570
# Houston            TEC-MA-10000822  Lexmark MX611dhe Monochrome Laser Printer                                                                                          -509.9970
# Carrollton         OFF-BI-10003925  Fellowes PB300 Plastic Comb Binding Machine                                                                                        -512.1468
# Springfield        FUR-BO-10001972  O'Sullivan 4-Shelf Bookcase in Odessa Pine                                                                                         -512.9552
# Aurora             FUR-TA-10002645  Hon Rectangular Conference Tables                                                                                                  -525.6405
# Oswego             OFF-BI-10004632  Ibico Hi-Tech Manual Binding System                                                                                                -533.7325
# Rockford           FUR-TA-10004256  Bretford “Just In Time” Height-Adjustable Multi-Task Work Tables                                                                   -538.4460
# New York City      FUR-TA-10001950  Balt Solid Wood Round Tables                                                                                                       -553.6476
# Philadelphia       TEC-MA-10004679  StarTech.com 10/100 VDSL2 Ethernet Extender Kit                                                                                    -559.3560
# Chicago            FUR-TA-10004289  BoxOffice By Design Rectangular and Half-Moon Meeting Room Tables                                                                  -566.5625
# Philadelphia       OFF-BI-10003656  Fellowes PB200 Plastic Comb Binding Machine                                                                                        -571.1664
# Greenville         TEC-MA-10002073  3D Systems Cube Printer, 2nd Generation, White                                                                                     -571.9956
# Columbus           TEC-PH-10000560  Samsung Galaxy S III - 16GB - pebble blue (T-Mobile)                                                                               -587.9832
# Philadelphia       FUR-TA-10004154  Riverside Furniture Oval Coffee Table, Oval End Table, End Table with Drawer                                                       -619.5960
#                    FUR-CH-10002024  HON 5400 Series Task Chairs for Big and Tall                                                                                       -630.8820
#                    TEC-MA-10001148  Okidata MB491 Multifunction Printer                                                                                                -643.7100
# Burlington         FUR-TA-10001889  Bush Advantage Collection Racetrack Conference Table                                                                               -653.2834
# Philadelphia       OFF-ST-10004459  Tennsco Single-Tier Lockers                                                                                                        -675.6120
# Phoenix            OFF-BI-10003650  GBC DocuBind 300 Electric Binding Machine                                                                                          -694.2936
# Rockford           OFF-BI-10004584  GBC ProClick 150 Presentation Binding System                                                                                       -729.9138
# Lorain             FUR-TA-10003954  Hon 94000 Series Round Tables                                                                                                      -734.5264
# Philadelphia       OFF-BI-10000545  GBC Ibimaster 500 Manual ProClick Binding System                                                                                   -760.9800
# Round Rock         OFF-SU-10000151  High Speed Automatic Electric Letter Opener                                                                                        -786.0144
# Colorado Springs   FUR-BO-10002613  Atlantic Metals Mobile 4-Shelf Bookcases, Custom Colors                                                                            -786.7440
# Phoenix            FUR-TA-10001889  Bush Advantage Collection Racetrack Conference Table                                                                               -814.4832
# Nashville          OFF-BI-10000545  GBC Ibimaster 500 Manual ProClick Binding System                                                                                   -913.1760
# Bethlehem          OFF-BI-10000545  GBC Ibimaster 500 Manual ProClick Binding System                                                                                   -913.1760
# Springfield        TEC-MA-10002210  Epson TM-T88V Direct Thermal Printer - Monochrome - Desktop                                                                        -935.9595
# Pueblo             TEC-MA-10001695  Zebra GK420t Direct Thermal/Thermal Transfer Printer                                                                               -938.2800
# Charlotte          TEC-MA-10001127  HP Designjet T520 Inkjet Large Format Printer - 24" Color                                                                          -944.9946
# Medina             TEC-MA-10000864  Cisco 9971 IP Video Phone Charcoal                                                                                                 -950.4000
# Columbia           FUR-TA-10001950  Balt Solid Wood Round Tables                                                                                                       -968.8833
# Knoxville          FUR-TA-10000198  Chromcraft Bull-Nose Wood Oval Conference Tables & Bases                                                                          -1002.7836
# Miami              OFF-BI-10001359  GBC DocuBind TL300 Electric Binding System                                                                                        -1031.5385
# Clarksville        OFF-BI-10000545  GBC Ibimaster 500 Manual ProClick Binding System                                                                                  -1065.3720
# Dallas             OFF-BI-10000545  GBC Ibimaster 500 Manual ProClick Binding System                                                                                  -1141.4700
# Chicago            OFF-BI-10003527  Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind                                                       -1143.8910
# San Antonio        OFF-AP-10002651  Hoover Upright Vacuum With Dirt Cup                                                                                               -1181.2824
# Philadelphia       OFF-SU-10002881  Martin Yale Chadless Opener Electric Letter Opener                                                                                -1199.2464
# Houston            OFF-AP-10002534  3.6 Cubic Foot Counter Height Office Refrigerator                                                                                 -1225.6192
# Memphis            OFF-BI-10001359  GBC DocuBind TL300 Electric Binding System                                                                                        -1237.8462
# Burlington         OFF-BI-10004995  GBC DocuBind P400 Electric Binding System                                                                                         -1306.5504
# San Antonio        TEC-MA-10000822  Lexmark MX611dhe Monochrome Laser Printer                                                                                         -1359.9920
# Houston            OFF-BI-10001359  GBC DocuBind TL300 Electric Binding System                                                                                        -1480.0335
# Philadelphia       FUR-BO-10004834  Riverside Palais Royal Lawyers Bookcase, Royale Cherry Finish                                                                     -1665.0522
# Jacksonville       TEC-MA-10002412  Cisco TelePresence System EX90 Videoconferencing Unit                                                                             -1811.0784
# Houston            OFF-BI-10004995  GBC DocuBind P400 Electric Binding System                                                                                         -1850.9464
# Concord            FUR-TA-10000198  Chromcraft Bull-Nose Wood Oval Conference Tables & Bases                                                                          -1862.3124
# Houston            OFF-BI-10003527  Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind                                                       -2287.7820
# Newark             TEC-MA-10000418  Cubify CubeX 3D Printer Double Head Print                                                                                         -2639.9912
# Chicago            OFF-BI-10001120  Ibico EPK-21 Electric Binding System                                                                                              -2929.4845
# Louisville         TEC-MA-10000822  Lexmark MX611dhe Monochrome Laser Printer                                                                                         -3399.9800
# San Antonio        OFF-BI-10004995  GBC DocuBind P400 Electric Binding System                                                                                         -3701.8928
# Burlington         TEC-MA-10004125  Cubify CubeX 3D Printer Triple Head Print                                                                                         -3839.9904
# Lancaster          TEC-MA-10000418  Cubify CubeX 3D Printer Double Head Print                                                                                         -6599.9780
# Name: Profit, dtype: float64

# %% [markdown]
# **Checking correlation between different variables**

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df_store.drop(columns='Postal Code').corr(),cbar=True,annot=True,cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
# How does unit price is affecting the sales
# sns.reset_defaults()
sns.set_style('whitegrid')
plt.figure(figsize=(10,10))
plt.scatter(x='unit_price',y='Sales',data=df_store)
plt.xlabel('Unit Price with no discounts')
plt.ylabel('Sales')
# Out:
# Text(0, 0.5, 'Sales')

# %% [markdown]
# **Identifying Customer Frequency**

# %%
df_products = df_store[['Customer ID', 'Product ID', 'Order Date']].sort_values(by=['Customer ID', 'Product ID', 'Order Date'])
df_products.head()
# Out:
#      Customer ID       Product ID Order Date
# 1108    AA-10315  FUR-FU-10002456 2014-09-15
# 7853    AA-10315  OFF-AP-10000576 2017-06-29
# 279     AA-10315  OFF-AP-10002765 2014-03-31
# 281     AA-10315  OFF-BI-10004390 2014-03-31
# 7855    AA-10315  OFF-BI-10004654 2017-06-29

# %%
df_product_count = df_store[['Customer ID', 'Product ID', 'Order Date']].groupby(['Customer ID', 'Product ID']).count()
df_product_count[df_product_count['Order Date'] > 1].head()
# Out:
#                              Order Date
# Customer ID Product ID
# AB-10060    OFF-PA-10001970           2
# AP-10915    OFF-PA-10001125           2
# AS-10090    OFF-BI-10002393           2
# AS-10630    OFF-LA-10001569           2
#             OFF-LA-10003190           2

# %%
df_products.join(df_product_count[df_product_count['Order Date'] > 1], how='inner', on=['Customer ID', 'Product ID'], lsuffix='ab').head()
# Out:
#      Customer ID       Product ID Order Dateab  Order Date
# 5408    AB-10060  OFF-PA-10001970   2016-09-01           2
# 5410    AB-10060  OFF-PA-10001970   2016-09-01           2
# 923     AP-10915  OFF-PA-10001125   2014-08-23           2
# 6461    AP-10915  OFF-PA-10001125   2016-12-10           2
# 3540    AS-10090  OFF-BI-10002393   2015-11-09           2

# %% [markdown]
# **Identifying if customers are increasing each month of each year**

# %%
# Churn rate - This store has customers increasing and we can see in the September, November and December they have most customers
df_store['order_month'] = df_store['Order Date'].dt.month
df_store['order_year'] = df_store['Order Date'].dt.year
df_store.drop_duplicates(subset=['order_year','order_month','Customer ID']).groupby(['order_year','order_month'])['Customer ID'].count()
# Out:
# order_year  order_month
# 2014        1               32
#             2               27
#             3               69
#             4               64
#             5               67
#             6               63
#             7               65
#             8               70
#             9              118
#             10              75
#             11             139
#             12             134
# 2015        1               28
#             2               36
#             3               77
#             4               69
#             5               69
#             6               68
#             7               64
#             8               64
#             9              126
#             10              79
#             11             146
#             12             141
# 2016        1               46
#             2               42
#             3               80
#             4               83
#             5               96
#             6               90
#             7               89
#             8               86
#             9              176
#             10              95
#             11             165
#             12             157
# 2017        1               67
#             2               53
#             3              115
#             4              109
#             5              113
#             6              118
#             7              102
#             8              104
#             9              196
#             10             136
#             11             216
#             12             195
# Name: Customer ID, dtype: int64

# %%
cust_jan_feb = set(df_store[(df_store['order_year']==2014) & (df_store['order_month'].isin([1,2]))]['Customer ID'])
cust_just_march = list(set(df_store[(df_store['order_year']==2014) & (df_store['order_month']==3)]['Customer ID']) - cust_jan_feb)
df_cust_just_march = df_store[df_store['Customer ID'].isin(cust_just_march)].head()

# %%
df_customer_counts = df_store.drop_duplicates(subset=['order_year','order_month','Customer ID']).groupby(['order_year','order_month'])['Customer ID'].count()

# %%
sns.set_style('whitegrid')
df_customer_counts.unstack(level=0).plot.line(grid=True,figsize=(10,10),xticks=range(1, 13),title='Customer each month')
# Out:
# <AxesSubplot:title={'center':'Customer each month'}, xlabel='order_month'>

# %% [markdown]
# **Identifying Customers who were not there before September**

# %%
mon = [1,2,3,4,5,6,7,8]
other_mon_cus = set(df_store[(df_store['order_month'].isin(mon)) & (df_store['order_year']==2014)]\
                .drop_duplicates(['Order ID','Customer ID'])['Customer ID'])

# %%
sep_cust = set(df_store[(df_store['order_month']==9) & (df_store['order_year']==2014)].drop_duplicates(['Order ID','Customer ID'])['Customer ID'])

# %%
# Total customers who came in september 2014
len(list(sep_cust - other_mon_cus))
# Out:
# 68

# %%
list(sep_cust - other_mon_cus)
# Out:
# ['LC-17140',
#  'MR-17545',
#  'CS-12400',
#  'NP-18700',
#  'PT-19090',
#  'PF-19165',
#  'AJ-10960',
#  'TT-21220',
#  'LW-17125',
#  'MC-17275',
#  'AS-10090',
#  'FA-14230',
#  'BM-11140',
#  'DB-13615',
#  'DL-12925',
#  'DM-13015',
#  'MC-18130',
#  'JM-15535',
#  'DN-13690',
#  'LH-17020',
#  'EA-14035',
#  'SB-20185',
#  'TH-21100',
#  'PR-18880',
#  'JK-15640',
#  'VP-21760',
#  'JG-15115',
#  'GZ-14545',
#  'KF-16285',
#  'CC-12220',
#  'TA-21385',
#  'BN-11470',
#  'HG-14965',
#  'LW-17215',
#  'SP-20620',
#  'KC-16255',
#  'LH-16750',
#  'SF-20065',
#  'SL-20155',
#  'LT-16765',
#  'AG-10765',
#  'JC-15775',
#  'RR-19525',
#  'LD-17005',
#  'EB-14170',
#  'JA-15970',
#  'KT-16465',
#  'KW-16570',
#  'JP-16135',
#  'SM-20950',
#  'SZ-20035',
#  'KD-16495',
#  'DM-12955',
#  'MA-17995',
#  'MS-17365',
#  'JB-15400',
#  'VG-21805',
#  'DK-13375',
#  'LR-17035',
#  'NB-18580',
#  'ON-18715',
#  'MF-18250',
#  'MT-18070',
#  'BF-11005',
#  'JD-16060',
#  'ES-14020',
#  'KD-16345',
#  'TH-21115']

# %% [markdown]
# **Monthly average discount each year--> considering when discounts given**

# %%
sns.set_style('whitegrid')
ser_monthly_discount = df_store.query('Discount > 0').groupby(by=['order_year','order_month'])['Discount'].mean()
df_monthly_discount = ser_monthly_discount.unstack(level=0)
df_monthly_discount.plot.line(figsize=(8,8),grid=True,xticks=range(1,13))
# Out:
# <AxesSubplot:xlabel='order_month'>

# %% [markdown]
# **Total number of discounts given each month**

# %%
sns.set_style('whitegrid')
ser_monthly_discount1 = df_store.query('Discount > 0').groupby(by=['order_year','order_month'])['Discount'].count()
df_monthly_discount1 = ser_monthly_discount1.unstack(level=0)
df_monthly_discount1.plot.line(figsize=(10,8),grid=True,xticks=range(1,13),title='Discount given each year')
# Out:
# <AxesSubplot:title={'center':'Discount given each year'}, xlabel='order_month'>

# %% [markdown]
# **Identifying customer buying only in September and November-->when discounts are given**

# %% [markdown]
# 1. unique customers in september 2014
# 2. have bought in january 2014 and so on
# 3. check if customer buying only in sep 2014 also buying in september of all years

# %%
offer_period_cust = set(df_store[(df_store['order_year']==2014) & (df_store['order_month'].isin([9,11,12]))]['Customer ID'])
len(offer_period_cust)
# Out:
# 332

# %%
months=[1,2,3,4,5,6,7,8,10]
other_month_customer = set(df_store[(df_store['order_year']==2014) & (df_store['order_month'].isin(months))]['Customer ID'])
offer_only_using_cust = list(offer_period_cust - other_month_customer)
print(offer_only_using_cust)
print(f'Total Customers buying in offer period: {len(offer_only_using_cust)}')
# Out:
# ['LC-17140', 'KD-16270', 'NG-18430', 'AT-10435', 'PT-19090', 'MK-17905', 'AB-10600', 'DB-13615', 'MC-18130', 'DP-13165', 'RB-19330', 'GZ-14545', 'SP-20920', 'KM-16660', 'AH-10210', 'LT-16765', 'MO-17500', 'AG-10765', 'TR-21325', 'DK-13150', 'LD-17005', 'TB-21190', 'PB-19210', 'PO-18850', 'SZ-20035', 'KN-16390', 'TZ-21580', 'CS-11845', 'BF-11215', 'RM-19675', 'AJ-10960', 'AS-10090', 'AB-10165', 'TH-21235', 'DM-13015', 'JM-15535', 'JF-15190', 'TH-21100', 'HR-14830', 'TW-21025', 'DK-12985', 'AH-10075', 'KF-16285', 'BG-11035', 'LW-17215', 'JK-15730', 'CP-12085', 'MG-17890', 'YC-21895', 'SH-20635', 'SS-20140', 'KC-16255', 'CY-12745', 'JC-16105', 'KT-16465', 'ML-17410', 'SC-20680', 'SM-20950', 'PS-19045', 'KD-16495', 'DM-12955', 'MS-17365', 'DJ-13420', 'DK-13375', 'MF-17665', 'MF-18250', 'AR-10540', 'DC-13285', 'NB-18655', 'BF-11005', 'ES-14020', 'SF-20200', 'CM-11815', 'DM-13345', 'RE-19405', 'TH-21115', 'TC-20980', 'CS-12400', 'EC-14050', 'SM-20005', 'JD-16150', 'LH-17020', 'TC-21475', 'BT-11680', 'KB-16600', 'PR-18880', 'RF-19840', 'JL-15175', 'TB-21250', 'KC-16675', 'RA-19285', 'DB-12970', 'WB-21850', 'RC-19825', 'NG-18355', 'JK-16120', 'KW-16570', 'DB-13360', 'JP-16135', 'TC-21535', 'JB-15400', 'JB-15925', 'SS-20875', 'ON-18715', 'MT-18070', 'DH-13075', 'JC-15775', 'KD-16345', 'DG-13300', 'PF-19165', 'SH-19975', 'PK-19075', 'NP-18700', 'MK-18160', 'TT-21220', 'TB-21175', 'LW-17125', 'MC-17275', 'PB-19105', 'SC-20695', 'BM-11140', 'JM-15865', 'DL-12925', 'BS-11380', 'SB-20185', 'EA-14035', 'BF-11080', 'SH-20395', 'JK-15640', 'AD-10180', 'MD-17350', 'CC-12100', 'PW-19240', 'PL-18925', 'CK-12595', 'TA-21385', 'MS-17530', 'MC-17635', 'BN-11470', 'HG-14965', 'SP-20620', 'LH-16750', 'SF-20065', 'PC-18745', 'AR-10345', 'RR-19525', 'AB-10105', 'RL-19615', 'JL-15505', 'SP-20860', 'CC-12670', 'JA-15970', 'IM-15070', 'EM-13825', 'MG-17695', 'GR-14560', 'SC-20305', 'VG-21805', 'LR-17035', 'SW-20755', 'JK-15325', 'MC-17575', 'LH-17155', 'KH-16630', 'MD-17860', 'FP-14320', 'TS-21505', 'JD-16060', 'FA-14230', 'RH-19510']
# Total Customers buying in offer period: 170

# %%
offer_period_cust1 = set(df_store[df_store['order_month'].isin([9,11,12])]['Customer ID'])
len(offer_period_cust1)
# Out:
# 740

# %%
other_month_customer1 = set(df_store[df_store['order_month'].isin(months)]['Customer ID'])
offer_only_using_cust1 = list(offer_period_cust1 - other_month_customer1)
offer_only_using_cust1
# Out:
# ['NG-18430',
#  'KC-16540',
#  'BF-11080',
#  'KB-16405',
#  'SH-20635',
#  'CD-12280',
#  'TC-21145',
#  'PC-18745',
#  'DJ-13630',
#  'AR-10345',
#  'DK-13150',
#  'RR-19315',
#  'TB-21190',
#  'CJ-11875',
#  'JB-15925',
#  'ER-13855',
#  'GR-14560',
#  'GH-14665',
#  'AS-10135',
#  'RE-19405']

# %%
# Check for month 9,11,12 with customers who have only the orders that has discount
# get these month customers
# Check if any of those customers even have a single order even with single item with no discount --> discard customer from consideration

df_cust_all = df_store[df_store['order_month'].isin([9,11,12])].groupby('Customer ID').count()
df_cust_discount = df_store[(df_store['order_month'].isin([9,11,12])) & (df_store['Discount'] > 0)].groupby('Customer ID').count()
df_cust_all_discount = df_cust_discount.join(df_cust_all, how='inner', on='Customer ID', rsuffix='all').query('Discount == Discountall')
df_cust_all_discount.index
# Out:
# Index(['AB-10165', 'AB-10600', 'AF-10885', 'AH-10120', 'AH-10195', 'AS-10045',
#        'BD-11620', 'BE-11410', 'BF-11275', 'BG-11740',
#        ...
#        'SA-20830', 'SC-20845', 'SH-20635', 'SJ-20215', 'SV-20815', 'TB-21280',
#        'TD-20995', 'TP-21565', 'TS-21610', 'VG-21805'],
#       dtype='object', name='Customer ID', length=126)

# %%
list_only = list(set(df_cust_all_discount.index) - other_month_customer1)
list_only
# Out:
# ['SH-20635', 'GH-14665', 'CJ-11875', 'RE-19405']

# %% [markdown]
# **Identifying Shipping Delays based on the Shipping mode used**

# %%
# A standatrd metric, to list down number of days shipping should take based on the shipping mode
cond_list_shipmode = [df_store['Ship Mode'] == 'Same Day', df_store['Ship Mode'] == 'First Class', 
                       df_store['Ship Mode'] == 'Second Class',df_store['Ship Mode'] == 'Standard Class']
choice_list_shipmode = [0,1,3,6]
df_store['taken_ship_days'] = (df_store['Ship Date'] - df_store['Order Date']).dt.days
df_store['required_ship_days'] = np.select(cond_list_shipmode,choice_list_shipmode)

# %%
df_store.tail()
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 9989  CA-2017-156720 2017-12-30 2018-01-03  Standard Class    JM-15580
# 9990  CA-2017-143259 2017-12-30 2018-01-03  Standard Class    PO-18865
# 9991  CA-2017-143259 2017-12-30 2018-01-03  Standard Class    PO-18865
# 9992  CA-2017-115427 2017-12-30 2018-01-03  Standard Class    EB-13975
# 9993  CA-2017-143259 2017-12-30 2018-01-03  Standard Class    PO-18865
#
#           Customer Name    Segment        Country           City       State  \
# 9989      Jill Matthias   Consumer  United States       Loveland    Colorado
# 9990  Patrick O'Donnell   Consumer  United States  New York City    New York
# 9991  Patrick O'Donnell   Consumer  United States  New York City    New York
# 9992         Erica Bern  Corporate  United States      Fairfield  California
# 9993  Patrick O'Donnell   Consumer  United States  New York City    New York
#
#       ...                                       Product Name    Sales  \
# 9989  ...                                Bagged Rubber Bands    3.024
# 9990  ...               Wilson Jones Legal Size Ring Binders   52.776
# 9991  ...                          Gear Head AU3700S Headset   90.930
# 9992  ...    Cardinal Slant-D Ring Binder, Heavy Gauge Vinyl   13.904
# 9993  ...  Bush Westfield Collection Bookcases, Fully Ass...  323.136
#
#      Quantity Discount   Profit unit_price  order_month  order_year  \
# 9989        3      0.2  -0.6048       1.26           12        2017
# 9990        3      0.2  19.7910      21.99           12        2017
# 9991        7      0.0   2.7279      12.99           12        2017
# 9992        2      0.2   4.5188       8.69           12        2017
# 9993        4      0.2  12.1176     100.98           12        2017
#
#       taken_ship_days  required_ship_days
# 9989                4                   6
# 9990                4                   6
# 9991                4                   6
# 9992                4                   6
# 9993                4                   6
#
# [5 rows x 25 columns]

# %%
# Creating column to store the ship status
cond_list_shipstatus = [(df_store['taken_ship_days'] > df_store['required_ship_days']),
                        (df_store['taken_ship_days'] == df_store['required_ship_days']), 
                        (df_store['taken_ship_days'] < df_store['required_ship_days'])]
choice_list_shipstatus = ['Late','On-Time','Early']
df_store['ship_status'] = np.select(cond_list_shipstatus,choice_list_shipstatus)
df_store.tail(20)
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 9974  US-2017-162068 2017-12-28 2017-12-31    Second Class    PC-18745
# 9975  US-2017-158526 2017-12-29 2018-01-01    Second Class    KH-16360
# 9976  US-2017-158526 2017-12-29 2018-01-01    Second Class    KH-16360
# 9977  US-2017-158526 2017-12-29 2018-01-01    Second Class    KH-16360
# 9978  US-2017-158526 2017-12-29 2018-01-01    Second Class    KH-16360
# 9979  US-2017-158526 2017-12-29 2018-01-01    Second Class    KH-16360
# 9980  CA-2017-130631 2017-12-29 2018-01-02  Standard Class    BS-11755
# 9981  CA-2017-118885 2017-12-29 2018-01-02  Standard Class    JG-15160
# 9982  CA-2017-146626 2017-12-29 2018-01-05  Standard Class    BP-11185
# 9983  CA-2017-130631 2017-12-29 2018-01-02  Standard Class    BS-11755
# 9984  CA-2017-118885 2017-12-29 2018-01-02  Standard Class    JG-15160
# 9985  CA-2017-158673 2017-12-29 2018-01-04  Standard Class    KB-16600
# 9986  US-2017-102638 2017-12-29 2017-12-31     First Class    MC-17845
# 9987  CA-2017-115427 2017-12-30 2018-01-03  Standard Class    EB-13975
# 9988  CA-2017-126221 2017-12-30 2018-01-05  Standard Class    CC-12430
# 9989  CA-2017-156720 2017-12-30 2018-01-03  Standard Class    JM-15580
# 9990  CA-2017-143259 2017-12-30 2018-01-03  Standard Class    PO-18865
# 9991  CA-2017-143259 2017-12-30 2018-01-03  Standard Class    PO-18865
# 9992  CA-2017-115427 2017-12-30 2018-01-03  Standard Class    EB-13975
# 9993  CA-2017-143259 2017-12-30 2018-01-03  Standard Class    PO-18865
#
#           Customer Name      Segment        Country           City  \
# 9974     Pamela Coakley    Corporate  United States       Loveland
# 9975   Katherine Hughes     Consumer  United States     Louisville
# 9976   Katherine Hughes     Consumer  United States     Louisville
# 9977   Katherine Hughes     Consumer  United States     Louisville
# 9978   Katherine Hughes     Consumer  United States     Louisville
# 9979   Katherine Hughes     Consumer  United States     Louisville
# 9980      Bruce Stewart     Consumer  United States        Edmonds
# 9981       James Galang     Consumer  United States    Los Angeles
# 9982       Ben Peterman    Corporate  United States        Anaheim
# 9983      Bruce Stewart     Consumer  United States        Edmonds
# 9984       James Galang     Consumer  United States    Los Angeles
# 9985        Ken Brennan    Corporate  United States   Grand Rapids
# 9986       Michael Chen     Consumer  United States  New York City
# 9987         Erica Bern    Corporate  United States      Fairfield
# 9988        Chuck Clark  Home Office  United States       Columbus
# 9989      Jill Matthias     Consumer  United States       Loveland
# 9990  Patrick O'Donnell     Consumer  United States  New York City
# 9991  Patrick O'Donnell     Consumer  United States  New York City
# 9992         Erica Bern    Corporate  United States      Fairfield
# 9993  Patrick O'Donnell     Consumer  United States  New York City
#
#            State  ...     Sales Quantity Discount    Profit unit_price  \
# 9974    Colorado  ...     1.188        2      0.7   -0.9900       1.98
# 9975    Kentucky  ...    34.580        1      0.0   10.0282      34.58
# 9976    Kentucky  ...    12.530        1      0.0    5.8891      12.53
# 9977    Kentucky  ...  1207.840        8      0.0  314.0384     150.98
# 9978    Kentucky  ...   258.750        3      0.0   77.6250      86.25
# 9979    Kentucky  ...   300.980        1      0.0   87.2842     300.98
# 9980  Washington  ...    68.460        2      0.0   20.5380      34.23
# 9981  California  ...   393.568        4      0.2  -44.2764     122.99
# 9982  California  ...   101.120        8      0.0   37.4144      12.64
# 9983  Washington  ...    19.600        5      0.0    9.6040       3.92
# 9984  California  ...   302.376        3      0.2   22.6782     125.99
# 9985    Michigan  ...   209.700        2      0.0  100.6560     104.85
# 9986    New York  ...     6.030        3      0.0    2.9547       2.01
# 9987  California  ...    20.720        2      0.2    6.4750      12.95
# 9988     Indiana  ...   209.300        2      0.0   56.5110     104.65
# 9989    Colorado  ...     3.024        3      0.2   -0.6048       1.26
# 9990    New York  ...    52.776        3      0.2   19.7910      21.99
# 9991    New York  ...    90.930        7      0.0    2.7279      12.99
# 9992  California  ...    13.904        2      0.2    4.5188       8.69
# 9993    New York  ...   323.136        4      0.2   12.1176     100.98
#
#      order_month  order_year  taken_ship_days  required_ship_days  ship_status
# 9974          12        2017                3                   3      On-Time
# 9975          12        2017                3                   3      On-Time
# 9976          12        2017                3                   3      On-Time
# 9977          12        2017                3                   3      On-Time
# 9978          12        2017                3                   3      On-Time
# 9979          12        2017                3                   3      On-Time
# 9980          12        2017                4                   6        Early
# 9981          12        2017                4                   6        Early
# 9982          12        2017                7                   6         Late
# 9983          12        2017                4                   6        Early
# 9984          12        2017                4                   6        Early
# 9985          12        2017                6                   6      On-Time
# 9986          12        2017                2                   1         Late
# 9987          12        2017                4                   6        Early
# 9988          12        2017                6                   6      On-Time
# 9989          12        2017                4                   6        Early
# 9990          12        2017                4                   6        Early
# 9991          12        2017                4                   6        Early
# 9992          12        2017                4                   6        Early
# 9993          12        2017                4                   6        Early
#
# [20 rows x 26 columns]

# %%
df_shipments = df_store.groupby(['Order ID','Sub-Category']).agg({
    'State': 'first',
    'order_month':'first',
    'order_year' : 'first',
    'taken_ship_days' : 'first',
    'required_ship_days' : 'first',
    'ship_status' : 'first'
})
df_shipments.head()
# Out:
#                                   State  order_month  order_year  \
# Order ID       Sub-Category
# CA-2014-100006 Phones          New York            9        2014
# CA-2014-100090 Binders       California            7        2014
#                Tables        California            7        2014
# CA-2014-100293 Paper            Florida            3        2014
# CA-2014-100328 Binders         New York            1        2014
#
#                              taken_ship_days  required_ship_days ship_status
# Order ID       Sub-Category
# CA-2014-100006 Phones                      6                   6     On-Time
# CA-2014-100090 Binders                     4                   6       Early
#                Tables                      4                   6       Early
# CA-2014-100293 Paper                       4                   6       Early
# CA-2014-100328 Binders                     6                   6     On-Time

# %%
df_shipments1 = df_shipments.reset_index()
df_shipments1.head()
# Out:
#          Order ID Sub-Category       State  order_month  order_year  \
# 0  CA-2014-100006       Phones    New York            9        2014
# 1  CA-2014-100090      Binders  California            7        2014
# 2  CA-2014-100090       Tables  California            7        2014
# 3  CA-2014-100293        Paper     Florida            3        2014
# 4  CA-2014-100328      Binders    New York            1        2014
#
#    taken_ship_days  required_ship_days ship_status
# 0                6                   6     On-Time
# 1                4                   6       Early
# 2                4                   6       Early
# 3                4                   6       Early
# 4                6                   6     On-Time

# %%
df_shipments1.shape
# Out:
# (9159, 8)

# %%
df_shipments2 = pd.DataFrame({
    'State' : df_shipments1['State'],
    'Sub-Category' : df_shipments1['Sub-Category']    
})
df_shipments2.drop_duplicates(inplace=True)

# %%
ser_stotal = df_shipments1.groupby(['State', 'Sub-Category']).count()['ship_status']
ser_searly = df_shipments1[df_shipments1['ship_status'] == 'Early'].groupby(['State', 'Sub-Category']).count()['ship_status']
ser_stime = df_shipments1[df_shipments1['ship_status'] == 'On-Time'].groupby(['State', 'Sub-Category']).count()['ship_status']
ser_slate = df_shipments1[df_shipments1['ship_status'] == 'Late'].groupby(['State', 'Sub-Category']).count()['ship_status']

# %%
df_shipments2 = df_shipments2.merge((ser_searly * 100 / ser_stotal), right_index=True, left_on=['State', 'Sub-Category']).rename(columns={'ship_status': 'percent_early'}) \
    .merge((ser_stime * 100 / ser_stotal), right_index=True, left_on=['State', 'Sub-Category']).rename(columns={'ship_status': 'percent_on_time'}) \
    .merge((ser_slate * 100 / ser_stotal), right_index=True, left_on=['State', 'Sub-Category']).rename(columns={'ship_status': 'percent_late'})

# %%
df_shipments2[df_shipments2['percent_late'].isnull()].head()
# Out:
#            State Sub-Category  percent_early  percent_on_time  percent_late
# 121  Mississippi      Storage      75.000000        25.000000           NaN
# 122  Mississippi       Tables     100.000000              NaN           NaN
# 123     Delaware     Machines            NaN       100.000000           NaN
# 125         Utah  Furnishings      33.333333        66.666667           NaN
# 171      Montana      Binders      66.666667        33.333333           NaN

# %%
# Late Deliveries Heat map
plt.figure(figsize=(15, 12))
df_pivot_late = df_shipments2.pivot('State','Sub-Category','percent_late')
sns.set(rc={'axes.facecolor':'gray'})
sns.heatmap(df_pivot_late,cmap="Oranges",linecolor='black',linewidths=0.5, mask=df_pivot_late.isnull())
# Out:
# <AxesSubplot:xlabel='Sub-Category', ylabel='State'>

# %%
df_shipments1[(df_shipments1['State']=='Alabama') & (df_shipments1['Sub-Category']=='Appliances')]
# Out:
#             Order ID Sub-Category    State  order_month  order_year  \
# 3897  CA-2016-127208   Appliances  Alabama            6        2016
#
#       taken_ship_days  required_ship_days ship_status
# 3897                3                   1        Late

# %%
df_random = df_store.drop_duplicates(['Order ID','Customer ID']).groupby('Customer ID')
# df_random.groups
df_low_orders = df_random.size().sort_values().reset_index()
df_low_orders.rename(columns={0: 'no_of_orders'},inplace=True)

# %%
df_low_orders.head(2)
# Out:
#   Customer ID  no_of_orders
# 0    CJ-11875             1
# 1    RM-19750             1

# %%
low_order_list = list(df_low_orders[df_low_orders['no_of_orders'] < 2]['Customer ID'])
df_ran2 = df_store[df_store['Customer ID'].isin(low_order_list)].sort_values(['Order ID','Customer ID'])

# %%
df_ran2.drop_duplicates(subset=['Order ID']).groupby('ship_status').count()['Order ID']\
        .plot.pie(y='Order ID',autopct=lambda p:'{:.0f}%'.format(p),legend=True,figsize=(5,5))
# Out:
# <AxesSubplot:ylabel='Order ID'>

# %%
moderate_order_list = list(df_low_orders[(df_low_orders['no_of_orders'] == 2) & (df_low_orders['no_of_orders'] < 5)]['Customer ID'])
df_ran3 = df_store[df_store['Customer ID'].isin(moderate_order_list)].sort_values(['Order ID','Customer ID'])
df_ran3.drop_duplicates(subset=['Order ID']).groupby('ship_status').count()['Order ID']\
        .plot.pie(y='Order ID',autopct=lambda p:'{:.0f}%'.format(p),legend=True,figsize=(5,5))
# Out:
# <AxesSubplot:ylabel='Order ID'>

# %%
high_order_list = list(df_low_orders[(df_low_orders['no_of_orders'] > 4)]['Customer ID'])
df_ran4 = df_store[df_store['Customer ID'].isin(high_order_list)].sort_values(['Order ID','Customer ID'])
# tot_ord = df_ran4.drop_duplicates(subset=['Order ID'])['Order ID'].count()
df_ran4.drop_duplicates(subset=['Order ID']).groupby('ship_status').count()['Order ID']\
        .plot.pie(y='Order ID',autopct = lambda p : '{:.0f}%'.format(p),legend=True,figsize=(5,5))
# Out:
# <AxesSubplot:ylabel='Order ID'>

# %% [markdown]
# **Plotting quantities sold for each sub-categories at no discounts and with different discount percentages**

# %%
df_store[df_store['Discount']==0].groupby('Sub-Category')['Sub-Category'].count()
# Out:
# Sub-Category
# Accessories    471
# Appliances     271
# Art            498
# Binders        337
# Bookcases       60
# Chairs         133
# Copiers         22
# Envelopes      152
# Fasteners      128
# Furnishings    571
# Labels         239
# Machines        29
# Paper          857
# Phones         311
# Storage        530
# Supplies       117
# Tables          72
# Name: Sub-Category, dtype: int64

# %%
fig,ax2 = plt.subplots(12,1,figsize=(8,90))
# No Discounts Offered
df_0 = df_store[df_store['Discount']==0].groupby('Sub-Category')['Quantity'].sum()
df_0_xvalue = df_0.index
df_0_yvalue = df_0.to_list()
ax2[0].barh(df_0_xvalue,df_0_yvalue,color='green')
ax2[0].set_title('No Discounts Offered')
ax2[0].set_facecolor('white')

# 10% Discount Offered
df_10 = df_store[df_store['Discount']==0.1].groupby('Sub-Category')['Quantity'].sum()
df_10_xvalue = df_10.index
df_10_yvalue = df_10.to_list()
ax2[1].barh(df_10_xvalue,df_10_yvalue,color='green')
ax2[1].set_title('10% Discounts Offered')
ax2[1].set_facecolor('white')

# 15% Discount Offered
df_15 = df_store[df_store['Discount']==0.15].groupby('Sub-Category')['Quantity'].sum()
df_15_xvalue = df_15.index
df_15_yvalue = df_15.to_list()
ax2[2].barh(df_15_xvalue,df_15_yvalue,color='green')
ax2[2].set_title('15% Discounts Offered')
ax2[2].set_facecolor('white')

# 20% Discount Offered
df_20 = df_store[df_store['Discount']==0.2].groupby('Sub-Category')['Quantity'].sum()
df_20_xvalue = df_20.index
df_20_yvalue = df_20.to_list()
ax2[3].barh(df_20_xvalue,df_20_yvalue,color='green')
ax2[3].set_title('20% Discounts Offered')
ax2[3].set_facecolor('white')

# 30% Discount Offered
df_30 = df_store[df_store['Discount']==0.3].groupby('Sub-Category')['Quantity'].sum()
df_30_xvalue = df_30.index
df_30_yvalue = df_30.to_list()
ax2[4].barh(df_30_xvalue,df_30_yvalue,color='green')
ax2[4].set_title('30% Discounts Offered')
ax2[4].set_facecolor('white')

# 32% Discount Offered
df_32 = df_store[df_store['Discount']==0.32].groupby('Sub-Category')['Quantity'].sum()
df_32_xvalue = df_32.index
df_32_yvalue = df_32.to_list()
ax2[5].barh(df_32_xvalue,df_32_yvalue,color='green')
ax2[5].set_title('32% Discounts Offered')
ax2[5].set_facecolor('white')

# 40% Discount Offered
df_40 = df_store[df_store['Discount']==0.4].groupby('Sub-Category')['Quantity'].sum()
df_40_xvalue = df_40.index
df_40_yvalue = df_40.to_list()
ax2[6].barh(df_40_xvalue,df_40_yvalue,color='green')
ax2[6].set_title('40% Discounts Offered')
ax2[6].set_facecolor('white')

# 45% Discount Offered
df_45 = df_store[df_store['Discount']==0.45].groupby('Sub-Category')['Quantity'].sum()
df_45_xvalue = df_45.index
df_45_yvalue = df_45.to_list()
ax2[7].barh(df_45_xvalue,df_45_yvalue,color='green')
ax2[7].set_title('45% Discounts Offered')
ax2[7].set_facecolor('white')

# 50% Discount Offered
df_50 = df_store[df_store['Discount']==0.5].groupby('Sub-Category')['Quantity'].sum()
df_50_xvalue = df_50.index
df_50_yvalue = df_50.to_list()
ax2[8].barh(df_50_xvalue,df_50_yvalue,color='green')
ax2[8].set_title('50% Discounts Offered')
ax2[8].set_facecolor('white')

# 60% Discount Offered
df_60 = df_store[df_store['Discount']==0.6].groupby('Sub-Category')['Quantity'].sum()
df_60_xvalue = df_60.index
df_60_yvalue = df_60.to_list()
ax2[9].barh(df_60_xvalue,df_60_yvalue,color='green')
ax2[9].set_title('60% Discounts Offered')
ax2[9].set_facecolor('white')

# 70% Discount Offered
df_70 = df_store[df_store['Discount']==0.7].groupby('Sub-Category')['Quantity'].sum()
df_70_xvalue = df_70.index
df_70_yvalue = df_70.to_list()
ax2[10].barh(df_70_xvalue,df_70_yvalue,color='green')
ax2[10].set_title('70% Discounts Offered')
ax2[10].set_facecolor('white')

# 80% Discount Offered
df_80 = df_store[df_store['Discount']==0.8].groupby('Sub-Category')['Quantity'].sum()
df_80_xvalue = df_80.index
df_80_yvalue = df_80.to_list()
ax2[11].barh(df_80_xvalue,df_80_yvalue,color='green')
ax2[11].set_title('80% Discounts Offered')
ax2[11].set_facecolor('white')

# %% [markdown]
# **Different Discounts offered for each sub-category**

# %%
sns.set_style('whitegrid')
# df_store['Discount_floor'] = (df_store['Discount'] * 10).apply(np.floor) / 10
df_stack_bar = df_store.groupby(['Sub-Category','Discount'])['Sub-Category'].count()

# %%
df_stack_bar1 = df_stack_bar \
    .unstack(level=1, fill_value=0) \
    .reset_index().rename_axis(None, axis=1)
df_stack_bar1.head()
# Out:
#   Sub-Category  0.0  0.1  0.15  0.2  0.3  0.32  0.4  0.45  0.5  0.6  0.7  0.8
# 0  Accessories  471    0     0  304    0     0    0     0    0    0    0    0
# 1   Appliances  271   16     0  112    0     0    0     0    0    0    0   67
# 2          Art  498    0     0  298    0     0    0     0    0    0    0    0
# 3      Binders  337    0     0  573    0     0    0     0    0    0  380  233
# 4    Bookcases   60    0    52   46   10    27    0     0   18    0   15    0

# %%
df_sum = df_stack_bar1.sum(axis=1)

df_stack_bar1[0.0] = df_stack_bar1[0.0] * 100 / df_sum
df_stack_bar1[0.1] = df_stack_bar1[0.1] * 100 / df_sum
df_stack_bar1[0.2] = df_stack_bar1[0.2] * 100 / df_sum
df_stack_bar1[0.3] = df_stack_bar1[0.3] * 100 / df_sum
df_stack_bar1[0.4] = df_stack_bar1[0.4] * 100 / df_sum
df_stack_bar1[0.5] = df_stack_bar1[0.5] * 100 / df_sum
df_stack_bar1[0.6] = df_stack_bar1[0.6] * 100 / df_sum
df_stack_bar1[0.7] = df_stack_bar1[0.7] * 100 / df_sum
df_stack_bar1[0.8] = df_stack_bar1[0.8] * 100 / df_sum
df_stack_bar1.head()
# Out:
# C:\Users\baira\AppData\Local\Temp\ipykernel_22884\1930558934.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_sum = df_stack_bar1.sum(axis=1)
#   Sub-Category        0.0       0.1  0.15        0.2       0.3  0.32  0.4  \
# 0  Accessories  60.774194  0.000000     0  39.225806  0.000000     0  0.0
# 1   Appliances  58.154506  3.433476     0  24.034335  0.000000     0  0.0
# 2          Art  62.562814  0.000000     0  37.437186  0.000000     0  0.0
# 3      Binders  22.127380  0.000000     0  37.623112  0.000000     0  0.0
# 4    Bookcases  26.315789  0.000000    52  20.175439  4.385965    27  0.0
#
#    0.45       0.5  0.6        0.7        0.8
# 0     0  0.000000  0.0   0.000000   0.000000
# 1     0  0.000000  0.0   0.000000  14.377682
# 2     0  0.000000  0.0   0.000000   0.000000
# 3     0  0.000000  0.0  24.950755  15.298752
# 4     0  7.894737  0.0   6.578947   0.000000

# %%
df_stack_bar1.plot.bar(x='Sub-Category',stacked=True, figsize=(15, 10))
plt.legend(fontsize=18)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
# Out:
# (array([  0.,  20.,  40.,  60.,  80., 100., 120., 140., 160.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
cust_ord_cnt = df_store.drop_duplicates(subset=['Order ID','Customer ID']).groupby('Customer ID')['Order ID'].count()
cust_ord_cnt[cust_ord_cnt == 1].sum()
# Out:
# 12

# %%
df_store.drop_duplicates(subset='Customer ID')['Customer ID'].count()
# Out:
# 793

# %% [markdown]
# **Checking retention of customers in each quarter starting from the year 2016**

# %%
df_store['Order Date'].min()
# Out:
# Timestamp('2014-01-03 00:00:00')

# %%
from datetime import datetime, timedelta
from matplotlib import ticker
from matplotlib.dates import DateFormatter
from matplotlib.pyplot import yticks

date_val = datetime(2016, 1, 1)

delta_24 = timedelta(days=24 * 30)  # no. of days in 24 months
delta_12 = timedelta(days=12 * 30)
delta_6 = timedelta(days=6 * 30)
delta_3 = timedelta(days=3 * 31)
end = datetime(2018, 1, 1)
idx = 0
retentions = []
while date_val < end:
    old_customers = df_store[(df_store['Order Date'] > (date_val - delta_24)) & (df_store['Order Date'] < (date_val - delta_12))]['Customer ID'].unique()
    recent_customers = df_store[(df_store['Order Date'] > (date_val - delta_6)) & (df_store['Order Date'] < date_val)]['Customer ID'].unique()
    retained_customers = np.intersect1d(old_customers, recent_customers)  # numpy.intersect1d--> Find the intersection of two arrays.    
    retentions.append([retained_customers.size * 100 / old_customers.size, date_val])
    date_val = date_val + delta_3  # change the quarter, by adding 3 months
    idx+= 1

df_retention = pd.DataFrame(retentions, columns=['Retention Rate' , 'Date'])
df_retention['Quarter'] = df_retention['Date'].dt.to_period('Q').dt.strftime('Q%q %Y')
ax = df_retention.plot.line(x='Quarter', y='Retention Rate', figsize=(12,8), yticks=range(0, 100, 5))
ax.yaxis.set_major_formatter(ticker.PercentFormatter())
